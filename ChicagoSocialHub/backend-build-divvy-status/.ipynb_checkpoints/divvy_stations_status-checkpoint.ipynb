# %%
##################################################################################################
##################################################################################################


### This file and the source code provided can be used only for the projects and assignments  
### of this course

### Last Edit by Dr. Atef Bader: 12/28/2018


##################################################################################################

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Divvy
#
# **Divvy** is a bicycle sharing system in the City of Chicago.
#
# Click __[here](https://en.wikipedia.org/wiki/Divvy)__ to read more about **Divvy**
#
#
# Click __[here](https://www.divvybikes.com/)__ to visit the official website for **Divvy**

# %% [markdown]
# This script will send a heartbeat every 2 minutes to divvy to collect their stations status in the City of Chicago.

# %% [markdown]
# ### PostgreSQL
#
# We will collect the data from **Divvy** servers and store the data in a table on **PostgreSQL** server.
#
# This python script will send a heartbeat to Divvy every 2 minutes to retrieve the  status of the Divvy dock stations and store the data on PostgreSQL server.
#
# You need the package **psycopg2** to Connect to **PostgreSQL** server.
#
# Execute the **pip install** command from the command window to install  the package listed bove:
# - pip install psycopg2

# %%
import json
import requests
import datetime
import time
import os
import psycopg2
import pandas as pd
import urllib.request
import json
import csv

from pprint import pprint
from psycopg2.extensions import ISOLATION_LEVEL_AUTOCOMMIT

# %%
# Get divvy statations status
# Status is returned as a json reply

response = urllib.request.urlopen('https://feeds.divvybikes.com/stations/stations.json')

# Extract the body of the reply
response_body = response.read()

# Decode the format in json format
stations_json = json.loads(response_body.decode("utf-8"))

# %%
type(stations_json)
# Out:
# dict

# %%
pprint(stations_json)
# Out:
# {'executionTime': '2019-03-29 18:54:30',
#  'stationBeanList': [{'altitude': '',
#                       'availableBikes': 9,
#                       'availableDocks': 29,
#                       'city': 'Chicago',
#                       'id': 2,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '15541',
#                       'lastCommunicationTime': '2019-03-29 18:50:37',
#                       'latitude': 41.87647,
#                       'location': '',
#                       'longitude': -87.62034,
#                       'postalCode': '60605',
#                       'stAddress1': 'Buckingham Fountain',
#                       'stAddress2': '',
#                       'stationName': 'Buckingham Fountain',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 38},
#                      {'altitude': '',
#                       'availableBikes': 1,
#                       'availableDocks': 54,
#                       'city': 'Chicago',
#                       'id': 3,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '15544',
#                       'lastCommunicationTime': '2019-03-29 18:52:18',
#                       'latitude': 41.86722595682,
#                       'location': '',
#                       'longitude': -87.6153553902,
#                       'postalCode': '',
#                       'stAddress1': 'Shedd Aquarium',
#                       'stAddress2': '',
#                       'stationName': 'Shedd Aquarium',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 55},
#                      {'altitude': '',
#                       'availableBikes': 3,
#                       'availableDocks': 19,
#                       'city': 'Chicago',
#                       'id': 4,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '15545',
#                       'lastCommunicationTime': '2019-03-29 18:52:24',
#                       'latitude': 41.856268,
#                       'location': '',
#                       'longitude': -87.613348,
#                       'postalCode': '',
#                       'stAddress1': 'Burnham Harbor',
#                       'stAddress2': '',
#                       'stationName': 'Burnham Harbor',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 23},
#                      {'altitude': '',
#                       'availableBikes': 6,
#                       'availableDocks': 17,
#                       'city': 'Chicago',
#                       'id': 5,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '13030',
#                       'lastCommunicationTime': '2019-03-29 18:52:38',
#                       'latitude': 41.874053,
#                       'location': '620 S. State St.',
#                       'longitude': -87.627716,
#                       'postalCode': '60605',
#                       'stAddress1': 'State St & Harrison St',
#                       'stAddress2': '',
#                       'stationName': 'State St & Harrison St',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 23},
#                      {'altitude': '',
#                       'availableBikes': 4,
#                       'availableDocks': 35,
#                       'city': 'Chicago',
#                       'id': 6,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '15548',
#                       'lastCommunicationTime': '2019-03-29 18:54:19',
#                       'latitude': 41.886976,
#                       'location': '',
#                       'longitude': -87.612813,
#                       'postalCode': '60601',
#                       'stAddress1': 'Dusable Harbor',
#                       'stAddress2': '',
#                       'stationName': 'Dusable Harbor',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 39},
#                      {'altitude': '',
#                       'availableBikes': 7,
#                       'availableDocks': 12,
#                       'city': 'Chicago',
#                       'id': 7,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '15534',
#                       'lastCommunicationTime': '2019-03-29 18:51:08',
#                       'latitude': 41.88634906269,
#                       'location': '',
#                       'longitude': -87.6175165471,
#                       'postalCode': '60601',
#                       'stAddress1': 'Field Blvd & South Water St',
#                       'stAddress2': '',
#                       'stationName': 'Field Blvd & South Water St',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 19},
#                      {'altitude': '',
#                       'availableBikes': 2,
#                       'availableDocks': 13,
#                       'city': 'Chicago',
#                       'id': 9,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '15695',
#                       'lastCommunicationTime': '2019-03-29 18:54:22',
#                       'latitude': 41.82879201994,
#                       'location': 'NA1',
#                       'longitude': -87.6806044594,
#                       'postalCode': '60609',
#                       'stAddress1': 'Leavitt St & Archer Ave',
#                       'stAddress2': '',
#                       'stationName': 'Leavitt St & Archer Ave',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 15},
#                      {'altitude': '',
#                       'availableBikes': 1,
#                       'availableDocks': 10,
#                       'city': 'Chicago',
#                       'id': 11,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '15496',
#                       'lastCommunicationTime': '2019-03-29 18:52:09',
#                       'latitude': 41.76663823695,
#                       'location': '',
#                       'longitude': -87.5764501141,
#                       'postalCode': '60649',
#                       'stAddress1': 'Jeffery Blvd & 71st St',
#                       'stAddress2': '',
#                       'stationName': 'Jeffery Blvd & 71st St',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 11},
#                      {'altitude': '',
#                       'availableBikes': 3,
#                       'availableDocks': 12,
#                       'city': 'Chicago',
#                       'id': 12,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '15497',
#                       'lastCommunicationTime': '2019-03-29 18:51:47',
#                       'latitude': 41.7664094567,
#                       'location': 'MLSW',
#                       'longitude': -87.5656875719,
#                       'postalCode': '60649',
#                       'stAddress1': 'South Shore Dr & 71st St',
#                       'stAddress2': '',
#                       'stationName': 'South Shore Dr & 71st St',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 15},
#                      {'altitude': '',
#                       'availableBikes': 11,
#                       'availableDocks': 24,
#                       'city': 'Chicago',
#                       'id': 13,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '13066',
#                       'lastCommunicationTime': '2019-03-29 18:52:16',
#                       'latitude': 41.932418,
#                       'location': '2790 N.Wilton Ave',
#                       'longitude': -87.652705,
#                       'postalCode': '60614',
#                       'stAddress1': 'Wilton Ave & Diversey Pkwy',
#                       'stAddress2': '',
#                       'stationName': 'Wilton Ave & Diversey Pkwy',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 35},
#                      {'altitude': '',
#                       'availableBikes': 6,
#                       'availableDocks': 9,
#                       'city': 'Chicago',
#                       'id': 14,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '13163',
#                       'lastCommunicationTime': '2019-03-29 18:53:48',
#                       'latitude': 41.858086,
#                       'location': '962 W. 18th St',
#                       'longitude': -87.651073,
#                       'postalCode': '60608',
#                       'stAddress1': 'Morgan St & 18th St',
#                       'stAddress2': '',
#                       'stationName': 'Morgan St & 18th St',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 15},
#                      {'altitude': '',
#                       'availableBikes': 6,
#                       'availableDocks': 9,
#                       'city': 'Chicago',
#                       'id': 15,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '13164',
#                       'lastCommunicationTime': '2019-03-29 18:54:13',
#                       'latitude': 41.858166,
#                       'location': '1726 S Racine Ave',
#                       'longitude': -87.656495,
#                       'postalCode': '60608',
#                       'stAddress1': 'Racine Ave & 18th St',
#                       'stAddress2': '',
#                       'stationName': 'Racine Ave & 18th St',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 15},
#                      {'altitude': '',
#                       'availableBikes': 4,
#                       'availableDocks': 11,
#                       'city': 'Chicago',
#                       'id': 16,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '13223',
#                       'lastCommunicationTime': '2019-03-29 18:54:22',
#                       'latitude': 41.910337,
#                       'location': '1575 N Paulina Ave',
#                       'longitude': -87.670072,
#                       'postalCode': '60622',
#                       'stAddress1': 'Paulina Ave & North Ave',
#                       'stAddress2': '',
#                       'stationName': 'Paulina Ave & North Ave',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 15},
#                      {'altitude': '',
#                       'availableBikes': 10,
#                       'availableDocks': 12,
#                       'city': 'Chicago',
#                       'id': 17,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '13246',
#                       'lastCommunicationTime': '2019-03-29 18:54:23',
#                       'latitude': 41.903119,
#                       'location': ' W. Divison St',
#                       'longitude': -87.673935,
#                       'postalCode': '60622',
#                       'stAddress1': 'Honore St & Division St',
#                       'stAddress2': '',
#                       'stationName': 'Honore St & Division St',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 23},
#                      {'altitude': '',
#                       'availableBikes': 0,
#                       'availableDocks': 19,
#                       'city': 'Chicago',
#                       'id': 18,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '15536',
#                       'lastCommunicationTime': '2019-03-29 18:50:31',
#                       'latitude': 41.883132,
#                       'location': '',
#                       'longitude': -87.637321,
#                       'postalCode': '60606',
#                       'stAddress1': 'Wacker Dr & Washington St',
#                       'stAddress2': '',
#                       'stationName': 'Wacker Dr & Washington St',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 19},
#                      {'altitude': '',
#                       'availableBikes': 5,
#                       'availableDocks': 11,
#                       'city': 'Chicago',
#                       'id': 19,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '13139',
#                       'lastCommunicationTime': '2019-03-29 18:54:22',
#                       'latitude': 41.868968,
#                       'location': '',
#                       'longitude': -87.659141,
#                       'postalCode': '60607',
#                       'stAddress1': 'Loomis St & Taylor St (*)',
#                       'stAddress2': '',
#                       'stationName': 'Loomis St & Taylor St (*)',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 16},
#                      {'altitude': '',
#                       'availableBikes': 8,
#                       'availableDocks': 7,
#                       'city': 'Chicago',
#                       'id': 20,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '13154',
#                       'lastCommunicationTime': '2019-03-29 18:53:44',
#                       'latitude': 41.910522,
#                       'location': '',
#                       'longitude': -87.653106,
#                       'postalCode': '60642',
#                       'stAddress1': 'Sheffield Ave & Kingsbury St',
#                       'stAddress2': '',
#                       'stationName': 'Sheffield Ave & Kingsbury St',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 15},
#                      {'altitude': '',
#                       'availableBikes': 15,
#                       'availableDocks': 8,
#                       'city': 'Chicago',
#                       'id': 21,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '13157',
#                       'lastCommunicationTime': '2019-03-29 18:53:50',
#                       'latitude': 41.87772613,
#                       'location': '1103 W.Jackson Blvd',
#                       'longitude': -87.65478743,
#                       'postalCode': '60607',
#                       'stAddress1': 'Aberdeen St & Jackson Blvd',
#                       'stAddress2': '',
#                       'stationName': 'Aberdeen St & Jackson Blvd',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 23},
#                      {'altitude': '',
#                       'availableBikes': 4,
#                       'availableDocks': 11,
#                       'city': 'Chicago',
#                       'id': 22,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '13160',
#                       'lastCommunicationTime': '2019-03-29 18:54:24',
#                       'latitude': 41.8694821,
#                       'location': '1134 W. Taylor St',
#                       'longitude': -87.6554864,
#                       'postalCode': '60607',
#                       'stAddress1': 'May St & Taylor St',
#                       'stAddress2': '',
#                       'stationName': 'May St & Taylor St',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 15},
#                      {'altitude': '',
#                       'availableBikes': 6,
#                       'availableDocks': 10,
#                       'city': 'Chicago',
#                       'id': 23,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '13172',
#                       'lastCommunicationTime': '2019-03-29 18:53:13',
#                       'latitude': 41.902924,
#                       'location': '350 W. Elm st',
#                       'longitude': -87.637715,
#                       'postalCode': '60610',
#                       'stAddress1': 'Orleans St & Elm St (*)',
#                       'stAddress2': '',
#                       'stationName': 'Orleans St & Elm St (*)',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 16},
#                      {'altitude': '',
#                       'availableBikes': 10,
#                       'availableDocks': 5,
#                       'city': 'Chicago',
#                       'id': 24,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '13262',
#                       'lastCommunicationTime': '2019-03-29 18:51:52',
#                       'latitude': 41.89186,
#                       'location': '240 E.Grand Ave.',
#                       'longitude': -87.62062,
#                       'postalCode': '60611',
#                       'stAddress1': 'Fairbanks Ct & Grand Ave',
#                       'stAddress2': '',
#                       'stationName': 'Fairbanks Ct & Grand Ave',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 15},
#                      {'altitude': '',
#                       'availableBikes': 18,
#                       'availableDocks': 5,
#                       'city': 'Chicago',
#                       'id': 25,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '13034',
#                       'lastCommunicationTime': '2019-03-29 18:50:32',
#                       'latitude': 41.89766,
#                       'location': '150 E.Pearson st',
#                       'longitude': -87.62351,
#                       'postalCode': '60611',
#                       'stAddress1': 'Michigan Ave & Pearson St',
#                       'stAddress2': '',
#                       'stationName': 'Michigan Ave & Pearson St',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 23},
#                      {'altitude': '',
#                       'availableBikes': 31,
#                       'availableDocks': 0,
#                       'city': 'Chicago',
#                       'id': 26,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '13051',
#                       'lastCommunicationTime': '2019-03-29 18:52:31',
#                       'latitude': 41.890359,
#                       'location': '',
#                       'longitude': -87.617532,
#                       'postalCode': '60611',
#                       'stAddress1': 'McClurg Ct & Illinois St',
#                       'stAddress2': '',
#                       'stationName': 'McClurg Ct & Illinois St',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 31},
#                      {'altitude': '',
#                       'availableBikes': 6,
#                       'availableDocks': 13,
#                       'city': 'Chicago',
#                       'id': 27,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '13174',
#                       'lastCommunicationTime': '2019-03-29 18:50:25',
#                       'latitude': 41.91021,
#                       'location': '1530 N.Larrabee st',
#                       'longitude': -87.6435,
#                       'postalCode': '60610',
#                       'stAddress1': 'Larrabee St & North Ave',
#                       'stAddress2': '',
#                       'stationName': 'Larrabee St & North Ave',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 19},
#                      {'altitude': '',
#                       'availableBikes': 6,
#                       'availableDocks': 9,
#                       'city': 'Chicago',
#                       'id': 28,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '13282',
#                       'lastCommunicationTime': '2019-03-29 18:52:00',
#                       'latitude': 41.91468,
#                       'location': '590 W. Menomonee',
#                       'longitude': -87.64332,
#                       'postalCode': '60614',
#                       'stAddress1': 'Larrabee St & Menomonee St',
#                       'stAddress2': '',
#                       'stationName': 'Larrabee St & Menomonee St',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 15},
#                      {'altitude': '',
#                       'availableBikes': 2,
#                       'availableDocks': 13,
#                       'city': 'Chicago',
#                       'id': 29,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '13290',
#                       'lastCommunicationTime': '2019-03-29 18:50:40',
#                       'latitude': 41.90068,
#                       'location': '1016 N. Noble St',
#                       'longitude': -87.6626,
#                       'postalCode': '60642',
#                       'stAddress1': 'Noble St & Milwaukee Ave',
#                       'stAddress2': '',
#                       'stationName': 'Noble St & Milwaukee Ave',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 15},
#                      {'altitude': '',
#                       'availableBikes': 11,
#                       'availableDocks': 4,
#                       'city': 'Chicago',
#                       'id': 30,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '13248',
#                       'lastCommunicationTime': '2019-03-29 18:50:49',
#                       'latitude': 41.899643,
#                       'location': '1611 W. Augusta Blvd',
#                       'longitude': -87.6677,
#                       'postalCode': '60642',
#                       'stAddress1': 'Ashland Ave & Augusta Blvd',
#                       'stAddress2': '',
#                       'stationName': 'Ashland Ave & Augusta Blvd',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 15},
#                      {'altitude': '',
#                       'availableBikes': 3,
#                       'availableDocks': 20,
#                       'city': 'Chicago',
#                       'id': 31,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '13017',
#                       'lastCommunicationTime': '2019-03-29 18:52:03',
#                       'latitude': 41.896776,
#                       'location': '805 N. Franklin St',
#                       'longitude': -87.635633,
#                       'postalCode': '60654',
#                       'stAddress1': 'Franklin St & Chicago Ave',
#                       'stAddress2': '',
#                       'stationName': 'Franklin St & Chicago Ave',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 23},
#                      {'altitude': '',
#                       'availableBikes': 4,
#                       'availableDocks': 15,
#                       'city': 'Chicago',
#                       'id': 32,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '13076',
#                       'lastCommunicationTime': '2019-03-29 18:51:19',
#                       'latitude': 41.87464,
#                       'location': '550 S. Racine',
#                       'longitude': -87.65703,
#                       'postalCode': '60607',
#                       'stAddress1': 'Racine Ave & Congress Pkwy',
#                       'stAddress2': '',
#                       'stationName': 'Racine Ave & Congress Pkwy',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 19},
#                      {'altitude': '',
#                       'availableBikes': 0,
#                       'availableDocks': 27,
#                       'city': 'Chicago',
#                       'id': 33,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '13003',
#                       'lastCommunicationTime': '2019-03-29 18:53:48',
#                       'latitude': 41.877181,
#                       'location': '360 S State St',
#                       'longitude': -87.627844,
#                       'postalCode': '60604',
#                       'stAddress1': 'State St & Van Buren St',
#                       'stAddress2': '',
#                       'stationName': 'State St & Van Buren St',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 27},
#                      {'altitude': '',
#                       'availableBikes': 7,
#                       'availableDocks': 7,
#                       'city': 'Chicago',
#                       'id': 34,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '13124',
#                       'lastCommunicationTime': '2019-03-29 18:53:22',
#                       'latitude': 41.9267559875,
#                       'location': '2432 N. Cannon Dr.',
#                       'longitude': -87.6344287848,
#                       'postalCode': '60614',
#                       'stAddress1': 'Cannon Dr & Fullerton Ave',
#                       'stAddress2': '',
#                       'stationName': 'Cannon Dr & Fullerton Ave',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 15},
#                      {'altitude': '',
#                       'availableBikes': 9,
#                       'availableDocks': 38,
#                       'city': 'Chicago',
#                       'id': 35,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '13022',
#                       'lastCommunicationTime': '2019-03-29 18:54:26',
#                       'latitude': 41.892278,
#                       'location': 'Navy Pier',
#                       'longitude': -87.612043,
#                       'postalCode': '60611',
#                       'stAddress1': 'Streeter Dr & Grand Ave',
#                       'stAddress2': '',
#                       'stationName': 'Streeter Dr & Grand Ave',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 47},
#                      {'altitude': '',
#                       'availableBikes': 5,
#                       'availableDocks': 33,
#                       'city': 'Chicago',
#                       'id': 36,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '13019',
#                       'lastCommunicationTime': '2019-03-29 18:52:12',
#                       'latitude': 41.8777079559,
#                       'location': '340 S. Franklin St',
#                       'longitude': -87.6353211408,
#                       'postalCode': '60606',
#                       'stAddress1': 'Franklin St & Jackson Blvd',
#                       'stAddress2': '',
#                       'stationName': 'Franklin St & Jackson Blvd',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 39},
#                      {'altitude': '',
#                       'availableBikes': 1,
#                       'availableDocks': 18,
#                       'city': 'Chicago',
#                       'id': 37,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '13020',
#                       'lastCommunicationTime': '2019-03-29 18:52:48',
#                       'latitude': 41.8793563587,
#                       'location': '59 W. Adams St ',
#                       'longitude': -87.6297910363,
#                       'postalCode': '60603',
#                       'stAddress1': 'Dearborn St & Adams St',
#                       'stAddress2': '',
#                       'stationName': 'Dearborn St & Adams St',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 19},
#                      {'altitude': '',
#                       'availableBikes': 9,
#                       'availableDocks': 18,
#                       'city': 'Chicago',
#                       'id': 38,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '15547',
#                       'lastCommunicationTime': '2019-03-29 18:52:09',
#                       'latitude': 41.88602082773,
#                       'location': '',
#                       'longitude': -87.6308760584,
#                       'postalCode': '60601',
#                       'stAddress1': 'Clark St & Lake St',
#                       'stAddress2': '',
#                       'stationName': 'Clark St & Lake St',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 27},
#                      {'altitude': '',
#                       'availableBikes': 11,
#                       'availableDocks': 12,
#                       'city': 'Chicago',
#                       'id': 39,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '15538',
#                       'lastCommunicationTime': '2019-03-29 18:51:10',
#                       'latitude': 41.87947235235,
#                       'location': '',
#                       'longitude': -87.6256886059,
#                       'postalCode': '60603',
#                       'stAddress1': 'Wabash Ave & Adams St',
#                       'stAddress2': '',
#                       'stationName': 'Wabash Ave & Adams St',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 23},
#                      {'altitude': '',
#                       'availableBikes': 1,
#                       'availableDocks': 13,
#                       'city': 'Chicago',
#                       'id': 40,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '15537',
#                       'lastCommunicationTime': '2019-03-29 18:50:43',
#                       'latitude': 41.87934437346,
#                       'location': '',
#                       'longitude': -87.6319852213,
#                       'postalCode': '60603',
#                       'stAddress1': 'LaSalle St & Adams St',
#                       'stAddress2': '',
#                       'stationName': 'LaSalle St & Adams St',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 15},
#                      {'altitude': '',
#                       'availableBikes': 12,
#                       'availableDocks': 6,
#                       'city': 'Chicago',
#                       'id': 41,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '15543',
#                       'lastCommunicationTime': '2019-03-29 18:50:13',
#                       'latitude': 41.87207763285,
#                       'location': '',
#                       'longitude': -87.6295437729,
#                       'postalCode': '60605',
#                       'stAddress1': 'Federal St & Polk St',
#                       'stAddress2': '',
#                       'stationName': 'Federal St & Polk St',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 19},
#                      {'altitude': '',
#                       'availableBikes': 9,
#                       'availableDocks': 2,
#                       'city': 'Chicago',
#                       'id': 42,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '13170',
#                       'lastCommunicationTime': '2019-03-29 18:53:30',
#                       'latitude': 41.852619,
#                       'location': '13 E Cermak Rd',
#                       'longitude': -87.626488,
#                       'postalCode': '60616',
#                       'stAddress1': 'Wabash Ave & Cermak Rd',
#                       'stAddress2': 'CTA Green Line - Cermak Stop',
#                       'stationName': 'Wabash Ave & Cermak Rd',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 11},
#                      {'altitude': '',
#                       'availableBikes': 10,
#                       'availableDocks': 33,
#                       'city': 'Chicago',
#                       'id': 43,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '13001',
#                       'lastCommunicationTime': '2019-03-29 18:54:13',
#                       'latitude': 41.8838927658,
#                       'location': '120 N Michigan',
#                       'longitude': -87.6246491409,
#                       'postalCode': '60602',
#                       'stAddress1': 'Michigan Ave & Washington St',
#                       'stAddress2': '',
#                       'stationName': 'Michigan Ave & Washington St',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 43},
#                      {'altitude': '',
#                       'availableBikes': 17,
#                       'availableDocks': 10,
#                       'city': 'Chicago',
#                       'id': 44,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '13002',
#                       'lastCommunicationTime': '2019-03-29 18:52:02',
#                       'latitude': 41.8847302006,
#                       'location': '',
#                       'longitude': -87.6277335692,
#                       'postalCode': '60601',
#                       'stAddress1': 'State St & Randolph St',
#                       'stAddress2': '',
#                       'stationName': 'State St & Randolph St',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 27},
#                      {'altitude': '',
#                       'availableBikes': 0,
#                       'availableDocks': 15,
#                       'city': 'Chicago',
#                       'id': 45,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '13040',
#                       'lastCommunicationTime': '2019-03-29 18:54:18',
#                       'latitude': 41.876243,
#                       'location': '420 w. Michigan',
#                       'longitude': -87.624426,
#                       'postalCode': '60605',
#                       'stAddress1': 'Michigan Ave & Ida B Wells Dr',
#                       'stAddress2': '',
#                       'stationName': 'Michigan Ave & Ida B Wells Dr',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 15},
#                      {'altitude': '',
#                       'availableBikes': 15,
#                       'availableDocks': 4,
#                       'city': 'Chicago',
#                       'id': 46,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '13046',
#                       'lastCommunicationTime': '2019-03-29 18:53:14',
#                       'latitude': 41.89993001,
#                       'location': '932 N Wells St',
#                       'longitude': -87.63443007,
#                       'postalCode': '60610',
#                       'stAddress1': 'Wells St & Walton St',
#                       'stAddress2': '',
#                       'stationName': 'Wells St & Walton St',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 19},
#                      {'altitude': '',
#                       'availableBikes': 5,
#                       'availableDocks': 26,
#                       'city': 'Chicago',
#                       'id': 47,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '13050',
#                       'lastCommunicationTime': '2019-03-29 18:52:49',
#                       'latitude': 41.889187,
#                       'location': '5 E Kinzie St',
#                       'longitude': -87.627754,
#                       'postalCode': '60654',
#                       'stAddress1': 'State St & Kinzie St',
#                       'stAddress2': '',
#                       'stationName': 'State St & Kinzie St',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 31},
#                      {'altitude': '',
#                       'availableBikes': 5,
#                       'availableDocks': 38,
#                       'city': 'Chicago',
#                       'id': 48,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '13012',
#                       'lastCommunicationTime': '2019-03-29 18:54:17',
#                       'latitude': 41.897764,
#                       'location': '840 N Larrabee St',
#                       'longitude': -87.642884,
#                       'postalCode': '60610',
#                       'stAddress1': 'Larrabee St & Kingsbury St',
#                       'stAddress2': '',
#                       'stationName': 'Larrabee St & Kingsbury St',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 43},
#                      {'altitude': '',
#                       'availableBikes': 19,
#                       'availableDocks': 18,
#                       'city': 'Chicago',
#                       'id': 49,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '13049',
#                       'lastCommunicationTime': '2019-03-29 18:52:53',
#                       'latitude': 41.881319815,
#                       'location': '80 S Dearborn St',
#                       'longitude': -87.6295209193,
#                       'postalCode': '60603',
#                       'stAddress1': 'Dearborn St & Monroe St',
#                       'stAddress2': '',
#                       'stationName': 'Dearborn St & Monroe St',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 39},
#                      {'altitude': '',
#                       'availableBikes': 11,
#                       'availableDocks': 24,
#                       'city': 'Chicago',
#                       'id': 50,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '13009',
#                       'lastCommunicationTime': '2019-03-29 18:54:20',
#                       'latitude': 41.8759326655,
#                       'location': '',
#                       'longitude': -87.6305845355,
#                       'postalCode': '60605',
#                       'stAddress1': 'Clark St & Ida B Wells Dr',
#                       'stAddress2': '',
#                       'stationName': 'Clark St & Ida B Wells Dr',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 35},
#                      {'altitude': '',
#                       'availableBikes': 14,
#                       'availableDocks': 25,
#                       'city': 'Chicago',
#                       'id': 51,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '13005',
#                       'lastCommunicationTime': '2019-03-29 18:52:42',
#                       'latitude': 41.884576228,
#                       'location': '120 W. Randolph St.',
#                       'longitude': -87.63188991,
#                       'postalCode': '60601',
#                       'stAddress1': 'Clark St & Randolph St',
#                       'stAddress2': '',
#                       'stationName': 'Clark St & Randolph St',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 39},
#                      {'altitude': '',
#                       'availableBikes': 2,
#                       'availableDocks': 33,
#                       'city': 'Chicago',
#                       'id': 52,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '13043',
#                       'lastCommunicationTime': '2019-03-29 18:51:24',
#                       'latitude': 41.886024,
#                       'location': '203 N Michigan Ave',
#                       'longitude': -87.624117,
#                       'postalCode': '60601',
#                       'stAddress1': 'Michigan Ave & Lake St',
#                       'stAddress2': '',
#                       'stationName': 'Michigan Ave & Lake St',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 35},
#                      {'altitude': '',
#                       'availableBikes': 14,
#                       'availableDocks': 12,
#                       'city': 'Chicago',
#                       'id': 53,
#                       'is_renting': True,
# ...
#                       'location': '',
#                       'longitude': -87.634774,
#                       'postalCode': '60621',
#                       'stAddress1': 'Stewart Ave & 63rd St (*)',
#                       'stAddress2': '',
#                       'stationName': 'Stewart Ave & 63rd St (*)',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 12},
#                      {'altitude': '',
#                       'availableBikes': 4,
#                       'availableDocks': 8,
#                       'city': 'Chicago',
#                       'id': 650,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '18027',
#                       'lastCommunicationTime': '2019-03-29 18:52:27',
#                       'latitude': 41.768898,
#                       'location': '',
#                       'longitude': -87.635876,
#                       'postalCode': '60621',
#                       'stAddress1': 'Eggleston Ave & 69th St (*)',
#                       'stAddress2': '',
#                       'stationName': 'Eggleston Ave & 69th St (*)',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 12},
#                      {'altitude': '',
#                       'availableBikes': 3,
#                       'availableDocks': 4,
#                       'city': 'Chicago',
#                       'id': 651,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '18028',
#                       'lastCommunicationTime': '2019-03-29 18:50:52',
#                       'latitude': 41.765286,
#                       'location': '',
#                       'longitude': -87.621748,
#                       'postalCode': '60619',
#                       'stAddress1': 'Michigan Ave & 71st St',
#                       'stAddress2': '',
#                       'stationName': 'Michigan Ave & 71st St',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 7},
#                      {'altitude': '',
#                       'availableBikes': 3,
#                       'availableDocks': 8,
#                       'city': 'Chicago',
#                       'id': 652,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '18029',
#                       'lastCommunicationTime': '2019-03-29 18:53:43',
#                       'latitude': 41.766,
#                       'location': '',
#                       'longitude': -87.611726,
#                       'postalCode': '60637',
#                       'stAddress1': 'Rhodes Ave & 71st St',
#                       'stAddress2': '',
#                       'stationName': 'Rhodes Ave & 71st St',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 11},
#                      {'altitude': '',
#                       'availableBikes': 4,
#                       'availableDocks': 6,
#                       'city': 'Chicago',
#                       'id': 653,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '18030',
#                       'lastCommunicationTime': '2019-03-29 18:52:30',
#                       'latitude': 41.780595,
#                       'location': '',
#                       'longitude': -87.584846,
#                       'postalCode': '60649',
#                       'stAddress1': 'Cornell Dr & Hayes Dr',
#                       'stAddress2': '',
#                       'stationName': 'Cornell Dr & Hayes Dr',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 11},
#                      {'altitude': '',
#                       'availableBikes': 9,
#                       'availableDocks': 3,
#                       'city': 'Chicago',
#                       'id': 654,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '18046',
#                       'lastCommunicationTime': '2019-03-29 18:51:34',
#                       'latitude': 41.883073,
#                       'location': '',
#                       'longitude': -87.656952,
#                       'postalCode': '60607',
#                       'stAddress1': 'Racine Ave & Washington Blvd (*)',
#                       'stAddress2': '',
#                       'stationName': 'Racine Ave & Washington Blvd (*)',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 12},
#                      {'altitude': '',
#                       'availableBikes': 4,
#                       'availableDocks': 11,
#                       'city': 'Chicago',
#                       'id': 655,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '18047',
#                       'lastCommunicationTime': '2019-03-29 18:52:54',
#                       'latitude': 41.979851,
#                       'location': '',
#                       'longitude': -87.681932,
#                       'postalCode': '60625',
#                       'stAddress1': 'Hoyne Ave & Balmoral Ave',
#                       'stAddress2': '',
#                       'stationName': 'Hoyne Ave & Balmoral Ave',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 15},
#                      {'altitude': '',
#                       'availableBikes': 1,
#                       'availableDocks': 15,
#                       'city': 'Chicago',
#                       'id': 656,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '18054',
#                       'lastCommunicationTime': '2019-03-29 18:50:19',
#                       'latitude': 41.885951,
#                       'location': '',
#                       'longitude': -87.677009,
#                       'postalCode': '60612',
#                       'stAddress1': 'Damen Ave & Walnut (Lake) St (*)',
#                       'stAddress2': '',
#                       'stationName': 'Damen Ave & Walnut (Lake) St (*)',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 16},
#                      {'altitude': '',
#                       'availableBikes': 6,
#                       'availableDocks': 9,
#                       'city': 'Chicago',
#                       'id': 657,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '18056',
#                       'lastCommunicationTime': '2019-03-29 18:51:38',
#                       'latitude': 41.899181,
#                       'location': '',
#                       'longitude': -87.6722,
#                       'postalCode': '60622',
#                       'stAddress1': 'Wood St & Augusta Blvd',
#                       'stAddress2': '',
#                       'stationName': 'Wood St & Augusta Blvd',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 15},
#                      {'altitude': '',
#                       'availableBikes': 11,
#                       'availableDocks': 5,
#                       'city': 'Chicago',
#                       'id': 658,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '18057',
#                       'lastCommunicationTime': '2019-03-29 18:51:35',
#                       'latitude': 41.902997,
#                       'location': '',
#                       'longitude': -87.683825,
#                       'postalCode': '60622',
#                       'stAddress1': 'Leavitt St & Division St (*)',
#                       'stAddress2': '',
#                       'stationName': 'Leavitt St & Division St (*)',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 16},
#                      {'altitude': '',
#                       'availableBikes': 8,
#                       'availableDocks': 7,
#                       'city': 'Chicago',
#                       'id': 659,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '18058',
#                       'lastCommunicationTime': '2019-03-29 18:50:05',
#                       'latitude': 41.895501,
#                       'location': '',
#                       'longitude': -87.682017,
#                       'postalCode': '60612',
#                       'stAddress1': 'Leavitt St & Chicago Ave',
#                       'stAddress2': '',
#                       'stationName': 'Leavitt St & Chicago Ave',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 15},
#                      {'altitude': '',
#                       'availableBikes': 12,
#                       'availableDocks': 3,
#                       'city': 'Chicago',
#                       'id': 660,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '18066',
#                       'lastCommunicationTime': '2019-03-29 18:54:06',
#                       'latitude': 42.004583,
#                       'location': '',
#                       'longitude': -87.661406,
#                       'postalCode': '60626',
#                       'stAddress1': 'Sheridan Rd & Columbia Ave',
#                       'stAddress2': '',
#                       'stationName': 'Sheridan Rd & Columbia Ave',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 15},
#                      {'altitude': '',
#                       'availableBikes': 6,
#                       'availableDocks': 9,
#                       'city': 'Evanston',
#                       'id': 661,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': 'E012',
#                       'lastCommunicationTime': '2019-03-29 18:51:00',
#                       'latitude': 42.057044,
#                       'location': '',
#                       'longitude': -87.686554,
#                       'postalCode': '60201',
#                       'stAddress1': 'Evanston Civic Center',
#                       'stAddress2': '',
#                       'stationName': 'Evanston Civic Center',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 15},
#                      {'altitude': '',
#                       'availableBikes': 5,
#                       'availableDocks': 10,
#                       'city': 'Evanston',
#                       'id': 662,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': 'E013',
#                       'lastCommunicationTime': '2019-03-29 18:50:14',
#                       'latitude': 42.023463,
#                       'location': '',
#                       'longitude': -87.699595,
#                       'postalCode': '60201',
#                       'stAddress1': 'Dodge Ave & Mulford St',
#                       'stAddress2': '',
#                       'stationName': 'Dodge Ave & Mulford St',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 15},
#                      {'altitude': '',
#                       'availableBikes': 11,
#                       'availableDocks': 4,
#                       'city': 'Evanston',
#                       'id': 663,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': 'E014',
#                       'lastCommunicationTime': '2019-03-29 18:50:46',
#                       'latitude': 42.064854,
#                       'location': '',
#                       'longitude': -87.715297,
#                       'postalCode': '60201',
#                       'stAddress1': 'Lincolnwood Dr & Central St',
#                       'stAddress2': '',
#                       'stationName': 'Lincolnwood Dr & Central St',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 15},
#                      {'altitude': '',
#                       'availableBikes': 11,
#                       'availableDocks': 5,
#                       'city': 'Chicago',
#                       'id': 664,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '18068',
#                       'lastCommunicationTime': '2019-03-29 18:51:22',
#                       'latitude': 41.939354,
#                       'location': '',
#                       'longitude': -87.683282,
#                       'postalCode': '60618',
#                       'stAddress1': 'Leavitt St & Belmont Ave (*)',
#                       'stAddress2': '',
#                       'stationName': 'Leavitt St & Belmont Ave (*)',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 16},
#                      {'altitude': '',
#                       'availableBikes': 3,
#                       'availableDocks': 4,
#                       'city': 'Chicago',
#                       'id': 665,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '19031',
#                       'lastCommunicationTime': '2019-03-29 18:50:34',
#                       'latitude': 41.747363,
#                       'location': '',
#                       'longitude': -87.580046,
#                       'postalCode': '60617',
#                       'stAddress1': 'South Chicago Ave & Elliot Ave',
#                       'stAddress2': '',
#                       'stationName': 'South Chicago Ave & Elliot Ave',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 7}]}

# %%
# load data file into a dataframe
df__stations = pd.DataFrame(stations_json['stationBeanList'])

# %% [markdown]
# **Data preparation and cleaning**
# - We need to do some Data preparation and cleaning work
# - Notice the alltitude is BLANK below
# - And sometimes we have BLANK zip code

# %%
df__stations.tail()
# Out:
#     altitude  availableBikes  availableDocks      city   id  is_renting  \
# 603                        6               9  Evanston  661        True
# 604                        5              10  Evanston  662        True
# 605                       11               4  Evanston  663        True
# 606                       11               5   Chicago  664        True
# 607                        3               4   Chicago  665        True
#
#     kioskType landMark lastCommunicationTime   latitude     ...      \
# 603   K3_FULL     E012   2019-03-29 18:51:00  42.057044     ...
# 604   K3_FULL     E013   2019-03-29 18:50:14  42.023463     ...
# 605   K3_FULL     E014   2019-03-29 18:50:46  42.064854     ...
# 606   K3_FULL    18068   2019-03-29 18:51:22  41.939354     ...
# 607   K3_FULL    19031   2019-03-29 18:50:34  41.747363     ...
#
#      longitude  postalCode                      stAddress1 stAddress2  \
# 603 -87.686554       60201           Evanston Civic Center
# 604 -87.699595       60201          Dodge Ave & Mulford St
# 605 -87.715297       60201     Lincolnwood Dr & Central St
# 606 -87.683282       60618    Leavitt St & Belmont Ave (*)
# 607 -87.580046       60617  South Chicago Ave & Elliot Ave
#
#                         stationName      status statusKey  statusValue  \
# 603           Evanston Civic Center  IN_SERVICE         1   In Service
# 604          Dodge Ave & Mulford St  IN_SERVICE         1   In Service
# 605     Lincolnwood Dr & Central St  IN_SERVICE         1   In Service
# 606    Leavitt St & Belmont Ave (*)  IN_SERVICE         1   In Service
# 607  South Chicago Ave & Elliot Ave  IN_SERVICE         1   In Service
#
#     testStation  totalDocks
# 603       False          15
# 604       False          15
# 605       False          15
# 606       False          16
# 607       False           7
#
# [5 rows x 21 columns]

# %%
# Clean the BLANKs from the data

df__stations['altitude'] = df__stations['altitude'].apply(lambda x: 0 if x == '' else x)
df__stations['postalCode'] = df__stations['postalCode'].apply(lambda x: 0 if x == '' else x)

# %% [markdown]
# ## Note:
# - There is a bug in the divvy data feed ...
# - Sometimes they add an extra space to the city name
# - See the following two records from divvy feed; compare the city names
#
#
# ['0', '14', '13', **'Chicago'**, '111', 'True', 'K3_FULL', '13052', '2018-12-26 19:20:34', '41.894666', '', '-87.638437', '60654', 'Sedgwick St & Huron St', '', 'Sedgwick St & Huron St', 'IN_SERVICE', '1', 'In Service', 'False', '27']
#
# ['0', '7', '8', **'Chicago '**, '112', 'True', 'K3_FULL', '13053', '2018-12-26 19:20:49', '41.883668', '', '-87.64867', '60607', 'Green St & Randolph St', '', 'Green St & Randolph St', 'IN_SERVICE', '1', 'In Service', 'False', '15']

# %%
df__stations.city.value_counts()
# Out:
# Chicago     553
# Chicago      41
# Evanston     14
# Name: city, dtype: int64

# %%
#Remove the whitespace from the end of hte city name

df__stations['city'] = df__stations['city'].apply(lambda x: 'Chicago' if x == 'Chicago ' else x)

# %%
#Sanity Test
df__stations.city.value_counts()
# Out:
# Chicago     594
# Evanston     14
# Name: city, dtype: int64

# %%
df__stations.head()
# Out:
#    altitude  availableBikes  availableDocks     city  id  is_renting  \
# 0         0               9              29  Chicago   2        True
# 1         0               1              54  Chicago   3        True
# 2         0               3              19  Chicago   4        True
# 3         0               6              17  Chicago   5        True
# 4         0               4              35  Chicago   6        True
#
#   kioskType landMark lastCommunicationTime   latitude     ...      longitude  \
# 0   K3_FULL    15541   2019-03-29 18:50:37  41.876470     ...     -87.620340
# 1   K3_FULL    15544   2019-03-29 18:52:18  41.867226     ...     -87.615355
# 2   K3_FULL    15545   2019-03-29 18:52:24  41.856268     ...     -87.613348
# 3   K3_FULL    13030   2019-03-29 18:52:38  41.874053     ...     -87.627716
# 4   K3_FULL    15548   2019-03-29 18:54:19  41.886976     ...     -87.612813
#
#    postalCode              stAddress1 stAddress2             stationName  \
# 0       60605     Buckingham Fountain                Buckingham Fountain
# 1           0          Shedd Aquarium                     Shedd Aquarium
# 2           0          Burnham Harbor                     Burnham Harbor
# 3       60605  State St & Harrison St             State St & Harrison St
# 4       60601          Dusable Harbor                     Dusable Harbor
#
#        status statusKey  statusValue testStation  totalDocks
# 0  IN_SERVICE         1   In Service       False          38
# 1  IN_SERVICE         1   In Service       False          55
# 2  IN_SERVICE         1   In Service       False          23
# 3  IN_SERVICE         1   In Service       False          23
# 4  IN_SERVICE         1   In Service       False          39
#
# [5 rows x 21 columns]

# %%
db_connection = psycopg2.connect(host='127.0.0.1',dbname="postgres", user="postgres" , password="root")


db_connection.set_isolation_level(ISOLATION_LEVEL_AUTOCOMMIT) 

cursor = db_connection.cursor()

# comment the following line if you already created the database 
# Only once you need to create the database

cursor.execute("CREATE DATABASE chicago_divvy_stations;")

# %%
db_connection = psycopg2.connect(host='127.0.0.1',dbname="chicago_divvy_stations", user="postgres" , password="root")


cursor = db_connection.cursor()

# %%
# Only once you need to create the postgis extension.
# Comment the following line if you already created the postgis extension

cursor.execute("CREATE EXTENSION postgis;")

# %%
db_connection.commit()

# %%
cursor.execute("DROP TABLE IF EXISTS divvy_stations")

# %%
db_connection.commit()

# %%
# Comment the following line if you already created the PROCEDURE
cursor.execute("""CREATE OR REPLACE FUNCTION notify_event() RETURNS TRIGGER AS $$
  DECLARE
    record RECORD;
    payload JSON;
  BEGIN
    IF (TG_OP = 'DELETE') THEN
      record = OLD;
    ELSE
      record = NEW;
    END IF;
    payload = json_build_object('data', row_to_json(record));

    PERFORM pg_notify('events', payload::text);

    RETURN NULL;
  END;
$$ LANGUAGE plpgsql;""")

# %%
db_connection.commit()

# %%
cursor.execute("""CREATE TABLE divvy_stations_status(
                altitude FLOAT,
                availableBikes INTEGER,
                availableDocks INTEGER,
                city TEXT,
                id INTEGER,
                is_renting BOOLEAN,
                kioskType TEXT,
                landMark TEXT,
                lastCommunicationTime timestamp,
                latitude FLOAT,
                location TEXT,
                longitude FLOAT,
                postalCode INTEGER,
                stAddress1 TEXT,
                stAddress2 TEXT,
                stationName TEXT,
                status TEXT,
                statusKey INTEGER,
                statusValue TEXT,
                testStation BOOLEAN,
                totalDocks INTEGER,
                Where_IS GEOGRAPHY);""")

# %%
cursor.execute("""CREATE TABLE divvy_stations_logs(
                altitude FLOAT,
                availableBikes INTEGER,
                availableDocks INTEGER,
                city TEXT,
                id INTEGER,
                is_renting BOOLEAN,
                kioskType TEXT,
                landMark TEXT,
                lastCommunicationTime timestamp,
                latitude FLOAT,
                location TEXT,
                longitude FLOAT,
                postalCode INTEGER,
                stAddress1 TEXT,
                stAddress2 TEXT,
                stationName TEXT,
                status TEXT,
                statusKey INTEGER,
                statusValue TEXT,
                testStation BOOLEAN,
                totalDocks INTEGER,
                Where_IS GEOGRAPHY);""")

# %%
db_connection.commit()

# %%
# Comment the following line if you already created the TRIGGER
cursor.execute("""CREATE TRIGGER divvy_update
AFTER INSERT ON divvy_stations_logs
  FOR EACH ROW EXECUTE PROCEDURE notify_event();""")

# %%
df__stations.dtypes
# Out:
# altitude                   int64
# availableBikes             int64
# availableDocks             int64
# city                      object
# id                         int64
# is_renting                  bool
# kioskType                 object
# landMark                  object
# lastCommunicationTime     object
# latitude                 float64
# location                  object
# longitude                float64
# postalCode                object
# stAddress1                object
# stAddress2                object
# stationName               object
# status                    object
# statusKey                  int64
# statusValue               object
# testStation                 bool
# totalDocks                 int64
# dtype: object

# %%
# lets store our data subset into a file
# This way you have a copy of data stored in a file 
# that you could use in case you want to debug a problem on the orginal data received

df__stations.to_csv('divvy_stations_status.csv',sep=',', encoding='utf-8', index=False)
df__stations.to_csv('divvy_stations_logs.csv',sep=',', encoding='utf-8', index=False)

# %%
# Now we will connect to the database and store divvy data


with open('divvy_stations_status.csv', 'r') as f:
    reader = csv.reader(f)
    next(reader)  # Skip the header row.
    for row in reader:
        print(row)
        cursor.execute(
                "INSERT INTO divvy_stations_status VALUES (%s, %s, %s, %s, %s,    %s, %s, %s, %s,%s,   %s, %s, %s, %s,%s,   %s, %s, %s, %s,%s,  %s, NULL)",
                row)
# Out:
# ['0', '9', '29', 'Chicago', '2', 'True', 'K3_FULL', '15541', '2019-03-29 18:50:37', '41.87647', '', '-87.62034', '60605', 'Buckingham Fountain', '', 'Buckingham Fountain', 'IN_SERVICE', '1', 'In Service', 'False', '38']
# ['0', '1', '54', 'Chicago', '3', 'True', 'K3_FULL', '15544', '2019-03-29 18:52:18', '41.86722595682', '', '-87.6153553902', '0', 'Shedd Aquarium', '', 'Shedd Aquarium', 'IN_SERVICE', '1', 'In Service', 'False', '55']
# ['0', '3', '19', 'Chicago', '4', 'True', 'K3_FULL', '15545', '2019-03-29 18:52:24', '41.856268', '', '-87.613348', '0', 'Burnham Harbor', '', 'Burnham Harbor', 'IN_SERVICE', '1', 'In Service', 'False', '23']
# ['0', '6', '17', 'Chicago', '5', 'True', 'K3_FULL', '13030', '2019-03-29 18:52:38', '41.874053', '620 S. State St.', '-87.627716', '60605', 'State St & Harrison St', '', 'State St & Harrison St', 'IN_SERVICE', '1', 'In Service', 'False', '23']
# ['0', '4', '35', 'Chicago', '6', 'True', 'K3_FULL', '15548', '2019-03-29 18:54:19', '41.886976', '', '-87.612813', '60601', 'Dusable Harbor', '', 'Dusable Harbor', 'IN_SERVICE', '1', 'In Service', 'False', '39']
# ['0', '7', '12', 'Chicago', '7', 'True', 'K3_FULL', '15534', '2019-03-29 18:51:08', '41.88634906269', '', '-87.6175165471', '60601', 'Field Blvd & South Water St', '', 'Field Blvd & South Water St', 'IN_SERVICE', '1', 'In Service', 'False', '19']
# ['0', '2', '13', 'Chicago', '9', 'True', 'K3_FULL', '15695', '2019-03-29 18:54:22', '41.82879201994', 'NA1', '-87.6806044594', '60609', 'Leavitt St & Archer Ave', '', 'Leavitt St & Archer Ave', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '1', '10', 'Chicago', '11', 'True', 'K3_FULL', '15496', '2019-03-29 18:52:09', '41.76663823695', '', '-87.5764501141', '60649', 'Jeffery Blvd & 71st St', '', 'Jeffery Blvd & 71st St', 'IN_SERVICE', '1', 'In Service', 'False', '11']
# ['0', '3', '12', 'Chicago', '12', 'True', 'K3_FULL', '15497', '2019-03-29 18:51:47', '41.7664094567', 'MLSW', '-87.5656875719', '60649', 'South Shore Dr & 71st St', '', 'South Shore Dr & 71st St', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '11', '24', 'Chicago', '13', 'True', 'K3_FULL', '13066', '2019-03-29 18:52:16', '41.932418', '2790 N.Wilton Ave', '-87.652705', '60614', 'Wilton Ave & Diversey Pkwy', '', 'Wilton Ave & Diversey Pkwy', 'IN_SERVICE', '1', 'In Service', 'False', '35']
# ['0', '6', '9', 'Chicago', '14', 'True', 'K3_FULL', '13163', '2019-03-29 18:53:48', '41.858086', '962 W. 18th St', '-87.651073', '60608', 'Morgan St & 18th St', '', 'Morgan St & 18th St', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '6', '9', 'Chicago', '15', 'True', 'K3_FULL', '13164', '2019-03-29 18:54:13', '41.858166', '1726 S Racine Ave', '-87.656495', '60608', 'Racine Ave & 18th St', '', 'Racine Ave & 18th St', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '4', '11', 'Chicago', '16', 'True', 'K3_FULL', '13223', '2019-03-29 18:54:22', '41.910337', '1575 N Paulina Ave', '-87.670072', '60622', 'Paulina Ave & North Ave', '', 'Paulina Ave & North Ave', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '10', '12', 'Chicago', '17', 'True', 'K3_FULL', '13246', '2019-03-29 18:54:23', '41.903119', ' W. Divison St', '-87.673935', '60622', 'Honore St & Division St', '', 'Honore St & Division St', 'IN_SERVICE', '1', 'In Service', 'False', '23']
# ['0', '0', '19', 'Chicago', '18', 'True', 'K3_FULL', '15536', '2019-03-29 18:50:31', '41.883132', '', '-87.637321', '60606', 'Wacker Dr & Washington St', '', 'Wacker Dr & Washington St', 'IN_SERVICE', '1', 'In Service', 'False', '19']
# ['0', '5', '11', 'Chicago', '19', 'True', 'K3_FULL', '13139', '2019-03-29 18:54:22', '41.868968', '', '-87.659141', '60607', 'Loomis St & Taylor St (*)', '', 'Loomis St & Taylor St (*)', 'IN_SERVICE', '1', 'In Service', 'False', '16']
# ['0', '8', '7', 'Chicago', '20', 'True', 'K3_FULL', '13154', '2019-03-29 18:53:44', '41.910522', '', '-87.653106', '60642', 'Sheffield Ave & Kingsbury St', '', 'Sheffield Ave & Kingsbury St', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '15', '8', 'Chicago', '21', 'True', 'K3_FULL', '13157', '2019-03-29 18:53:50', '41.87772613', '1103 W.Jackson Blvd', '-87.65478743', '60607', 'Aberdeen St & Jackson Blvd', '', 'Aberdeen St & Jackson Blvd', 'IN_SERVICE', '1', 'In Service', 'False', '23']
# ['0', '4', '11', 'Chicago', '22', 'True', 'K3_FULL', '13160', '2019-03-29 18:54:24', '41.8694821', '1134 W. Taylor St', '-87.6554864', '60607', 'May St & Taylor St', '', 'May St & Taylor St', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '6', '10', 'Chicago', '23', 'True', 'K3_FULL', '13172', '2019-03-29 18:53:13', '41.902924', '350 W. Elm st', '-87.637715', '60610', 'Orleans St & Elm St (*)', '', 'Orleans St & Elm St (*)', 'IN_SERVICE', '1', 'In Service', 'False', '16']
# ['0', '10', '5', 'Chicago', '24', 'True', 'K3_FULL', '13262', '2019-03-29 18:51:52', '41.89186', '240 E.Grand Ave.', '-87.62062', '60611', 'Fairbanks Ct & Grand Ave', '', 'Fairbanks Ct & Grand Ave', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '18', '5', 'Chicago', '25', 'True', 'K3_FULL', '13034', '2019-03-29 18:50:32', '41.89766', '150 E.Pearson st', '-87.62351', '60611', 'Michigan Ave & Pearson St', '', 'Michigan Ave & Pearson St', 'IN_SERVICE', '1', 'In Service', 'False', '23']
# ['0', '31', '0', 'Chicago', '26', 'True', 'K3_FULL', '13051', '2019-03-29 18:52:31', '41.890359', '', '-87.617532', '60611', 'McClurg Ct & Illinois St', '', 'McClurg Ct & Illinois St', 'IN_SERVICE', '1', 'In Service', 'False', '31']
# ['0', '6', '13', 'Chicago', '27', 'True', 'K3_FULL', '13174', '2019-03-29 18:50:25', '41.91021', '1530 N.Larrabee st', '-87.6435', '60610', 'Larrabee St & North Ave', '', 'Larrabee St & North Ave', 'IN_SERVICE', '1', 'In Service', 'False', '19']
# ['0', '6', '9', 'Chicago', '28', 'True', 'K3_FULL', '13282', '2019-03-29 18:52:00', '41.91468', '590 W. Menomonee', '-87.64332', '60614', 'Larrabee St & Menomonee St', '', 'Larrabee St & Menomonee St', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '2', '13', 'Chicago', '29', 'True', 'K3_FULL', '13290', '2019-03-29 18:50:40', '41.90068', '1016 N. Noble St', '-87.6626', '60642', 'Noble St & Milwaukee Ave', '', 'Noble St & Milwaukee Ave', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '11', '4', 'Chicago', '30', 'True', 'K3_FULL', '13248', '2019-03-29 18:50:49', '41.899643', '1611 W. Augusta Blvd', '-87.6677', '60642', 'Ashland Ave & Augusta Blvd', '', 'Ashland Ave & Augusta Blvd', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '3', '20', 'Chicago', '31', 'True', 'K3_FULL', '13017', '2019-03-29 18:52:03', '41.896776', '805 N. Franklin St', '-87.635633', '60654', 'Franklin St & Chicago Ave', '', 'Franklin St & Chicago Ave', 'IN_SERVICE', '1', 'In Service', 'False', '23']
# ['0', '4', '15', 'Chicago', '32', 'True', 'K3_FULL', '13076', '2019-03-29 18:51:19', '41.87464', '550 S. Racine', '-87.65703', '60607', 'Racine Ave & Congress Pkwy', '', 'Racine Ave & Congress Pkwy', 'IN_SERVICE', '1', 'In Service', 'False', '19']
# ['0', '0', '27', 'Chicago', '33', 'True', 'K3_FULL', '13003', '2019-03-29 18:53:48', '41.877181', '360 S State St', '-87.627844', '60604', 'State St & Van Buren St', '', 'State St & Van Buren St', 'IN_SERVICE', '1', 'In Service', 'False', '27']
# ['0', '7', '7', 'Chicago', '34', 'True', 'K3_FULL', '13124', '2019-03-29 18:53:22', '41.9267559875', '2432 N. Cannon Dr.', '-87.6344287848', '60614', 'Cannon Dr & Fullerton Ave', '', 'Cannon Dr & Fullerton Ave', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '9', '38', 'Chicago', '35', 'True', 'K3_FULL', '13022', '2019-03-29 18:54:26', '41.892278', 'Navy Pier', '-87.612043', '60611', 'Streeter Dr & Grand Ave', '', 'Streeter Dr & Grand Ave', 'IN_SERVICE', '1', 'In Service', 'False', '47']
# ['0', '5', '33', 'Chicago', '36', 'True', 'K3_FULL', '13019', '2019-03-29 18:52:12', '41.8777079559', '340 S. Franklin St', '-87.6353211408', '60606', 'Franklin St & Jackson Blvd', '', 'Franklin St & Jackson Blvd', 'IN_SERVICE', '1', 'In Service', 'False', '39']
# ['0', '1', '18', 'Chicago', '37', 'True', 'K3_FULL', '13020', '2019-03-29 18:52:48', '41.8793563587', '59 W. Adams St ', '-87.6297910363', '60603', 'Dearborn St & Adams St', '', 'Dearborn St & Adams St', 'IN_SERVICE', '1', 'In Service', 'False', '19']
# ['0', '9', '18', 'Chicago', '38', 'True', 'K3_FULL', '15547', '2019-03-29 18:52:09', '41.88602082773', '', '-87.6308760584', '60601', 'Clark St & Lake St', '', 'Clark St & Lake St', 'IN_SERVICE', '1', 'In Service', 'False', '27']
# ['0', '11', '12', 'Chicago', '39', 'True', 'K3_FULL', '15538', '2019-03-29 18:51:10', '41.87947235235', '', '-87.6256886059', '60603', 'Wabash Ave & Adams St', '', 'Wabash Ave & Adams St', 'IN_SERVICE', '1', 'In Service', 'False', '23']
# ['0', '1', '13', 'Chicago', '40', 'True', 'K3_FULL', '15537', '2019-03-29 18:50:43', '41.87934437346', '', '-87.6319852213', '60603', 'LaSalle St & Adams St', '', 'LaSalle St & Adams St', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '12', '6', 'Chicago', '41', 'True', 'K3_FULL', '15543', '2019-03-29 18:50:13', '41.87207763285', '', '-87.6295437729', '60605', 'Federal St & Polk St', '', 'Federal St & Polk St', 'IN_SERVICE', '1', 'In Service', 'False', '19']
# ['0', '9', '2', 'Chicago', '42', 'True', 'K3_FULL', '13170', '2019-03-29 18:53:30', '41.852619', '13 E Cermak Rd', '-87.626488', '60616', 'Wabash Ave & Cermak Rd', 'CTA Green Line - Cermak Stop', 'Wabash Ave & Cermak Rd', 'IN_SERVICE', '1', 'In Service', 'False', '11']
# ['0', '10', '33', 'Chicago', '43', 'True', 'K3_FULL', '13001', '2019-03-29 18:54:13', '41.8838927658', '120 N Michigan', '-87.6246491409', '60602', 'Michigan Ave & Washington St', '', 'Michigan Ave & Washington St', 'IN_SERVICE', '1', 'In Service', 'False', '43']
# ['0', '17', '10', 'Chicago', '44', 'True', 'K3_FULL', '13002', '2019-03-29 18:52:02', '41.8847302006', '', '-87.6277335692', '60601', 'State St & Randolph St', '', 'State St & Randolph St', 'IN_SERVICE', '1', 'In Service', 'False', '27']
# ['0', '0', '15', 'Chicago', '45', 'True', 'K3_FULL', '13040', '2019-03-29 18:54:18', '41.876243', '420 w. Michigan', '-87.624426', '60605', 'Michigan Ave & Ida B Wells Dr', '', 'Michigan Ave & Ida B Wells Dr', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '15', '4', 'Chicago', '46', 'True', 'K3_FULL', '13046', '2019-03-29 18:53:14', '41.89993001', '932 N Wells St', '-87.63443007', '60610', 'Wells St & Walton St', '', 'Wells St & Walton St', 'IN_SERVICE', '1', 'In Service', 'False', '19']
# ['0', '5', '26', 'Chicago', '47', 'True', 'K3_FULL', '13050', '2019-03-29 18:52:49', '41.889187', '5 E Kinzie St', '-87.627754', '60654', 'State St & Kinzie St', '', 'State St & Kinzie St', 'IN_SERVICE', '1', 'In Service', 'False', '31']
# ['0', '5', '38', 'Chicago', '48', 'True', 'K3_FULL', '13012', '2019-03-29 18:54:17', '41.897764', '840 N Larrabee St', '-87.642884', '60610', 'Larrabee St & Kingsbury St', '', 'Larrabee St & Kingsbury St', 'IN_SERVICE', '1', 'In Service', 'False', '43']
# ['0', '19', '18', 'Chicago', '49', 'True', 'K3_FULL', '13049', '2019-03-29 18:52:53', '41.881319815', '80 S Dearborn St', '-87.6295209193', '60603', 'Dearborn St & Monroe St', '', 'Dearborn St & Monroe St', 'IN_SERVICE', '1', 'In Service', 'False', '39']
# ['0', '11', '24', 'Chicago', '50', 'True', 'K3_FULL', '13009', '2019-03-29 18:54:20', '41.8759326655', '', '-87.6305845355', '60605', 'Clark St & Ida B Wells Dr', '', 'Clark St & Ida B Wells Dr', 'IN_SERVICE', '1', 'In Service', 'False', '35']
# ['0', '14', '25', 'Chicago', '51', 'True', 'K3_FULL', '13005', '2019-03-29 18:52:42', '41.884576228', '120 W. Randolph St.', '-87.63188991', '60601', 'Clark St & Randolph St', '', 'Clark St & Randolph St', 'IN_SERVICE', '1', 'In Service', 'False', '39']
# ['0', '2', '33', 'Chicago', '52', 'True', 'K3_FULL', '13043', '2019-03-29 18:51:24', '41.886024', '203 N Michigan Ave', '-87.624117', '60601', 'Michigan Ave & Lake St', '', 'Michigan Ave & Lake St', 'IN_SERVICE', '1', 'In Service', 'False', '35']
# ['0', '14', '12', 'Chicago', '53', 'True', 'K3_FULL', '13064', '2019-03-29 18:54:26', '41.894722', '', '-87.634362', '60654', 'Wells St & Huron St', '', 'Wells St & Huron St', 'IN_SERVICE', '1', 'In Service', 'False', '27']
# ['0', '10', '8', 'Chicago', '54', 'True', 'K3_FULL', '13044', '2019-03-29 18:50:47', '41.896362458', '1040 W. Chicago Ave.', '-87.6540612729', '60642', 'Ogden Ave & Chicago Ave', '', 'Ogden Ave & Chicago Ave', 'IN_SERVICE', '1', 'In Service', 'False', '19']
# ['0', '0', '23', 'Chicago', '55', 'True', 'K3_FULL', '13166', '2019-03-29 18:52:33', '41.867324', '850 W Roosevelt Rd', '-87.648625', '60608', 'Halsted St & Roosevelt Rd', '', 'Halsted St & Roosevelt Rd', 'IN_SERVICE', '1', 'In Service', 'False', '23']
# ['0', '6', '20', 'Chicago', '56', 'True', 'K3_FULL', '13039', '2019-03-29 18:52:05', '41.888716036', '368 N. Desplaines St.', '-87.6444478533', '60661', 'Desplaines St & Kinzie St', '', 'Desplaines St & Kinzie St', 'IN_SERVICE', '1', 'In Service', 'False', '27']
# ['0', '12', '3', 'Chicago', '57', 'True', 'K3_FULL', '13327', '2019-03-29 18:53:27', '41.8671177825', '559 W Roosevelt Rd', '-87.6410879593', '60607', 'Clinton St & Roosevelt Rd', '', 'Clinton St & Roosevelt Rd', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '0', '23', 'Chicago', '58', 'True', 'K3_FULL', '13025', '2019-03-29 18:52:12', '41.916017', '', '-87.668879', '60622', 'Marshfield Ave & Cortland St', '', 'Marshfield Ave & Cortland St', 'IN_SERVICE', '1', 'In Service', 'False', '23']
# ['0', '14', '9', 'Chicago', '59', 'True', 'K3_FULL', '13031', '2019-03-29 18:52:35', '41.867227', '1210 S Wabash Ave', '-87.625961', '60605', 'Wabash Ave & Roosevelt Rd', '', 'Wabash Ave & Roosevelt Rd', 'IN_SERVICE', '1', 'In Service', 'False', '23']
# ['0', '13', '6', 'Chicago', '60', 'True', 'K3_FULL', '13058', '2019-03-29 18:54:19', '41.9105780349', '1575 N Dayton St', '-87.6494219288', '60642', 'Dayton St & North Ave', '', 'Dayton St & North Ave', 'IN_SERVICE', '1', 'In Service', 'False', '19']
# ['0', '13', '6', 'Chicago', '61', 'True', 'K3_FULL', '13221', '2019-03-29 18:51:25', '41.907655', '1416 N Wood St', '-87.672552', '60622', 'Wood St & Milwaukee Ave', '', 'Wood St & Milwaukee Ave', 'IN_SERVICE', '1', 'In Service', 'False', '19']
# ['0', '9', '18', 'Chicago', '62', 'True', 'K3_FULL', '13106', '2019-03-29 18:51:20', '41.8513751729', '2253 S Dr Martin Luther King Jr Dr', '-87.6188346489', '60616', 'McCormick Place', '', 'McCormick Place', 'IN_SERVICE', '1', 'In Service', 'False', '27']
# ['0', '8', '15', 'Chicago', '66', 'True', 'K3_FULL', '13021', '2019-03-29 18:50:39', '41.885637', '', '-87.641823', '60661', 'Clinton St & Lake St', '', 'Clinton St & Lake St', 'IN_SERVICE', '1', 'In Service', 'False', '23']
# ['0', '2', '25', 'Chicago', '67', 'True', 'K3_FULL', '13060', '2019-03-29 18:52:58', '41.9256018819', '2410 N Sheffield Ave', '-87.6537080423', '60614', 'Sheffield Ave & Fullerton Ave', '', 'Sheffield Ave & Fullerton Ave', 'IN_SERVICE', '1', 'In Service', 'False', '27']
# ['0', '5', '17', 'Chicago', '68', 'True', 'K3_FULL', '13037', '2019-03-29 18:51:59', '41.875885', '520 W Tilden St', '-87.640795', '60607', 'Clinton St & Tilden St', '', 'Clinton St & Tilden St', 'IN_SERVICE', '1', 'In Service', 'False', '23']
# ['0', '16', '7', 'Chicago', '69', 'True', 'K3_FULL', '13065', '2019-03-29 18:51:01', '41.9093960065', '2002 W Pierce Ave', '-87.6776919292', '60622', 'Damen Ave & Pierce Ave', '', 'Damen Ave & Pierce Ave', 'IN_SERVICE', '1', 'In Service', 'False', '23']
# ['0', '17', '6', 'Chicago', '71', 'True', 'K3_FULL', '13072', '2019-03-29 18:53:49', '41.8854833079', '1003 W. Lake St.', '-87.6523048564', '60607', 'Morgan St & Lake St', '', 'Morgan St & Lake St', 'IN_SERVICE', '1', 'In Service', 'False', '23']
# ['0', '27', '12', 'Chicago', '72', 'True', 'K3_FULL', '13148', '2019-03-29 18:53:21', '41.860384', '1590 S Wabash Ave', '-87.625813', '60605', 'Wabash Ave & 16th St', '', 'Wabash Ave & 16th St', 'IN_SERVICE', '1', 'In Service', 'False', '39']
# ['0', '1', '18', 'Chicago', '73', 'True', 'K3_FULL', '13038', '2019-03-29 18:52:08', '41.880422', '207 S Jefferson St', '-87.642746', '60661', 'Jefferson St & Monroe St', '', 'Jefferson St & Monroe St', 'IN_SERVICE', '1', 'In Service', 'False', '19']
# ['0', '22', '1', 'Chicago', '74', 'True', 'K3_FULL', '13265', '2019-03-29 18:52:29', '41.893626', '511 W Erie St', '-87.641527', '60654', 'Kingsbury St & Erie St', '', 'Kingsbury St & Erie St', 'IN_SERVICE', '1', 'In Service', 'False', '23']
# ['0', '2', '36', 'Chicago', '75', 'True', 'K3_FULL', '13138', '2019-03-29 18:51:59', '41.877245', '', '-87.639366', '60661', 'Canal St & Jackson Blvd', '', 'Canal St & Jackson Blvd', 'IN_SERVICE', '1', 'In Service', 'False', '39']
# ['0', '8', '31', 'Chicago', '76', 'True', 'K3_FULL', '13300', '2019-03-29 18:52:20', '41.880958', '402 E Monroe St', '-87.616743', '60603', 'Lake Shore Dr & Monroe St', '', 'Lake Shore Dr & Monroe St', 'IN_SERVICE', '1', 'In Service', 'False', '39']
# ['0', '6', '24', 'Chicago', '77', 'True', 'K3_FULL', '13301', '2019-03-29 18:51:46', '41.882242', '5 N Clinton St', '-87.641066', '60661', 'Clinton St & Madison St', '', 'Clinton St & Madison St', 'IN_SERVICE', '1', 'In Service', 'False', '31']
# ['0', '7', '12', 'Chicago', '80', 'True', 'K3_FULL', '13156', '2019-03-29 18:50:31', '41.880419', '', '-87.655519', '60607', 'Aberdeen St & Monroe St', '', 'Aberdeen St & Monroe St', 'IN_SERVICE', '1', 'In Service', 'False', '19']
# ['0', '1', '38', 'Chicago', '81', 'True', 'K3_FULL', '13023', '2019-03-29 18:50:49', '41.884241', '', '-87.629634', '60601', 'Daley Center Plaza', '', 'Daley Center Plaza', 'IN_SERVICE', '1', 'In Service', 'False', '39']
# ['0', '7', '12', 'Chicago', '84', 'True', 'K3_FULL', '13033', '2019-03-29 18:52:28', '41.891578', '500 N Milwaukee Ave.', '-87.648384', '60654', 'Milwaukee Ave & Grand Ave', '', 'Milwaukee Ave & Grand Ave', 'IN_SERVICE', '1', 'In Service', 'False', '19']
# ['0', '22', '1', 'Chicago', '85', 'True', 'K3_FULL', '13042', '2019-03-29 18:54:21', '41.90096039', '140 E Oak St', '-87.62377664', '60611', 'Michigan Ave & Oak St', '', 'Michigan Ave & Oak St', 'IN_SERVICE', '1', 'In Service', 'False', '23']
# ['0', '4', '15', 'Chicago', '86', 'True', 'K3_FULL', '13289', '2019-03-29 18:51:48', '41.89637337', '811 N Noble St', '-87.66098386', '60642', 'Eckhart Park', '', 'Eckhart Park', 'IN_SERVICE', '1', 'In Service', 'False', '19']
# ['0', '5', '14', 'Chicago', '87', 'True', 'K3_FULL', '13189', '2019-03-29 18:51:14', '41.92556258', '2411 N Racine Ave', '-87.65840426', '60614', 'Racine Ave & Fullerton Ave', '', 'Racine Ave & Fullerton Ave', 'IN_SERVICE', '1', 'In Service', 'False', '19']
# ['0', '17', '2', 'Chicago', '88', 'True', 'K3_FULL', '13155', '2019-03-29 18:51:05', '41.884069', '1213 W Randolph St', '-87.656853', '60607', 'Racine Ave & Randolph St', '', 'Racine Ave & Randolph St', 'IN_SERVICE', '1', 'In Service', 'False', '19']
# ['0', '5', '10', 'Chicago', '89', 'True', 'K3_FULL', '15540', '2019-03-29 18:50:59', '41.874618', '', '-87.632882', '60605', 'Financial Pl & Ida B Wells Dr (Temp)', '', 'Financial Pl & Ida B Wells Dr (Temp)', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '19', '28', 'Chicago', '90', 'True', 'K3_FULL', '13008', '2019-03-29 18:53:55', '41.8810317', '33 S Michigan Ave', '-87.62408432', '60601', 'Millennium Park', '', 'Millennium Park', 'IN_SERVICE', '1', 'In Service', 'False', '47']
# ['0', '4', '25', 'Chicago', '91', 'True', 'K3_FULL', '13010', '2019-03-29 18:50:36', '41.88338', '109 N Clinton St', '-87.64117', '60661', 'Clinton St & Washington Blvd', '', 'Clinton St & Washington Blvd', 'IN_SERVICE', '1', 'In Service', 'False', '31']
# ['0', '11', '8', 'Chicago', '92', 'True', 'K3_FULL', '13196', '2019-03-29 18:54:07', '41.894556', '', '-87.653449', '60642', 'Carpenter St & Huron St', '', 'Carpenter St & Huron St', 'IN_SERVICE', '1', 'In Service', 'False', '19']
# ['0', '6', '9', 'Chicago', '93', 'True', 'K3_FULL', '13190', '2019-03-29 18:54:04', '41.913688', '1740 N Sheffield Ave', '-87.652855', '60614', 'Sheffield Ave & Willow St', '', 'Sheffield Ave & Willow St', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '19', '12', 'Chicago', '94', 'True', 'K3_FULL', '13146', '2019-03-29 18:51:29', '41.918306', '', '-87.636282', '60614', 'Clark St & Armitage Ave', '', 'Clark St & Armitage Ave', 'IN_SERVICE', '1', 'In Service', 'False', '31']
# ['0', '3', '8', 'Chicago', '95', 'True', 'K3_FULL', '15490', '2019-03-29 18:51:54', '41.778881', '', '-87.586647', '60637', 'Stony Island Ave & 64th St', '', 'Stony Island Ave & 64th St', 'IN_SERVICE', '1', 'In Service', 'False', '11']
# ['0', '15', '8', 'Chicago', '96', 'True', 'K3_FULL', '15535', '2019-03-29 18:50:26', '41.88461618962', '', '-87.6445705849', '60661', 'Desplaines St & Randolph St', '', 'Desplaines St & Randolph St', 'IN_SERVICE', '1', 'In Service', 'False', '23']
# ['0', '0', '55', 'Chicago', '97', 'True', 'K3_FULL', '13029', '2019-03-29 18:52:22', '41.865312', 'Off Street', '-87.617867', '60605', 'Field Museum', '', 'Field Museum', 'IN_SERVICE', '1', 'In Service', 'False', '55']
# ['0', '0', '15', 'Chicago', '98', 'True', 'K3_FULL', '13006', '2019-03-29 18:54:12', '41.882664', '', '-87.63253', '60602', 'LaSalle St & Washington St', '', 'LaSalle St & Washington St', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '6', '13', 'Chicago', '99', 'True', 'K3_FULL', '13337', '2019-03-29 18:50:03', '41.89257', '', '-87.614492', '60611', 'Lake Shore Dr & Ohio St', '', 'Lake Shore Dr & Ohio St', 'IN_SERVICE', '1', 'In Service', 'False', '19']
# ['0', '14', '21', 'Chicago', '100', 'True', 'K3_FULL', '13013', '2019-03-29 18:50:22', '41.888243', '333 N Orleans St', '-87.63639', '60654', 'Orleans St & Merchandise Mart Plaza', '', 'Orleans St & Merchandise Mart Plaza', 'IN_SERVICE', '1', 'In Service', 'False', '35']
# ['0', '7', '8', 'Chicago', '101', 'True', 'K3_FULL', '15491', '2019-03-29 18:50:23', '41.78101637196', '', '-87.5761197602', '60649', '63rd St Beach', '', '63rd St Beach', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '3', '8', 'Chicago', '102', 'True', 'K3_FULL', '15492', '2019-03-29 18:54:02', '41.77345849948', '', '-87.5853397391', '60649', 'Stony Island Ave & 67th St', '', 'Stony Island Ave & 67th St', 'IN_SERVICE', '1', 'In Service', 'False', '11']
# ['0', '9', '7', 'Chicago', '103', 'True', 'K3_FULL', '15542', '2019-03-29 18:52:40', '41.87146651779', '', '-87.6409491327', '60607', 'Clinton St & Polk St (*)', 'Old kiosk KA1503000022 now at Clark & Montrose 5.3.2017 DH', 'Clinton St & Polk St (*)', 'IN_SERVICE', '1', 'In Service', 'False', '16']
# ['0', '10', '17', 'Chicago', '106', 'True', 'K3_FULL', '13014', '2019-03-29 18:51:23', '41.897448', '', '-87.628722', '60610', 'State St & Pearson St', '', 'State St & Pearson St', 'IN_SERVICE', '1', 'In Service', 'False', '27']
# ['0', '17', '10', 'Chicago', '107', 'True', 'K3_FULL', '15539', '2019-03-29 18:52:41', '41.878287', '', '-87.643909', '60661', 'Desplaines St & Jackson Blvd', '', 'Desplaines St & Jackson Blvd', 'IN_SERVICE', '1', 'In Service', 'False', '27']
# ['0', '12', '7', 'Chicago', '108', 'True', 'K3_FULL', '13027', '2019-03-29 18:50:01', '41.87184', '', '-87.64664', '60607', 'Halsted St & Polk St', '', 'Halsted St & Polk St', 'IN_SERVICE', '1', 'In Service', 'False', '19']
# ['0', '0', '19', 'Chicago', '109', 'True', 'K3_FULL', '13028', '2019-03-29 18:50:27', '41.874754', '', '-87.649807', '60607', '900 W Harrison St', 'Peoria Blue Line', '900 W Harrison St', 'IN_SERVICE', '1', 'In Service', 'False', '19']
# ['0', '12', '15', 'Chicago', '110', 'True', 'K3_FULL', '13045', '2019-03-29 18:51:24', '41.893992', '', '-87.629318', '60654', 'Dearborn St & Erie St', '\n', 'Dearborn St & Erie St', 'IN_SERVICE', '1', 'In Service', 'False', '27']
# ['0', '7', '20', 'Chicago', '111', 'True', 'K3_FULL', '13052', '2019-03-29 18:51:41', '41.894666', '', '-87.638437', '60654', 'Sedgwick St & Huron St', '', 'Sedgwick St & Huron St', 'IN_SERVICE', '1', 'In Service', 'False', '27']
# ['0', '14', '0', 'Chicago', '112', 'True', 'K3_FULL', '13053', '2019-03-29 18:54:17', '41.883668', '', '-87.64867', '60607', 'Green St & Randolph St', '', 'Green St & Randolph St', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '15', '0', 'Chicago', '113', 'True', 'K3_FULL', '13059', '2019-03-29 18:50:01', '41.91844', '', '-87.65222', '60614', 'Bissell St & Armitage Ave', '', 'Bissell St & Armitage Ave', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '6', '21', 'Chicago', '114', 'True', 'K3_FULL', '13062', '2019-03-29 18:53:31', '41.949399', '', '-87.654529', '60657', 'Sheffield Ave & Waveland Ave', '', 'Sheffield Ave & Waveland Ave', 'IN_SERVICE', '1', 'In Service', 'False', '27']
# ['0', '2', '21', 'Chicago', '115', 'True', 'K3_FULL', '13067', '2019-03-29 18:52:05', '41.936266', '', '-87.652662', '60657', 'Sheffield Ave & Wellington Ave', '', 'Sheffield Ave & Wellington Ave', 'IN_SERVICE', '1', 'In Service', 'False', '23']
# ['0', '6', '9', 'Chicago', '116', 'True', 'K3_FULL', '13068', '2019-03-29 18:53:53', '41.91552', '', '-87.687022', '60647', 'Western Ave & Winnebago Ave', '', 'Western Ave & Winnebago Ave', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '0', '27', 'Chicago', '117', 'True', 'K3_FULL', '13069', '2019-03-29 18:53:44', '41.94018', '', '-87.65304', '60657', 'Wilton Ave & Belmont Ave', '', 'Wilton Ave & Belmont Ave', 'IN_SERVICE', '1', 'In Service', 'False', '27']
# ['0', '4', '15', 'Chicago', '118', 'True', 'K3_FULL', '13070', '2019-03-29 18:53:38', '41.911386', '', '-87.638677', '60610', 'Sedgwick St & North Ave', '', 'Sedgwick St & North Ave', 'IN_SERVICE', '1', 'In Service', 'False', '19']
# ['0', '0', '19', 'Chicago', '119', 'True', 'K3_FULL', '13073', '2019-03-29 18:50:32', '41.88592', '', '-87.66717', '60612', 'Ashland Ave & Lake St (Temp)', '', 'Ashland Ave & Lake St (Temp)', 'IN_SERVICE', '1', 'In Service', 'False', '19']
# ['0', '13', '6', 'Chicago', '120', 'True', 'K3_FULL', '13075', '2019-03-29 18:50:40', '41.853005', '', '-87.630578', '60616', 'Wentworth Ave & Cermak Rd (Temp)', '', 'Wentworth Ave & Cermak Rd (Temp)', 'IN_SERVICE', '1', 'In Service', 'False', '19']
# ['0', '6', '12', 'Chicago', '121', 'True', 'K3_FULL', '13398', '2019-03-29 18:52:58', '41.802562', '', '-87.590368', '60615', 'Blackstone Ave & Hyde Park Blvd', '', 'Blackstone Ave & Hyde Park Blvd', 'IN_SERVICE', '1', 'In Service', 'False', '19']
# ['0', '0', '15', 'Chicago', '122', 'True', 'K3_FULL', '13081', '2019-03-29 18:51:56', '41.87501', '', '-87.67328', '60612', 'Ogden Ave & Congress Pkwy', '', 'Ogden Ave & Congress Pkwy', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '14', '1', 'Chicago', '123', 'True', 'K3_FULL', '13084', '2019-03-29 18:50:45', '41.922695', '', '-87.697153', '60647', 'California Ave & Milwaukee Ave', '', 'California Ave & Milwaukee Ave', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '14', '1', 'Chicago', '124', 'True', 'K3_FULL', '13089', '2019-03-29 18:53:24', '41.855048', '', '-87.675726', '60608', 'Damen Ave & Cullerton St', '', 'Damen Ave & Cullerton St', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '13', '10', 'Chicago', '125', 'True', 'K3_FULL', '15533', '2019-03-29 18:52:20', '41.890173', '', '-87.626185', '60611', 'Rush St & Hubbard St', '', 'Rush St & Hubbard St', 'IN_SERVICE', '1', 'In Service', 'False', '23']
# ['0', '8', '7', 'Chicago', '126', 'True', 'K3_FULL', '13128', '2019-03-29 18:53:01', '41.911974', '', '-87.631942', '60614', 'Clark St & North Ave', '', 'Clark St & North Ave', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '4', '10', 'Chicago', '127', 'True', 'K3_FULL', '13131', '2019-03-29 18:53:49', '41.925905', '', '-87.64926', '60614', 'Lincoln Ave & Fullerton Ave', '', 'Lincoln Ave & Fullerton Ave', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '2', '17', 'Chicago', '128', 'True', 'K3_FULL', '13132', '2019-03-29 18:51:34', '41.895769', '', '-87.67722', '60622', 'Damen Ave & Chicago Ave', '', 'Damen Ave & Chicago Ave', 'IN_SERVICE', '1', 'In Service', 'False', '19']
# ['0', '13', '2', 'Chicago', '129', 'True', 'K3_FULL', '13135', '2019-03-29 18:51:02', '41.857556', '', '-87.661535', '60608', 'Blue Island Ave & 18th St', '', 'Blue Island Ave & 18th St', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '13', '5', 'Chicago', '130', 'True', 'K3_FULL', '13136', '2019-03-29 18:50:19', '41.903266', '', '-87.678435', '60622', 'Damen Ave & Division St', '', 'Damen Ave & Division St', 'IN_SERVICE', '1', 'In Service', 'False', '19']
# ['0', '1', '14', 'Chicago', '131', 'True', 'K3_FULL', '13140', '2019-03-29 18:54:21', '41.939365', '', '-87.668385', '60657', 'Lincoln Ave & Belmont Ave', '', 'Lincoln Ave & Belmont Ave', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '12', '3', 'Chicago', '132', 'True', 'K3_FULL', '13149', '2019-03-29 18:51:43', '41.849237', '', '-87.631715', '60616', 'Wentworth Ave & 24th St', '', 'Wentworth Ave & 24th St', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '12', '19', 'Chicago', '133', 'True', 'K3_FULL', '15532', '2019-03-29 18:54:20', '41.88917683258', '', '-87.6385057718', '60654', 'Kingsbury St & Kinzie St', '', 'Kingsbury St & Kinzie St', 'IN_SERVICE', '1', 'In Service', 'False', '31']
# ['0', '10', '9', 'Chicago', '134', 'True', 'K3_FULL', '13158', '2019-03-29 18:52:02', '41.877749', '', '-87.649633', '60607', 'Peoria St & Jackson Blvd', '', 'Peoria St & Jackson Blvd', 'IN_SERVICE', '1', 'In Service', 'False', '19']
# ['0', '1', '10', 'Chicago', '135', 'True', 'K3_FULL', '13162', '2019-03-29 18:53:54', '41.85378', '', '-87.64665', '60608', 'Halsted St & 21st St', '', 'Halsted St & 21st St', 'IN_SERVICE', '1', 'In Service', 'False', '11']
# ['0', '9', '6', 'Chicago', '136', 'True', 'K3_FULL', '13165', '2019-03-29 18:50:17', '41.865054', '', '-87.656959', '60608', 'Racine Ave & 13th St', '', 'Racine Ave & 13th St', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '9', '6', 'Chicago', '137', 'True', 'K3_FULL', '13169', '2019-03-29 18:53:45', '41.862378', '', '-87.651062', '60608', 'Morgan Ave & 14th Pl', '', 'Morgan Ave & 14th Pl', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '13', '2', 'Chicago', '138', 'True', 'K3_FULL', '13171', '2019-03-29 18:51:03', '41.904613', '', '-87.640552', '60610', 'Clybourn Ave & Division St', '', 'Clybourn Ave & Division St', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '6', '13', 'Chicago', '140', 'True', 'K3_FULL', '13173', '2019-03-29 18:50:59', '41.898969', '', '-87.629912', '60610', 'Dearborn Pkwy & Delaware Pl', '', 'Dearborn Pkwy & Delaware Pl', 'IN_SERVICE', '1', 'In Service', 'False', '19']
# ['0', '9', '13', 'Chicago', '141', 'True', 'K3_FULL', '13179', '2019-03-29 18:54:25', '41.915689', '', '-87.6346', '60614', 'Clark St & Lincoln Ave', '', 'Clark St & Lincoln Ave', 'IN_SERVICE', '1', 'In Service', 'False', '23']
# ['0', '6', '25', 'Chicago', '142', 'True', 'K3_FULL', '15531', '2019-03-29 18:52:04', '41.894503', '660 N McClurg Ct', '-87.617854', '60611', 'McClurg Ct & Erie St', '', 'McClurg Ct & Erie St', 'IN_SERVICE', '1', 'In Service', 'False', '31']
# ['0', '4', '10', 'Chicago', '143', 'True', 'K3_FULL', '13191', '2019-03-29 18:53:56', '41.922167', '', '-87.638888', '60614', 'Sedgwick St & Webster Ave', '', 'Sedgwick St & Webster Ave', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '9', '10', 'Chicago', '144', 'True', 'K3_FULL', '13193', '2019-03-29 18:50:37', '41.921822', '', '-87.64414', '60614', 'Larrabee St & Webster Ave', '', 'Larrabee St & Webster Ave', 'IN_SERVICE', '1', 'In Service', 'False', '19']
# ['0', '10', '9', 'Chicago', '145', 'True', 'K3_FULL', '15529', '2019-03-29 18:52:37', '41.8985866514', '', '-87.6219152258', '60611', 'Mies van der Rohe Way & Chestnut St', '', 'Mies van der Rohe Way & Chestnut St', 'IN_SERVICE', '1', 'In Service', 'False', '19']
# ['0', '16', '3', 'Chicago', '146', 'True', 'K3_FULL', '13206', '2019-03-29 18:50:59', '41.877945', '', '-87.662007', '60607', 'Loomis St & Jackson Blvd', '', 'Loomis St & Jackson Blvd', 'IN_SERVICE', '1', 'In Service', 'False', '19']
# ['0', '8', '7', 'Chicago', '147', 'True', 'K3_FULL', '13212', '2019-03-29 18:52:12', '41.845687', '', '-87.622481', '60616', 'Indiana Ave & 26th St', '', 'Indiana Ave & 26th St', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '7', '8', 'Chicago', '148', 'True', 'K3_FULL', '13216', '2019-03-29 18:50:49', '41.834734', '', '-87.625813', '60616', 'State St & 33rd St', '', 'State St & 33rd St', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '0', '11', 'Chicago', '149', 'True', 'K3_FULL', '13217', '2019-03-29 18:52:28', '41.8349', '', '-87.61793', '60616', 'Calumet Ave & 33rd St', '', 'Calumet Ave & 33rd St', 'IN_SERVICE', '1', 'In Service', 'False', '11']
# ['0', '13', '14', 'Chicago', '150', 'True', 'K3_FULL', '13220', '2019-03-29 18:50:29', '41.838556', '', '-87.608218', '60616', 'Fort Dearborn Dr & 31st St', '', 'Fort Dearborn Dr & 31st St', 'IN_SERVICE', '1', 'In Service', 'False', '27']
# ['0', '9', '5', 'Chicago', '152', 'True', 'K3_FULL', '13226', '2019-03-29 18:50:28', '41.932225', '', '-87.658617', '60614', 'Lincoln Ave & Diversey Pkwy', '', 'Lincoln Ave & Diversey Pkwy', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '13', '6', 'Chicago', '153', 'True', 'K3_FULL', '13228', '2019-03-29 18:53:46', '41.935733', '', '-87.663576', '60657', 'Southport Ave & Wellington Ave', '', 'Southport Ave & Wellington Ave', 'IN_SERVICE', '1', 'In Service', 'False', '19']
# ['0', '8', '7', 'Chicago', '154', 'True', 'K3_FULL', '13229', '2019-03-29 18:52:36', '41.93949', '', '-87.66378', '60657', 'Southport Ave & Belmont Ave', '', 'Southport Ave & Belmont Ave', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '14', '1', 'Chicago', '156', 'True', 'K3_FULL', '13232', '2019-03-29 18:52:29', '41.9364968219', '', '-87.6475386582', '60657', 'Clark St & Wellington Ave', '', 'Clark St & Wellington Ave', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '7', '8', 'Chicago', '157', 'True', 'K3_FULL', '13234', '2019-03-29 18:53:57', '41.936669', '', '-87.636794', '60657', 'Lake Shore Dr & Wellington Ave', '', 'Lake Shore Dr & Wellington Ave', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '7', '8', 'Chicago', '158', 'True', 'K3_FULL', '13243', '2019-03-29 18:53:38', '41.912616', '', '-87.681391', '60647', 'Milwaukee Ave & Wabansia Ave', '', 'Milwaukee Ave & Wabansia Ave', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '7', '4', 'Chicago', '159', 'True', 'K3_FULL', '13245', '2019-03-29 18:52:21', '41.907781', '', '-87.685854', '60622', '1451 N Claremont Ave', '', 'Claremont Ave & Hirsch St', 'IN_SERVICE', '1', 'In Service', 'False', '11']
# ['0', '10', '5', 'Chicago', '160', 'True', 'K3_FULL', '13257', '2019-03-29 18:50:58', '41.910535', '', '-87.689556', '60647', 'Campbell Ave & North Ave', '', 'Campbell Ave & North Ave', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '15', '8', 'Chicago', '161', 'True', 'K3_FULL', '15530', '2019-03-29 18:52:21', '41.89576474564', '', '-87.6259080327', '60611', 'Rush St & Superior St', '', 'Rush St & Superior St', 'IN_SERVICE', '1', 'In Service', 'False', '23']
# ['0', '5', '10', 'Chicago', '162', 'True', 'K3_FULL', '13268', '2019-03-29 18:51:30', '41.93588', '', '-87.67842', '60618', 'Damen Ave & Wellington Ave', '', 'Damen Ave & Wellington Ave', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '4', '11', 'Chicago', '163', 'True', 'K3_FULL', '13271', '2019-03-29 18:52:47', '41.931931', '', '-87.677856', '60614', 'Damen Ave & Clybourn Ave', '', 'Damen Ave & Clybourn Ave', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '0', '27', 'Chicago', '164', 'True', 'K3_FULL', '13272', '2019-03-29 18:51:54', '41.885837', '', '-87.6355', '60606', 'Franklin St & Lake St', '', 'Franklin St & Lake St', 'IN_SERVICE', '1', 'In Service', 'False', '27']
# ['0', '13', '9', 'Chicago', '165', 'True', 'K3_FULL', '13275', '2019-03-29 18:51:02', '41.95078', '', '-87.659172', '60613', 'Clark St & Grace St', '', 'Clark St & Grace St', 'IN_SERVICE', '1', 'In Service', 'False', '23']
# ['0', '5', '10', 'Chicago', '166', 'True', 'K3_FULL', '13296', '2019-03-29 18:53:55', '41.92883', '', '-87.668507', '60614', 'Ashland Ave & Wrightwood Ave', '', 'Ashland Ave & Wrightwood Ave', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '6', '1', 'Chicago', '167', 'True', 'K3_FULL', '13306', '2019-03-29 18:51:29', '41.8492', '', '-87.67564', '60608', 'Damen Ave & Coulter St', '', 'Damen Ave & Coulter St', 'IN_SERVICE', '1', 'In Service', 'False', '7']
# ['0', '11', '8', 'Chicago', '168', 'True', 'K3_FULL', '13310', '2019-03-29 18:50:17', '41.864059', '', '-87.623727', '60605', 'Michigan Ave & 14th St', '', 'Michigan Ave & 14th St', 'IN_SERVICE', '1', 'In Service', 'False', '19']
# ['0', '2', '13', 'Chicago', '169', 'True', 'K3_FULL', '13326', '2019-03-29 18:51:17', '41.874255', '', '-87.639573', '60607', 'Canal St & Harrison St', '', 'Canal St & Harrison St', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '4', '11', 'Chicago', '170', 'True', 'K3_FULL', '13329', '2019-03-29 18:51:03', '41.85795', '', '-87.640826', '60616', 'Clinton St & 18th St', '', 'Clinton St & 18th St', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '2', '9', 'Chicago', '171', 'True', 'K3_FULL', '13331', '2019-03-29 18:50:48', '41.855136', '', '-87.654127', '60608', 'May St & Cullerton St', '', 'May St & Cullerton St', 'IN_SERVICE', '1', 'In Service', 'False', '11']
# ['0', '10', '1', 'Chicago', '172', 'True', 'K3_FULL', '15525', '2019-03-29 18:51:05', '41.90230870122', '', '-87.627690528', '60611', 'Rush St & Cedar St', '', 'Rush St & Cedar St', 'IN_SERVICE', '1', 'In Service', 'False', '11']
# ['0', '10', '5', 'Chicago', '173', 'True', 'K3_FULL', '13338', '2019-03-29 18:52:13', '41.89691', '', '-87.621743', '60611', 'Mies van der Rohe Way & Chicago Ave', '', 'Mies van der Rohe Way & Chicago Ave', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '12', '23', 'Chicago', '174', 'True', 'K3_FULL', '13341', '2019-03-29 18:53:13', '41.882091', '', '-87.639833', '60606', 'Canal St & Madison St', '', 'Canal St & Madison St', 'IN_SERVICE', '1', 'In Service', 'False', '35']
# ['0', '8', '11', 'Chicago', '175', 'True', 'K3_FULL', '13344', '2019-03-29 18:51:08', '41.872596', '', '-87.633502', '60607', 'Wells St & Polk St', '', 'Wells St & Polk St', 'IN_SERVICE', '1', 'In Service', 'False', '19']
# ['0', '19', '20', 'Chicago', '176', 'True', 'K3_FULL', '13349', '2019-03-29 18:50:40', '41.902973', '', '-87.63128', '60610', 'Clark St & Elm St', '', 'Clark St & Elm St', 'IN_SERVICE', '1', 'In Service', 'False', '39']
# ['0', '23', '8', 'Chicago', '177', 'True', 'K3_FULL', '13350 ', '2019-03-29 18:51:45', '41.926277', '', '-87.630834', '60614', 'Theater on the Lake', '', 'Theater on the Lake', 'IN_SERVICE', '1', 'In Service', 'False', '31']
# ['0', '15', '0', 'Chicago', '178', 'True', 'K3_FULL', '13408', '2019-03-29 18:50:37', '41.856594', '', '-87.627542', '60616', 'State St & 19th St', '', 'State St & 19th St', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '6', '9', 'Chicago', '179', 'True', 'K3_FULL', '13420', '2019-03-29 18:52:28', '41.8246', 'Off Steet', '-87.61678', '60653', 'MLK Jr Dr & Pershing Rd', 'Formerly MLK Jr Dr & Oakwood Blvd', 'MLK Jr Dr & Pershing Rd', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '15', '0', 'Chicago', '180', 'True', 'K3_FULL', '15523', '2019-03-29 18:53:53', '41.906866', '', '-87.626217', '60610', 'Ritchie Ct & Banks St', '', 'Ritchie Ct & Banks St', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '24', '7', 'Chicago', '181', 'True', 'K3_FULL', '13430', '2019-03-29 18:50:36', '41.890762', 'On Street', '-87.631697', '60654', 'LaSalle St & Illinois St', '', 'LaSalle St & Illinois St', 'IN_SERVICE', '1', 'In Service', 'False', '31']
# ['0', '13', '10', 'Chicago', '182', 'True', 'K3_FULL', '15522', '2019-03-29 18:51:18', '41.903222', '', '-87.634324', '60610', 'Wells St & Elm St', '', 'Wells St & Elm St', 'IN_SERVICE', '1', 'In Service', 'False', '23']
# ['0', '14', '9', 'Chicago', '183', 'True', 'K3_FULL', '13142', '2019-03-29 18:51:04', '41.901315', '', '-87.677409', '60622', 'Damen Ave & Thomas St (Augusta Blvd)', '', 'Damen Ave & Thomas St (Augusta Blvd)', 'IN_SERVICE', '1', 'In Service', 'False', '23']
# ['0', '10', '5', 'Chicago', '184', 'True', 'K3_FULL', '13082', '2019-03-29 18:50:59', '41.83104', '', '-87.62688', '60616', 'State St & 35th St', '', 'State St & 35th St', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '7', '4', 'Chicago', '185', 'True', 'K3_FULL', '13266', '2019-03-29 18:53:13', '41.917741', '', '-87.691392', '60647', 'Stave St & Armitage Ave', '', 'Stave St & Armitage Ave', 'IN_SERVICE', '1', 'In Service', 'False', '11']
# ['0', '11', '4', 'Chicago', '186', 'True', 'K3_FULL', '13194', '2019-03-29 18:51:16', '41.891795', '', '-87.658751', '60642', 'Ogden Ave & Race Ave', '', 'Ogden Ave & Race Ave', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '15', '0', 'Chicago', '188', 'True', 'K3_FULL', '13295', '2019-03-29 18:50:56', '41.92533', '', '-87.6658', '60614', 'Greenview Ave & Fullerton Ave', '', 'Greenview Ave & Fullerton Ave', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '12', '3', 'Chicago', '190', 'True', 'K3_FULL', '13298', '2019-03-29 18:53:44', '41.928773', '', '-87.663913', '60614', 'Southport Ave & Wrightwood Ave', '', 'Southport Ave & Wrightwood Ave', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '7', '21', 'Chicago', '191', 'True', 'K3_FULL', '13056', '2019-03-29 18:50:15', '41.880381', '', '-87.639507', '60661', 'Canal St & Monroe St (*)', '', 'Canal St & Monroe St (*)', 'IN_SERVICE', '1', 'In Service', 'False', '28']
# ['0', '35', '12', 'Chicago', '192', 'True', 'K3_FULL', '13011', '2019-03-29 18:50:35', '41.879255', '', '-87.639904', '60661', 'Canal St & Adams St', '', 'Canal St & Adams St', 'IN_SERVICE', '1', 'In Service', 'False', '47']
# ['0', '4', '7', 'Chicago', '193', 'True', 'K3_FULL', '13213', '2019-03-29 18:50:24', '41.841707', '', '-87.626938', '60616', 'State St & 29th St', '', 'State St & 29th St', 'IN_SERVICE', '1', 'In Service', 'False', '11']
# ['0', '1', '18', 'Chicago', '194', 'True', 'K3_FULL', '13339', '2019-03-29 18:53:40', '41.886875', '', '-87.62603', '60601', 'Wabash Ave & Wacker Pl', '', 'Wabash Ave & Wacker Pl', 'IN_SERVICE', '1', 'In Service', 'False', '19']
# ['0', '25', '30', 'Chicago', '195', 'True', 'K3_FULL', '13263', '2019-03-29 18:51:36', '41.884728', '', '-87.619521', '60601', 'Columbus Dr & Randolph St', '', 'Columbus Dr & Randolph St', 'IN_SERVICE', '1', 'In Service', 'False', '55']
# ['0', '4', '27', 'Chicago', '196', 'True', 'K3_FULL', '13427', '2019-03-29 18:51:42', '41.890573', '', '-87.622072', '60611', 'Cityfront Plaza Dr & Pioneer Ct', '', 'Cityfront Plaza Dr & Pioneer Ct', 'IN_SERVICE', '1', 'In Service', 'False', '31']
# ['0', '9', '10', 'Chicago', '197', 'True', 'K3_FULL', '13036', '2019-03-29 18:50:11', '41.882134', '', '-87.625125', '60602', 'Michigan Ave & Madison St', '', 'Michigan Ave & Madison St', 'IN_SERVICE', '1', 'In Service', 'False', '19']
# ['0', '20', '7', 'Chicago', '198', 'True', 'K3_FULL', '13159', '2019-03-29 18:50:33', '41.881892', '', '-87.648789', '60661', 'Green St & Madison St', '', 'Green St & Madison St', 'IN_SERVICE', '1', 'In Service', 'False', '27']
# ['0', '1', '30', 'Chicago', '199', 'True', 'K3_FULL', '13004', '2019-03-29 18:52:17', '41.891466', '', '-87.626761', '60611', 'Wabash Ave & Grand Ave', '', 'Wabash Ave & Grand Ave', 'IN_SERVICE', '1', 'In Service', 'False', '31']
# ['0', '1', '10', 'Chicago', '200', 'True', 'K3_FULL', '13090', '2019-03-29 18:52:47', '41.809851', '', '-87.616279', '60653', 'MLK Jr Dr & 47th St', '', 'MLK Jr Dr & 47th St', 'IN_SERVICE', '1', 'In Service', 'False', '11']
# ['0', '5', '6', 'Chicago', '201', 'True', 'K3_FULL', '13083', '2019-03-29 18:51:36', '41.82168', '', '-87.6216', '60653', 'Indiana Ave & 40th St', '', 'Indiana Ave & 40th St', 'IN_SERVICE', '1', 'In Service', 'False', '11']
# ['0', '6', '9', 'Chicago', '202', 'True', 'K3_FULL', '13099', '2019-03-29 18:54:09', '41.857499', '', '-87.646277', '60616', 'Halsted St & 18th St', '', 'Halsted St & 18th St', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '3', '12', 'Chicago', '203', 'True', 'K3_FULL', '13091', '2019-03-29 18:50:50', '41.854109', '', '-87.685838', '60608', 'Western Ave & 21st St', '', 'Western Ave & 21st St', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '1', '10', 'Chicago', '204', 'True', 'K3_FULL', '13101', '2019-03-29 18:53:22', '41.794853', '', '-87.618691', '60637', 'Prairie Ave & Garfield Blvd', '', 'Prairie Ave & Garfield Blvd', 'IN_SERVICE', '1', 'In Service', 'False', '11']
# ['0', '2', '13', 'Chicago', '205', 'True', 'K3_FULL', '13088', '2019-03-29 18:52:08', '41.857901', '', '-87.668745', '60608', 'Paulina St & 18th St', '', 'Paulina St & 18th St', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '4', '11', 'Chicago', '206', 'True', 'K3_FULL', '13098', '2019-03-29 18:52:52', '41.847203', '', '-87.646795', '60608', 'Halsted St & Archer Ave', '', 'Halsted St & Archer Ave', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '3', '12', 'Chicago', '207', 'True', 'K3_FULL', '13399', '2019-03-29 18:50:32', '41.84358', '', '-87.645368', '60616', 'Emerald Ave & 28th St', '', 'Emerald Ave & 28th St', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '12', '3', 'Chicago', '208', 'True', 'K3_FULL', '13307', '2019-03-29 18:53:47', '41.85381', '', '-87.665897', '60608', 'Ashland Ave & 21st St', '', 'Ashland Ave & 21st St', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '8', '3', 'Chicago', '209', 'True', 'K3_FULL', '13308', '2019-03-29 18:53:35', '41.849527', '', '-87.640591', '60616', 'Normal Ave & Archer Ave', '', 'Normal Ave & Archer Ave', 'IN_SERVICE', '1', 'In Service', 'False', '11']
# ['0', '8', '19', 'Chicago', '210', 'True', 'K3_FULL', '13061', '2019-03-29 18:51:14', '41.90345', '', '-87.667747', '60622', 'Ashland Ave & Division St', '', 'Ashland Ave & Division St', 'IN_SERVICE', '1', 'In Service', 'False', '27']
# ['0', '15', '4', 'Chicago', '211', 'True', 'K3_FULL', '13016', '2019-03-29 18:53:50', '41.894448', '', '-87.622663', '60611', 'St. Clair St & Erie St', '', 'St. Clair St & Erie St', 'IN_SERVICE', '1', 'In Service', 'False', '19']
# ['0', '10', '20', 'Chicago', '212', 'True', 'K3_FULL', '13264', '2019-03-29 18:53:41', '41.889906', '', '-87.634266', '60654', 'Wells St & Hubbard St', '', 'Wells St & Hubbard St', 'IN_SERVICE', '1', 'In Service', 'False', '31']
# ['0', '2', '13', 'Chicago', '213', 'True', 'K3_FULL', '13244', '2019-03-29 18:53:45', '41.910153', '', '-87.68229', '60622', 'Leavitt St & North Ave', '', 'Leavitt St & North Ave', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '12', '11', 'Chicago', '214', 'True', 'K3_FULL', '13141', '2019-03-29 18:52:11', '41.89122', '', '-87.67686', '60622', 'Damen Ave & Grand Ave', '', 'Damen Ave & Grand Ave', 'IN_SERVICE', '1', 'In Service', 'False', '23']
# ['0', '5', '10', 'Chicago', '215', 'True', 'K3_FULL', '13134', '2019-03-29 18:50:19', '41.88137', '', '-87.67493', '60612', 'Damen Ave & Madison St', '', 'Damen Ave & Madison St', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '14', '1', 'Chicago', '216', 'True', 'K3_FULL', '13256', '2019-03-29 18:53:12', '41.903029', '', '-87.697474', '60622', 'California Ave & Division St', '', 'California Ave & Division St', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '4', '11', 'Chicago', '217', 'True', 'K3_FULL', '13197', '2019-03-29 18:51:05', '41.886926', '', '-87.656919', '60607', 'Racine Ave (May St) & Fulton St', '', 'Racine Ave (May St) & Fulton St', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '5', '6', 'Chicago', '218', 'True', 'K3_FULL', '13180', '2019-03-29 18:52:25', '41.856802', '', '-87.633879', '60616', 'Wells St & 19th St', '', 'Wells St & 19th St', 'IN_SERVICE', '1', 'In Service', 'False', '11']
# ['0', '15', '4', 'Chicago', '219', 'True', 'K3_FULL', '13133', '2019-03-29 18:51:02', '41.915983', '', '-87.677335', '60622', 'Damen Ave & Cortland St', '', 'Damen Ave & Cortland St', 'IN_SERVICE', '1', 'In Service', 'False', '19']
# ...
# ['0', '1', '10', 'Chicago', '583', 'True', 'K3_FULL', '16975', '2019-03-29 18:52:13', '41.746559', '', '-87.586005', '60617', 'Stony Island Ave & 82nd St', '', 'Stony Island Ave & 82nd St', 'IN_SERVICE', '1', 'In Service', 'False', '11']
# ['0', '3', '8', 'Chicago', '584', 'True', 'K3_FULL', '16976', '2019-03-29 18:54:26', '41.744123', '', '-87.599034', '60619', 'Ellis Ave & 83rd St', '', 'Ellis Ave & 83rd St', 'IN_SERVICE', '1', 'In Service', 'False', '11']
# ['0', '4', '7', 'Chicago', '585', 'True', 'K3_FULL', '16977', '2019-03-29 18:51:13', '41.744053', '', '-87.604786', '60619', 'Cottage Grove Ave & 83rd St', '', 'Cottage Grove Ave & 83rd St', 'IN_SERVICE', '1', 'In Service', 'False', '11']
# ['0', '6', '5', 'Chicago', '586', 'True', 'K3_FULL', '16978', '2019-03-29 18:51:51', '41.743116', '', '-87.6148', '60619', 'MLK Jr Dr & 83rd St', '', 'MLK Jr Dr & 83rd St', 'IN_SERVICE', '1', 'In Service', 'False', '11']
# ['0', '4', '7', 'Chicago', '587', 'True', 'K3_FULL', '16979', '2019-03-29 18:50:19', '41.743316', '', '-87.622849', '60619', 'Wabash Ave & 83rd St', '', 'Wabash Ave & 83rd St', 'IN_SERVICE', '1', 'In Service', 'False', '11']
# ['0', '4', '7', 'Chicago', '588', 'True', 'K3_FULL', '16980', '2019-03-29 18:52:35', '41.743921', '', '-87.575225', '60617', 'South Chicago Ave & 83rd St', '', 'South Chicago Ave & 83rd St', 'IN_SERVICE', '1', 'In Service', 'False', '11']
# ['0', '7', '4', 'Chicago', '589', 'True', 'K3_FULL', '16991', '2019-03-29 18:51:32', '41.954468', '', '-87.749594', '60641', 'Milwaukee Ave & Cuyler Ave', '', 'Milwaukee Ave & Cuyler Ave', 'IN_SERVICE', '1', 'In Service', 'False', '11']
# ['0', '4', '7', 'Chicago', '590', 'True', 'K3_FULL', '16992', '2019-03-29 18:51:07', '41.953733', '', '-87.740569', '60641', 'Kilbourn Ave & Irving Park Rd', '', 'Kilbourn Ave & Irving Park Rd', 'IN_SERVICE', '1', 'In Service', 'False', '11']
# ['0', '7', '8', 'Chicago', '591', 'True', 'K3_FULL', '16994', '2019-03-29 18:50:41', '41.948818', '', '-87.74002', '60641', 'Kilbourn Ave & Milwaukee Ave', '', 'Kilbourn Ave & Milwaukee Ave', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '2', '9', 'Chicago', '592', 'True', 'K3_FULL', '16001', '2019-03-29 18:53:33', '41.960631', '', '-87.745359', '60641', 'Knox Ave & Montrose Ave', '', 'Knox Ave & Montrose Ave', 'IN_SERVICE', '1', 'In Service', 'False', '11']
# ['0', '5', '5', 'Chicago', '593', 'True', 'K3_FULL', '16005', '2019-03-29 18:51:01', '41.787539', '', '-87.644874', '60621', 'Halsted St & 59th St', '', 'Halsted St & 59th St', 'IN_SERVICE', '1', 'In Service', 'False', '11']
# ['0', '2', '9', 'Chicago', '594', 'True', 'K3_FULL', '16008', '2019-03-29 18:50:24', '41.805661', '', '-87.683392', '60609', 'Western Blvd & 48th Pl', '', 'Western Blvd & 48th Pl', 'IN_SERVICE', '1', 'In Service', 'False', '11']
# ['0', '4', '7', 'Chicago', '595', 'True', 'K3_FULL', '16009', '2019-03-29 18:51:58', '41.736646', '', '-87.622634', '60619', 'Wabash Ave & 87th St', '', 'Wabash Ave & 87th St', 'IN_SERVICE', '1', 'In Service', 'False', '11']
# ['0', '14', '1', 'Evanston', '596', 'True', 'K3_FULL', 'E001', '2019-03-29 18:50:31', '42.048214', '', '-87.683485', '0', 'Benson Ave & Church St', '', 'Benson Ave & Church St', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '0', '15', 'Evanston', '597', 'True', 'K3_FULL', 'E002', '2019-03-29 18:52:43', '42.032562', '', '-87.679101', '0', 'Chicago Ave & Washington St', '', 'Chicago Ave & Washington St', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '2', '13', 'Evanston', '598', 'True', 'K3_FULL', 'E003', '2019-03-29 18:53:20', '42.025784', '', '-87.684107', '60202', 'Elmwood Ave & Austin St', '', 'Elmwood Ave & Austin St', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '9', '6', 'Evanston', '599', 'True', 'K3_FULL', 'E004', '2019-03-29 18:50:42', '42.039742', '', '-87.699413', '60202', 'Valli Produce - Evanston Plaza', '', 'Valli Produce - Evanston Plaza', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '0', '15', 'Evanston', '600', 'True', 'K3_FULL', 'E005', '2019-03-29 18:53:58', '42.048308', '', '-87.698224', '0', 'Dodge Ave & Church St', '', 'Dodge Ave & Church St', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '9', '6', 'Evanston', '601', 'True', 'K3_FULL', 'E006', '2019-03-29 18:54:25', '42.063598', '', '-87.69873', '0', 'Central St Metra', '', 'Central St Metra', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '0', '15', 'Evanston', '602', 'True', 'K3_FULL', 'E007', '2019-03-29 18:53:07', '42.064313', '', '-87.686152', '60201', 'Central St & Girard Ave', '', 'Central St & Girard Ave', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '6', '8', 'Evanston', '603', 'True', 'K3_FULL', 'E008', '2019-03-29 18:50:21', '42.050491', '', '-87.677821', '60201', 'Chicago Ave & Sheridan Rd', '', 'Chicago Ave & Sheridan Rd', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '5', '10', 'Evanston', '604', 'True', 'K3_FULL', 'E009', '2019-03-29 18:50:10', '42.058239', '', '-87.677432', '60208', 'Sheridan Rd & Noyes St (NU)', '', 'Sheridan Rd & Noyes St (NU)', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '5', '10', 'Evanston', '605', 'True', 'K3_FULL', 'E010', '2019-03-29 18:52:24', '42.052939', '', '-87.673447', '60208', 'University Library (NU)', '', 'University Library (NU)', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '1', '10', 'Chicago', '619', 'True', 'K3_FULL', '16010', '2019-03-29 18:54:13', '41.924377', '', '-87.728231', '60639', 'Keystone Ave & Fullerton Ave', '', 'Keystone Ave & Fullerton Ave', 'IN_SERVICE', '1', 'In Service', 'False', '11']
# ['0', '4', '9', 'Chicago', '620', 'True', 'K3_FULL', '16011', '2019-03-29 18:53:44', '41.898203', '', '-87.637536', '60610', 'Orleans St & Chestnut St (NEXT Apts)', '', 'Orleans St & Chestnut St (NEXT Apts)', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '14', '0', 'Chicago', '621', 'True', 'K3_FULL', '18062', '2019-03-29 18:52:25', '41.884114', '', '-87.654264', '60607', 'Aberdeen St & Randolph St', '', 'Aberdeen St & Randolph St', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '7', '8', 'Chicago', '622', 'True', 'K3_FULL', '17660', '2019-03-29 18:54:11', '41.900363', '', '-87.696704', '60622', 'California Ave & Cortez St', '', 'California Ave & Cortez St', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '3', '40', 'Chicago', '623', 'True', 'K3_FULL', '17541', '2019-03-29 18:53:33', '41.872773', '', '-87.623981', '60605', 'Michigan Ave & 8th St', '', 'Michigan Ave & 8th St', 'IN_SERVICE', '1', 'In Service', 'False', '43']
# ['0', '4', '12', 'Chicago', '624', 'True', 'K3_FULL', '17013', '2019-03-29 18:52:04', '41.876268', '417 S Dearborn St', '-87.629155', '60605', 'Dearborn St & Van Buren St (*)', '', 'Dearborn St & Van Buren St (*)', 'IN_SERVICE', '1', 'In Service', 'False', '16']
# ['0', '8', '7', 'Evanston', '625', 'True', 'K3_FULL', 'E011', '2019-03-29 18:52:40', '42.041691', '', '-87.680687', '60201', 'Chicago Ave & Dempster St', '1312 Chicago Ave', 'Chicago Ave & Dempster St', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '3', '15', 'Chicago', '626', 'True', 'K3_FULL', '17043', '2019-03-29 18:53:17', '41.867491', '', '-87.63219', '60605', 'Delano Ct & Roosevelt Rd', 'Roosevelt Collection Shops', 'Delano Ct & Roosevelt Rd', 'IN_SERVICE', '1', 'In Service', 'False', '19']
# ['0', '19', '1', 'Chicago', '627', 'True', 'K3_FULL', '18064', '2019-03-29 18:50:31', '41.894877', '', '-87.632326', '60654', 'LaSalle Dr & Huron St(*)', '', 'LaSalle Dr & Huron St (*)', 'IN_SERVICE', '1', 'In Service', 'False', '20']
# ['0', '7', '16', 'Chicago', '628', 'True', 'K3_FULL', '18067', '2019-03-29 18:53:16', '41.91461', 'Off-Street', '-87.667968', '60622', 'Walsh Park', 'Walsh Park', 'Walsh Park', 'IN_SERVICE', '1', 'In Service', 'False', '23']
# ['0', '5', '10', 'Chicago', '630', 'True', 'K3_FULL', '18015', '2019-03-29 18:52:20', '41.96108', 'On-Street', '-87.73569', '60630', 'Kildare Ave & Montrose Ave', '', 'Kildare Ave & Montrose Ave', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '2', '17', 'Chicago', '631', 'True', 'K3_FULL', '18045', '2019-03-29 18:50:23', '41.877618', '', '-87.673895', '60612', 'Malcolm X College', '', 'Malcolm X College', 'IN_SERVICE', '1', 'In Service', 'False', '19']
# ['0', '10', '5', 'Chicago', '632', 'True', 'K3_FULL', '18001', '2019-03-29 18:50:08', '41.94454', '', '-87.654678', '60657', 'Clark St & Newport St', '', 'Clark St & Newport St', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '0', '12', 'Chicago', '635', 'True', 'K3_FULL', '18003', '2019-03-29 18:52:54', '41.895748', '', '-87.620104', '60611', 'Fairbanks St & Superior St (*)', '', 'Fairbanks St & Superior St (*)', 'IN_SERVICE', '1', 'In Service', 'False', '12']
# ['0', '7', '5', 'Chicago', '636', 'True', 'K3_FULL', '18005', '2019-03-29 18:52:29', '41.890028', '', '-87.636618', '60654', 'Orleans St & Hubbard St (*)', '', 'Orleans St & Hubbard St (*)', 'IN_SERVICE', '1', 'In Service', 'False', '12']
# ['0', '7', '9', 'Chicago', '637', 'True', 'K3_FULL', '18006', '2019-03-29 18:52:33', '41.895634', '', '-87.672069', '60622', 'Wood St & Chicago Ave (*)', '', 'Wood St & Chicago Ave (*)', 'IN_SERVICE', '1', 'In Service', 'False', '16']
# ['0', '23', '9', 'Chicago', '638', 'True', 'K3_FULL', '18012', '2019-03-29 18:51:47', '41.878419', '', '-87.640977', '60661', 'Clinton St & Jackson Blvd (*)', '', 'Clinton St & Jackson Blvd (*)', 'IN_SERVICE', '1', 'In Service', 'False', '32']
# ['0', '14', '1', 'Chicago', '639', 'True', 'K3_FULL', '18014', '2019-03-29 18:51:37', '41.965845', '', '-87.645361', '60640', 'Lakefront Trail & Wilson Ave', '', 'Lakefront Trail & Wilson Ave', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '0', '11', 'Chicago', '640', 'True', 'K3_FULL', '18016', '2019-03-29 18:53:57', '41.949923', '', '-87.713949', '60618', 'Bernard St & Elston Ave', '', 'Bernard St & Elston Ave', 'IN_SERVICE', '1', 'In Service', 'False', '11']
# ['0', '9', '2', 'Chicago', '641', 'True', 'K3_FULL', '18017', '2019-03-29 18:52:54', '41.914166', '', '-87.716755', '60647', 'Central Park Ave & Bloomingdale Ave', '', 'Central Park Ave & Bloomingdale Ave', 'IN_SERVICE', '1', 'In Service', 'False', '11']
# ['0', '5', '2', 'Chicago', '642', 'True', 'K3_FULL', '18018', '2019-03-29 18:54:18', '41.894745', '', '-87.756895', '60644', 'Latrobe Ave & Chicago Ave', '', 'Latrobe Ave & Chicago Ave', 'IN_SERVICE', '1', 'In Service', 'False', '7']
# ['0', '7', '9', 'Chicago', '643', 'True', 'K3_FULL', '18019', '2019-03-29 18:53:11', '41.892048', '', '-87.689397', '60612', 'Smith Park (*)', '', 'Smith Park (*)', 'IN_SERVICE', '1', 'In Service', 'False', '16']
# ['0', '10', '2', 'Chicago', '644', 'True', 'K3_FULL', '18021', '2019-03-29 18:51:43', '41.868563', '', '-87.686234', '60612', 'Western Ave & Fillmore St (*)', '', 'Western Ave & Fillmore St (*)', 'IN_SERVICE', '1', 'In Service', 'False', '12']
# ['0', '2', '10', 'Chicago', '645', 'True', 'K3_FULL', '18022', '2019-03-29 18:52:02', '41.826712', '', '-87.683144', '60609', 'Archer (Damen) Ave & 37th St (*)', '', 'Archer (Damen) Ave & 37th St (*)', 'IN_SERVICE', '1', 'In Service', 'False', '12']
# ['0', '1', '10', 'Chicago', '646', 'True', 'K3_FULL', '18023', '2019-03-29 18:52:33', '41.796642', '', '-87.625923', '60609', 'State St & 54th St', '', 'State St & 54th St', 'IN_SERVICE', '1', 'In Service', 'False', '11']
# ['0', '3', '4', 'Chicago', '647', 'True', 'K3_FULL', '18024', '2019-03-29 18:52:24', '41.786691', '', '-87.655859', '60636', 'Elizabeth St & 59th St', '', 'Elizabeth St & 59th St', 'IN_SERVICE', '1', 'In Service', 'False', '7']
# ['0', '3', '4', 'Chicago', '648', 'True', 'K3_FULL', '18025', '2019-03-29 18:51:25', '41.77987', '', '-87.650919', '60621', 'Carpenter St & 63rd St', '', 'Carpenter St & 63rd St', 'IN_SERVICE', '1', 'In Service', 'False', '7']
# ['0', '4', '8', 'Chicago', '649', 'True', 'K3_FULL', '18026', '2019-03-29 18:54:17', '41.779835', '', '-87.634774', '60621', 'Stewart Ave & 63rd St (*)', '', 'Stewart Ave & 63rd St (*)', 'IN_SERVICE', '1', 'In Service', 'False', '12']
# ['0', '4', '8', 'Chicago', '650', 'True', 'K3_FULL', '18027', '2019-03-29 18:52:27', '41.768898', '', '-87.635876', '60621', 'Eggleston Ave & 69th St (*)', '', 'Eggleston Ave & 69th St (*)', 'IN_SERVICE', '1', 'In Service', 'False', '12']
# ['0', '3', '4', 'Chicago', '651', 'True', 'K3_FULL', '18028', '2019-03-29 18:50:52', '41.765286', '', '-87.621748', '60619', 'Michigan Ave & 71st St', '', 'Michigan Ave & 71st St', 'IN_SERVICE', '1', 'In Service', 'False', '7']
# ['0', '3', '8', 'Chicago', '652', 'True', 'K3_FULL', '18029', '2019-03-29 18:53:43', '41.766', '', '-87.611726', '60637', 'Rhodes Ave & 71st St', '', 'Rhodes Ave & 71st St', 'IN_SERVICE', '1', 'In Service', 'False', '11']
# ['0', '4', '6', 'Chicago', '653', 'True', 'K3_FULL', '18030', '2019-03-29 18:52:30', '41.780595', '', '-87.584846', '60649', 'Cornell Dr & Hayes Dr', '', 'Cornell Dr & Hayes Dr', 'IN_SERVICE', '1', 'In Service', 'False', '11']
# ['0', '9', '3', 'Chicago', '654', 'True', 'K3_FULL', '18046', '2019-03-29 18:51:34', '41.883073', '', '-87.656952', '60607', 'Racine Ave & Washington Blvd (*)', '', 'Racine Ave & Washington Blvd (*)', 'IN_SERVICE', '1', 'In Service', 'False', '12']
# ['0', '4', '11', 'Chicago', '655', 'True', 'K3_FULL', '18047', '2019-03-29 18:52:54', '41.979851', '', '-87.681932', '60625', 'Hoyne Ave & Balmoral Ave', '', 'Hoyne Ave & Balmoral Ave', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '1', '15', 'Chicago', '656', 'True', 'K3_FULL', '18054', '2019-03-29 18:50:19', '41.885951', '', '-87.677009', '60612', 'Damen Ave & Walnut (Lake) St (*)', '', 'Damen Ave & Walnut (Lake) St (*)', 'IN_SERVICE', '1', 'In Service', 'False', '16']
# ['0', '6', '9', 'Chicago', '657', 'True', 'K3_FULL', '18056', '2019-03-29 18:51:38', '41.899181', '', '-87.6722', '60622', 'Wood St & Augusta Blvd', '', 'Wood St & Augusta Blvd', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '11', '5', 'Chicago', '658', 'True', 'K3_FULL', '18057', '2019-03-29 18:51:35', '41.902997', '', '-87.683825', '60622', 'Leavitt St & Division St (*)', '', 'Leavitt St & Division St (*)', 'IN_SERVICE', '1', 'In Service', 'False', '16']
# ['0', '8', '7', 'Chicago', '659', 'True', 'K3_FULL', '18058', '2019-03-29 18:50:05', '41.895501', '', '-87.682017', '60612', 'Leavitt St & Chicago Ave', '', 'Leavitt St & Chicago Ave', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '12', '3', 'Chicago', '660', 'True', 'K3_FULL', '18066', '2019-03-29 18:54:06', '42.004583', '', '-87.661406', '60626', 'Sheridan Rd & Columbia Ave', '', 'Sheridan Rd & Columbia Ave', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '6', '9', 'Evanston', '661', 'True', 'K3_FULL', 'E012', '2019-03-29 18:51:00', '42.057044', '', '-87.686554', '60201', 'Evanston Civic Center', '', 'Evanston Civic Center', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '5', '10', 'Evanston', '662', 'True', 'K3_FULL', 'E013', '2019-03-29 18:50:14', '42.023463', '', '-87.699595', '60201', 'Dodge Ave & Mulford St', '', 'Dodge Ave & Mulford St', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '11', '4', 'Evanston', '663', 'True', 'K3_FULL', 'E014', '2019-03-29 18:50:46', '42.064854', '', '-87.715297', '60201', 'Lincolnwood Dr & Central St', '', 'Lincolnwood Dr & Central St', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '11', '5', 'Chicago', '664', 'True', 'K3_FULL', '18068', '2019-03-29 18:51:22', '41.939354', '', '-87.683282', '60618', 'Leavitt St & Belmont Ave (*)', '', 'Leavitt St & Belmont Ave (*)', 'IN_SERVICE', '1', 'In Service', 'False', '16']
# ['0', '3', '4', 'Chicago', '665', 'True', 'K3_FULL', '19031', '2019-03-29 18:50:34', '41.747363', '', '-87.580046', '60617', 'South Chicago Ave & Elliot Ave', '', 'South Chicago Ave & Elliot Ave', 'IN_SERVICE', '1', 'In Service', 'False', '7']

# %%
with open('divvy_stations_logs.csv', 'r') as f:
    reader = csv.reader(f)
    next(reader)  # Skip the header row.
    for row in reader:
        print(row)
        cursor.execute(
                "INSERT INTO divvy_stations_logs VALUES (%s, %s, %s, %s, %s,    %s, %s, %s, %s,%s,   %s, %s, %s, %s,%s,   %s, %s, %s, %s,%s,  %s, NULL)",
                row)
# Out:
# ['0', '9', '29', 'Chicago', '2', 'True', 'K3_FULL', '15541', '2019-03-29 18:50:37', '41.87647', '', '-87.62034', '60605', 'Buckingham Fountain', '', 'Buckingham Fountain', 'IN_SERVICE', '1', 'In Service', 'False', '38']
# ['0', '1', '54', 'Chicago', '3', 'True', 'K3_FULL', '15544', '2019-03-29 18:52:18', '41.86722595682', '', '-87.6153553902', '0', 'Shedd Aquarium', '', 'Shedd Aquarium', 'IN_SERVICE', '1', 'In Service', 'False', '55']
# ['0', '3', '19', 'Chicago', '4', 'True', 'K3_FULL', '15545', '2019-03-29 18:52:24', '41.856268', '', '-87.613348', '0', 'Burnham Harbor', '', 'Burnham Harbor', 'IN_SERVICE', '1', 'In Service', 'False', '23']
# ['0', '6', '17', 'Chicago', '5', 'True', 'K3_FULL', '13030', '2019-03-29 18:52:38', '41.874053', '620 S. State St.', '-87.627716', '60605', 'State St & Harrison St', '', 'State St & Harrison St', 'IN_SERVICE', '1', 'In Service', 'False', '23']
# ['0', '4', '35', 'Chicago', '6', 'True', 'K3_FULL', '15548', '2019-03-29 18:54:19', '41.886976', '', '-87.612813', '60601', 'Dusable Harbor', '', 'Dusable Harbor', 'IN_SERVICE', '1', 'In Service', 'False', '39']
# ['0', '7', '12', 'Chicago', '7', 'True', 'K3_FULL', '15534', '2019-03-29 18:51:08', '41.88634906269', '', '-87.6175165471', '60601', 'Field Blvd & South Water St', '', 'Field Blvd & South Water St', 'IN_SERVICE', '1', 'In Service', 'False', '19']
# ['0', '2', '13', 'Chicago', '9', 'True', 'K3_FULL', '15695', '2019-03-29 18:54:22', '41.82879201994', 'NA1', '-87.6806044594', '60609', 'Leavitt St & Archer Ave', '', 'Leavitt St & Archer Ave', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '1', '10', 'Chicago', '11', 'True', 'K3_FULL', '15496', '2019-03-29 18:52:09', '41.76663823695', '', '-87.5764501141', '60649', 'Jeffery Blvd & 71st St', '', 'Jeffery Blvd & 71st St', 'IN_SERVICE', '1', 'In Service', 'False', '11']
# ['0', '3', '12', 'Chicago', '12', 'True', 'K3_FULL', '15497', '2019-03-29 18:51:47', '41.7664094567', 'MLSW', '-87.5656875719', '60649', 'South Shore Dr & 71st St', '', 'South Shore Dr & 71st St', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '11', '24', 'Chicago', '13', 'True', 'K3_FULL', '13066', '2019-03-29 18:52:16', '41.932418', '2790 N.Wilton Ave', '-87.652705', '60614', 'Wilton Ave & Diversey Pkwy', '', 'Wilton Ave & Diversey Pkwy', 'IN_SERVICE', '1', 'In Service', 'False', '35']
# ['0', '6', '9', 'Chicago', '14', 'True', 'K3_FULL', '13163', '2019-03-29 18:53:48', '41.858086', '962 W. 18th St', '-87.651073', '60608', 'Morgan St & 18th St', '', 'Morgan St & 18th St', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '6', '9', 'Chicago', '15', 'True', 'K3_FULL', '13164', '2019-03-29 18:54:13', '41.858166', '1726 S Racine Ave', '-87.656495', '60608', 'Racine Ave & 18th St', '', 'Racine Ave & 18th St', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '4', '11', 'Chicago', '16', 'True', 'K3_FULL', '13223', '2019-03-29 18:54:22', '41.910337', '1575 N Paulina Ave', '-87.670072', '60622', 'Paulina Ave & North Ave', '', 'Paulina Ave & North Ave', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '10', '12', 'Chicago', '17', 'True', 'K3_FULL', '13246', '2019-03-29 18:54:23', '41.903119', ' W. Divison St', '-87.673935', '60622', 'Honore St & Division St', '', 'Honore St & Division St', 'IN_SERVICE', '1', 'In Service', 'False', '23']
# ['0', '0', '19', 'Chicago', '18', 'True', 'K3_FULL', '15536', '2019-03-29 18:50:31', '41.883132', '', '-87.637321', '60606', 'Wacker Dr & Washington St', '', 'Wacker Dr & Washington St', 'IN_SERVICE', '1', 'In Service', 'False', '19']
# ['0', '5', '11', 'Chicago', '19', 'True', 'K3_FULL', '13139', '2019-03-29 18:54:22', '41.868968', '', '-87.659141', '60607', 'Loomis St & Taylor St (*)', '', 'Loomis St & Taylor St (*)', 'IN_SERVICE', '1', 'In Service', 'False', '16']
# ['0', '8', '7', 'Chicago', '20', 'True', 'K3_FULL', '13154', '2019-03-29 18:53:44', '41.910522', '', '-87.653106', '60642', 'Sheffield Ave & Kingsbury St', '', 'Sheffield Ave & Kingsbury St', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '15', '8', 'Chicago', '21', 'True', 'K3_FULL', '13157', '2019-03-29 18:53:50', '41.87772613', '1103 W.Jackson Blvd', '-87.65478743', '60607', 'Aberdeen St & Jackson Blvd', '', 'Aberdeen St & Jackson Blvd', 'IN_SERVICE', '1', 'In Service', 'False', '23']
# ['0', '4', '11', 'Chicago', '22', 'True', 'K3_FULL', '13160', '2019-03-29 18:54:24', '41.8694821', '1134 W. Taylor St', '-87.6554864', '60607', 'May St & Taylor St', '', 'May St & Taylor St', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '6', '10', 'Chicago', '23', 'True', 'K3_FULL', '13172', '2019-03-29 18:53:13', '41.902924', '350 W. Elm st', '-87.637715', '60610', 'Orleans St & Elm St (*)', '', 'Orleans St & Elm St (*)', 'IN_SERVICE', '1', 'In Service', 'False', '16']
# ['0', '10', '5', 'Chicago', '24', 'True', 'K3_FULL', '13262', '2019-03-29 18:51:52', '41.89186', '240 E.Grand Ave.', '-87.62062', '60611', 'Fairbanks Ct & Grand Ave', '', 'Fairbanks Ct & Grand Ave', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '18', '5', 'Chicago', '25', 'True', 'K3_FULL', '13034', '2019-03-29 18:50:32', '41.89766', '150 E.Pearson st', '-87.62351', '60611', 'Michigan Ave & Pearson St', '', 'Michigan Ave & Pearson St', 'IN_SERVICE', '1', 'In Service', 'False', '23']
# ['0', '31', '0', 'Chicago', '26', 'True', 'K3_FULL', '13051', '2019-03-29 18:52:31', '41.890359', '', '-87.617532', '60611', 'McClurg Ct & Illinois St', '', 'McClurg Ct & Illinois St', 'IN_SERVICE', '1', 'In Service', 'False', '31']
# ['0', '6', '13', 'Chicago', '27', 'True', 'K3_FULL', '13174', '2019-03-29 18:50:25', '41.91021', '1530 N.Larrabee st', '-87.6435', '60610', 'Larrabee St & North Ave', '', 'Larrabee St & North Ave', 'IN_SERVICE', '1', 'In Service', 'False', '19']
# ['0', '6', '9', 'Chicago', '28', 'True', 'K3_FULL', '13282', '2019-03-29 18:52:00', '41.91468', '590 W. Menomonee', '-87.64332', '60614', 'Larrabee St & Menomonee St', '', 'Larrabee St & Menomonee St', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '2', '13', 'Chicago', '29', 'True', 'K3_FULL', '13290', '2019-03-29 18:50:40', '41.90068', '1016 N. Noble St', '-87.6626', '60642', 'Noble St & Milwaukee Ave', '', 'Noble St & Milwaukee Ave', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '11', '4', 'Chicago', '30', 'True', 'K3_FULL', '13248', '2019-03-29 18:50:49', '41.899643', '1611 W. Augusta Blvd', '-87.6677', '60642', 'Ashland Ave & Augusta Blvd', '', 'Ashland Ave & Augusta Blvd', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '3', '20', 'Chicago', '31', 'True', 'K3_FULL', '13017', '2019-03-29 18:52:03', '41.896776', '805 N. Franklin St', '-87.635633', '60654', 'Franklin St & Chicago Ave', '', 'Franklin St & Chicago Ave', 'IN_SERVICE', '1', 'In Service', 'False', '23']
# ['0', '4', '15', 'Chicago', '32', 'True', 'K3_FULL', '13076', '2019-03-29 18:51:19', '41.87464', '550 S. Racine', '-87.65703', '60607', 'Racine Ave & Congress Pkwy', '', 'Racine Ave & Congress Pkwy', 'IN_SERVICE', '1', 'In Service', 'False', '19']
# ['0', '0', '27', 'Chicago', '33', 'True', 'K3_FULL', '13003', '2019-03-29 18:53:48', '41.877181', '360 S State St', '-87.627844', '60604', 'State St & Van Buren St', '', 'State St & Van Buren St', 'IN_SERVICE', '1', 'In Service', 'False', '27']
# ['0', '7', '7', 'Chicago', '34', 'True', 'K3_FULL', '13124', '2019-03-29 18:53:22', '41.9267559875', '2432 N. Cannon Dr.', '-87.6344287848', '60614', 'Cannon Dr & Fullerton Ave', '', 'Cannon Dr & Fullerton Ave', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '9', '38', 'Chicago', '35', 'True', 'K3_FULL', '13022', '2019-03-29 18:54:26', '41.892278', 'Navy Pier', '-87.612043', '60611', 'Streeter Dr & Grand Ave', '', 'Streeter Dr & Grand Ave', 'IN_SERVICE', '1', 'In Service', 'False', '47']
# ['0', '5', '33', 'Chicago', '36', 'True', 'K3_FULL', '13019', '2019-03-29 18:52:12', '41.8777079559', '340 S. Franklin St', '-87.6353211408', '60606', 'Franklin St & Jackson Blvd', '', 'Franklin St & Jackson Blvd', 'IN_SERVICE', '1', 'In Service', 'False', '39']
# ['0', '1', '18', 'Chicago', '37', 'True', 'K3_FULL', '13020', '2019-03-29 18:52:48', '41.8793563587', '59 W. Adams St ', '-87.6297910363', '60603', 'Dearborn St & Adams St', '', 'Dearborn St & Adams St', 'IN_SERVICE', '1', 'In Service', 'False', '19']
# ['0', '9', '18', 'Chicago', '38', 'True', 'K3_FULL', '15547', '2019-03-29 18:52:09', '41.88602082773', '', '-87.6308760584', '60601', 'Clark St & Lake St', '', 'Clark St & Lake St', 'IN_SERVICE', '1', 'In Service', 'False', '27']
# ['0', '11', '12', 'Chicago', '39', 'True', 'K3_FULL', '15538', '2019-03-29 18:51:10', '41.87947235235', '', '-87.6256886059', '60603', 'Wabash Ave & Adams St', '', 'Wabash Ave & Adams St', 'IN_SERVICE', '1', 'In Service', 'False', '23']
# ['0', '1', '13', 'Chicago', '40', 'True', 'K3_FULL', '15537', '2019-03-29 18:50:43', '41.87934437346', '', '-87.6319852213', '60603', 'LaSalle St & Adams St', '', 'LaSalle St & Adams St', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '12', '6', 'Chicago', '41', 'True', 'K3_FULL', '15543', '2019-03-29 18:50:13', '41.87207763285', '', '-87.6295437729', '60605', 'Federal St & Polk St', '', 'Federal St & Polk St', 'IN_SERVICE', '1', 'In Service', 'False', '19']
# ['0', '9', '2', 'Chicago', '42', 'True', 'K3_FULL', '13170', '2019-03-29 18:53:30', '41.852619', '13 E Cermak Rd', '-87.626488', '60616', 'Wabash Ave & Cermak Rd', 'CTA Green Line - Cermak Stop', 'Wabash Ave & Cermak Rd', 'IN_SERVICE', '1', 'In Service', 'False', '11']
# ['0', '10', '33', 'Chicago', '43', 'True', 'K3_FULL', '13001', '2019-03-29 18:54:13', '41.8838927658', '120 N Michigan', '-87.6246491409', '60602', 'Michigan Ave & Washington St', '', 'Michigan Ave & Washington St', 'IN_SERVICE', '1', 'In Service', 'False', '43']
# ['0', '17', '10', 'Chicago', '44', 'True', 'K3_FULL', '13002', '2019-03-29 18:52:02', '41.8847302006', '', '-87.6277335692', '60601', 'State St & Randolph St', '', 'State St & Randolph St', 'IN_SERVICE', '1', 'In Service', 'False', '27']
# ['0', '0', '15', 'Chicago', '45', 'True', 'K3_FULL', '13040', '2019-03-29 18:54:18', '41.876243', '420 w. Michigan', '-87.624426', '60605', 'Michigan Ave & Ida B Wells Dr', '', 'Michigan Ave & Ida B Wells Dr', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '15', '4', 'Chicago', '46', 'True', 'K3_FULL', '13046', '2019-03-29 18:53:14', '41.89993001', '932 N Wells St', '-87.63443007', '60610', 'Wells St & Walton St', '', 'Wells St & Walton St', 'IN_SERVICE', '1', 'In Service', 'False', '19']
# ['0', '5', '26', 'Chicago', '47', 'True', 'K3_FULL', '13050', '2019-03-29 18:52:49', '41.889187', '5 E Kinzie St', '-87.627754', '60654', 'State St & Kinzie St', '', 'State St & Kinzie St', 'IN_SERVICE', '1', 'In Service', 'False', '31']
# ['0', '5', '38', 'Chicago', '48', 'True', 'K3_FULL', '13012', '2019-03-29 18:54:17', '41.897764', '840 N Larrabee St', '-87.642884', '60610', 'Larrabee St & Kingsbury St', '', 'Larrabee St & Kingsbury St', 'IN_SERVICE', '1', 'In Service', 'False', '43']
# ['0', '19', '18', 'Chicago', '49', 'True', 'K3_FULL', '13049', '2019-03-29 18:52:53', '41.881319815', '80 S Dearborn St', '-87.6295209193', '60603', 'Dearborn St & Monroe St', '', 'Dearborn St & Monroe St', 'IN_SERVICE', '1', 'In Service', 'False', '39']
# ['0', '11', '24', 'Chicago', '50', 'True', 'K3_FULL', '13009', '2019-03-29 18:54:20', '41.8759326655', '', '-87.6305845355', '60605', 'Clark St & Ida B Wells Dr', '', 'Clark St & Ida B Wells Dr', 'IN_SERVICE', '1', 'In Service', 'False', '35']
# ['0', '14', '25', 'Chicago', '51', 'True', 'K3_FULL', '13005', '2019-03-29 18:52:42', '41.884576228', '120 W. Randolph St.', '-87.63188991', '60601', 'Clark St & Randolph St', '', 'Clark St & Randolph St', 'IN_SERVICE', '1', 'In Service', 'False', '39']
# ['0', '2', '33', 'Chicago', '52', 'True', 'K3_FULL', '13043', '2019-03-29 18:51:24', '41.886024', '203 N Michigan Ave', '-87.624117', '60601', 'Michigan Ave & Lake St', '', 'Michigan Ave & Lake St', 'IN_SERVICE', '1', 'In Service', 'False', '35']
# ['0', '14', '12', 'Chicago', '53', 'True', 'K3_FULL', '13064', '2019-03-29 18:54:26', '41.894722', '', '-87.634362', '60654', 'Wells St & Huron St', '', 'Wells St & Huron St', 'IN_SERVICE', '1', 'In Service', 'False', '27']
# ['0', '10', '8', 'Chicago', '54', 'True', 'K3_FULL', '13044', '2019-03-29 18:50:47', '41.896362458', '1040 W. Chicago Ave.', '-87.6540612729', '60642', 'Ogden Ave & Chicago Ave', '', 'Ogden Ave & Chicago Ave', 'IN_SERVICE', '1', 'In Service', 'False', '19']
# ['0', '0', '23', 'Chicago', '55', 'True', 'K3_FULL', '13166', '2019-03-29 18:52:33', '41.867324', '850 W Roosevelt Rd', '-87.648625', '60608', 'Halsted St & Roosevelt Rd', '', 'Halsted St & Roosevelt Rd', 'IN_SERVICE', '1', 'In Service', 'False', '23']
# ['0', '6', '20', 'Chicago', '56', 'True', 'K3_FULL', '13039', '2019-03-29 18:52:05', '41.888716036', '368 N. Desplaines St.', '-87.6444478533', '60661', 'Desplaines St & Kinzie St', '', 'Desplaines St & Kinzie St', 'IN_SERVICE', '1', 'In Service', 'False', '27']
# ['0', '12', '3', 'Chicago', '57', 'True', 'K3_FULL', '13327', '2019-03-29 18:53:27', '41.8671177825', '559 W Roosevelt Rd', '-87.6410879593', '60607', 'Clinton St & Roosevelt Rd', '', 'Clinton St & Roosevelt Rd', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '0', '23', 'Chicago', '58', 'True', 'K3_FULL', '13025', '2019-03-29 18:52:12', '41.916017', '', '-87.668879', '60622', 'Marshfield Ave & Cortland St', '', 'Marshfield Ave & Cortland St', 'IN_SERVICE', '1', 'In Service', 'False', '23']
# ['0', '14', '9', 'Chicago', '59', 'True', 'K3_FULL', '13031', '2019-03-29 18:52:35', '41.867227', '1210 S Wabash Ave', '-87.625961', '60605', 'Wabash Ave & Roosevelt Rd', '', 'Wabash Ave & Roosevelt Rd', 'IN_SERVICE', '1', 'In Service', 'False', '23']
# ['0', '13', '6', 'Chicago', '60', 'True', 'K3_FULL', '13058', '2019-03-29 18:54:19', '41.9105780349', '1575 N Dayton St', '-87.6494219288', '60642', 'Dayton St & North Ave', '', 'Dayton St & North Ave', 'IN_SERVICE', '1', 'In Service', 'False', '19']
# ['0', '13', '6', 'Chicago', '61', 'True', 'K3_FULL', '13221', '2019-03-29 18:51:25', '41.907655', '1416 N Wood St', '-87.672552', '60622', 'Wood St & Milwaukee Ave', '', 'Wood St & Milwaukee Ave', 'IN_SERVICE', '1', 'In Service', 'False', '19']
# ['0', '9', '18', 'Chicago', '62', 'True', 'K3_FULL', '13106', '2019-03-29 18:51:20', '41.8513751729', '2253 S Dr Martin Luther King Jr Dr', '-87.6188346489', '60616', 'McCormick Place', '', 'McCormick Place', 'IN_SERVICE', '1', 'In Service', 'False', '27']
# ['0', '8', '15', 'Chicago', '66', 'True', 'K3_FULL', '13021', '2019-03-29 18:50:39', '41.885637', '', '-87.641823', '60661', 'Clinton St & Lake St', '', 'Clinton St & Lake St', 'IN_SERVICE', '1', 'In Service', 'False', '23']
# ['0', '2', '25', 'Chicago', '67', 'True', 'K3_FULL', '13060', '2019-03-29 18:52:58', '41.9256018819', '2410 N Sheffield Ave', '-87.6537080423', '60614', 'Sheffield Ave & Fullerton Ave', '', 'Sheffield Ave & Fullerton Ave', 'IN_SERVICE', '1', 'In Service', 'False', '27']
# ['0', '5', '17', 'Chicago', '68', 'True', 'K3_FULL', '13037', '2019-03-29 18:51:59', '41.875885', '520 W Tilden St', '-87.640795', '60607', 'Clinton St & Tilden St', '', 'Clinton St & Tilden St', 'IN_SERVICE', '1', 'In Service', 'False', '23']
# ['0', '16', '7', 'Chicago', '69', 'True', 'K3_FULL', '13065', '2019-03-29 18:51:01', '41.9093960065', '2002 W Pierce Ave', '-87.6776919292', '60622', 'Damen Ave & Pierce Ave', '', 'Damen Ave & Pierce Ave', 'IN_SERVICE', '1', 'In Service', 'False', '23']
# ['0', '17', '6', 'Chicago', '71', 'True', 'K3_FULL', '13072', '2019-03-29 18:53:49', '41.8854833079', '1003 W. Lake St.', '-87.6523048564', '60607', 'Morgan St & Lake St', '', 'Morgan St & Lake St', 'IN_SERVICE', '1', 'In Service', 'False', '23']
# ['0', '27', '12', 'Chicago', '72', 'True', 'K3_FULL', '13148', '2019-03-29 18:53:21', '41.860384', '1590 S Wabash Ave', '-87.625813', '60605', 'Wabash Ave & 16th St', '', 'Wabash Ave & 16th St', 'IN_SERVICE', '1', 'In Service', 'False', '39']
# ['0', '1', '18', 'Chicago', '73', 'True', 'K3_FULL', '13038', '2019-03-29 18:52:08', '41.880422', '207 S Jefferson St', '-87.642746', '60661', 'Jefferson St & Monroe St', '', 'Jefferson St & Monroe St', 'IN_SERVICE', '1', 'In Service', 'False', '19']
# ['0', '22', '1', 'Chicago', '74', 'True', 'K3_FULL', '13265', '2019-03-29 18:52:29', '41.893626', '511 W Erie St', '-87.641527', '60654', 'Kingsbury St & Erie St', '', 'Kingsbury St & Erie St', 'IN_SERVICE', '1', 'In Service', 'False', '23']
# ['0', '2', '36', 'Chicago', '75', 'True', 'K3_FULL', '13138', '2019-03-29 18:51:59', '41.877245', '', '-87.639366', '60661', 'Canal St & Jackson Blvd', '', 'Canal St & Jackson Blvd', 'IN_SERVICE', '1', 'In Service', 'False', '39']
# ['0', '8', '31', 'Chicago', '76', 'True', 'K3_FULL', '13300', '2019-03-29 18:52:20', '41.880958', '402 E Monroe St', '-87.616743', '60603', 'Lake Shore Dr & Monroe St', '', 'Lake Shore Dr & Monroe St', 'IN_SERVICE', '1', 'In Service', 'False', '39']
# ['0', '6', '24', 'Chicago', '77', 'True', 'K3_FULL', '13301', '2019-03-29 18:51:46', '41.882242', '5 N Clinton St', '-87.641066', '60661', 'Clinton St & Madison St', '', 'Clinton St & Madison St', 'IN_SERVICE', '1', 'In Service', 'False', '31']
# ['0', '7', '12', 'Chicago', '80', 'True', 'K3_FULL', '13156', '2019-03-29 18:50:31', '41.880419', '', '-87.655519', '60607', 'Aberdeen St & Monroe St', '', 'Aberdeen St & Monroe St', 'IN_SERVICE', '1', 'In Service', 'False', '19']
# ['0', '1', '38', 'Chicago', '81', 'True', 'K3_FULL', '13023', '2019-03-29 18:50:49', '41.884241', '', '-87.629634', '60601', 'Daley Center Plaza', '', 'Daley Center Plaza', 'IN_SERVICE', '1', 'In Service', 'False', '39']
# ['0', '7', '12', 'Chicago', '84', 'True', 'K3_FULL', '13033', '2019-03-29 18:52:28', '41.891578', '500 N Milwaukee Ave.', '-87.648384', '60654', 'Milwaukee Ave & Grand Ave', '', 'Milwaukee Ave & Grand Ave', 'IN_SERVICE', '1', 'In Service', 'False', '19']
# ['0', '22', '1', 'Chicago', '85', 'True', 'K3_FULL', '13042', '2019-03-29 18:54:21', '41.90096039', '140 E Oak St', '-87.62377664', '60611', 'Michigan Ave & Oak St', '', 'Michigan Ave & Oak St', 'IN_SERVICE', '1', 'In Service', 'False', '23']
# ['0', '4', '15', 'Chicago', '86', 'True', 'K3_FULL', '13289', '2019-03-29 18:51:48', '41.89637337', '811 N Noble St', '-87.66098386', '60642', 'Eckhart Park', '', 'Eckhart Park', 'IN_SERVICE', '1', 'In Service', 'False', '19']
# ['0', '5', '14', 'Chicago', '87', 'True', 'K3_FULL', '13189', '2019-03-29 18:51:14', '41.92556258', '2411 N Racine Ave', '-87.65840426', '60614', 'Racine Ave & Fullerton Ave', '', 'Racine Ave & Fullerton Ave', 'IN_SERVICE', '1', 'In Service', 'False', '19']
# ['0', '17', '2', 'Chicago', '88', 'True', 'K3_FULL', '13155', '2019-03-29 18:51:05', '41.884069', '1213 W Randolph St', '-87.656853', '60607', 'Racine Ave & Randolph St', '', 'Racine Ave & Randolph St', 'IN_SERVICE', '1', 'In Service', 'False', '19']
# ['0', '5', '10', 'Chicago', '89', 'True', 'K3_FULL', '15540', '2019-03-29 18:50:59', '41.874618', '', '-87.632882', '60605', 'Financial Pl & Ida B Wells Dr (Temp)', '', 'Financial Pl & Ida B Wells Dr (Temp)', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '19', '28', 'Chicago', '90', 'True', 'K3_FULL', '13008', '2019-03-29 18:53:55', '41.8810317', '33 S Michigan Ave', '-87.62408432', '60601', 'Millennium Park', '', 'Millennium Park', 'IN_SERVICE', '1', 'In Service', 'False', '47']
# ['0', '4', '25', 'Chicago', '91', 'True', 'K3_FULL', '13010', '2019-03-29 18:50:36', '41.88338', '109 N Clinton St', '-87.64117', '60661', 'Clinton St & Washington Blvd', '', 'Clinton St & Washington Blvd', 'IN_SERVICE', '1', 'In Service', 'False', '31']
# ['0', '11', '8', 'Chicago', '92', 'True', 'K3_FULL', '13196', '2019-03-29 18:54:07', '41.894556', '', '-87.653449', '60642', 'Carpenter St & Huron St', '', 'Carpenter St & Huron St', 'IN_SERVICE', '1', 'In Service', 'False', '19']
# ['0', '6', '9', 'Chicago', '93', 'True', 'K3_FULL', '13190', '2019-03-29 18:54:04', '41.913688', '1740 N Sheffield Ave', '-87.652855', '60614', 'Sheffield Ave & Willow St', '', 'Sheffield Ave & Willow St', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '19', '12', 'Chicago', '94', 'True', 'K3_FULL', '13146', '2019-03-29 18:51:29', '41.918306', '', '-87.636282', '60614', 'Clark St & Armitage Ave', '', 'Clark St & Armitage Ave', 'IN_SERVICE', '1', 'In Service', 'False', '31']
# ['0', '3', '8', 'Chicago', '95', 'True', 'K3_FULL', '15490', '2019-03-29 18:51:54', '41.778881', '', '-87.586647', '60637', 'Stony Island Ave & 64th St', '', 'Stony Island Ave & 64th St', 'IN_SERVICE', '1', 'In Service', 'False', '11']
# ['0', '15', '8', 'Chicago', '96', 'True', 'K3_FULL', '15535', '2019-03-29 18:50:26', '41.88461618962', '', '-87.6445705849', '60661', 'Desplaines St & Randolph St', '', 'Desplaines St & Randolph St', 'IN_SERVICE', '1', 'In Service', 'False', '23']
# ['0', '0', '55', 'Chicago', '97', 'True', 'K3_FULL', '13029', '2019-03-29 18:52:22', '41.865312', 'Off Street', '-87.617867', '60605', 'Field Museum', '', 'Field Museum', 'IN_SERVICE', '1', 'In Service', 'False', '55']
# ['0', '0', '15', 'Chicago', '98', 'True', 'K3_FULL', '13006', '2019-03-29 18:54:12', '41.882664', '', '-87.63253', '60602', 'LaSalle St & Washington St', '', 'LaSalle St & Washington St', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '6', '13', 'Chicago', '99', 'True', 'K3_FULL', '13337', '2019-03-29 18:50:03', '41.89257', '', '-87.614492', '60611', 'Lake Shore Dr & Ohio St', '', 'Lake Shore Dr & Ohio St', 'IN_SERVICE', '1', 'In Service', 'False', '19']
# ['0', '14', '21', 'Chicago', '100', 'True', 'K3_FULL', '13013', '2019-03-29 18:50:22', '41.888243', '333 N Orleans St', '-87.63639', '60654', 'Orleans St & Merchandise Mart Plaza', '', 'Orleans St & Merchandise Mart Plaza', 'IN_SERVICE', '1', 'In Service', 'False', '35']
# ['0', '7', '8', 'Chicago', '101', 'True', 'K3_FULL', '15491', '2019-03-29 18:50:23', '41.78101637196', '', '-87.5761197602', '60649', '63rd St Beach', '', '63rd St Beach', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '3', '8', 'Chicago', '102', 'True', 'K3_FULL', '15492', '2019-03-29 18:54:02', '41.77345849948', '', '-87.5853397391', '60649', 'Stony Island Ave & 67th St', '', 'Stony Island Ave & 67th St', 'IN_SERVICE', '1', 'In Service', 'False', '11']
# ['0', '9', '7', 'Chicago', '103', 'True', 'K3_FULL', '15542', '2019-03-29 18:52:40', '41.87146651779', '', '-87.6409491327', '60607', 'Clinton St & Polk St (*)', 'Old kiosk KA1503000022 now at Clark & Montrose 5.3.2017 DH', 'Clinton St & Polk St (*)', 'IN_SERVICE', '1', 'In Service', 'False', '16']
# ['0', '10', '17', 'Chicago', '106', 'True', 'K3_FULL', '13014', '2019-03-29 18:51:23', '41.897448', '', '-87.628722', '60610', 'State St & Pearson St', '', 'State St & Pearson St', 'IN_SERVICE', '1', 'In Service', 'False', '27']
# ['0', '17', '10', 'Chicago', '107', 'True', 'K3_FULL', '15539', '2019-03-29 18:52:41', '41.878287', '', '-87.643909', '60661', 'Desplaines St & Jackson Blvd', '', 'Desplaines St & Jackson Blvd', 'IN_SERVICE', '1', 'In Service', 'False', '27']
# ['0', '12', '7', 'Chicago', '108', 'True', 'K3_FULL', '13027', '2019-03-29 18:50:01', '41.87184', '', '-87.64664', '60607', 'Halsted St & Polk St', '', 'Halsted St & Polk St', 'IN_SERVICE', '1', 'In Service', 'False', '19']
# ['0', '0', '19', 'Chicago', '109', 'True', 'K3_FULL', '13028', '2019-03-29 18:50:27', '41.874754', '', '-87.649807', '60607', '900 W Harrison St', 'Peoria Blue Line', '900 W Harrison St', 'IN_SERVICE', '1', 'In Service', 'False', '19']
# ['0', '12', '15', 'Chicago', '110', 'True', 'K3_FULL', '13045', '2019-03-29 18:51:24', '41.893992', '', '-87.629318', '60654', 'Dearborn St & Erie St', '\n', 'Dearborn St & Erie St', 'IN_SERVICE', '1', 'In Service', 'False', '27']
# ['0', '7', '20', 'Chicago', '111', 'True', 'K3_FULL', '13052', '2019-03-29 18:51:41', '41.894666', '', '-87.638437', '60654', 'Sedgwick St & Huron St', '', 'Sedgwick St & Huron St', 'IN_SERVICE', '1', 'In Service', 'False', '27']
# ['0', '14', '0', 'Chicago', '112', 'True', 'K3_FULL', '13053', '2019-03-29 18:54:17', '41.883668', '', '-87.64867', '60607', 'Green St & Randolph St', '', 'Green St & Randolph St', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '15', '0', 'Chicago', '113', 'True', 'K3_FULL', '13059', '2019-03-29 18:50:01', '41.91844', '', '-87.65222', '60614', 'Bissell St & Armitage Ave', '', 'Bissell St & Armitage Ave', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '6', '21', 'Chicago', '114', 'True', 'K3_FULL', '13062', '2019-03-29 18:53:31', '41.949399', '', '-87.654529', '60657', 'Sheffield Ave & Waveland Ave', '', 'Sheffield Ave & Waveland Ave', 'IN_SERVICE', '1', 'In Service', 'False', '27']
# ['0', '2', '21', 'Chicago', '115', 'True', 'K3_FULL', '13067', '2019-03-29 18:52:05', '41.936266', '', '-87.652662', '60657', 'Sheffield Ave & Wellington Ave', '', 'Sheffield Ave & Wellington Ave', 'IN_SERVICE', '1', 'In Service', 'False', '23']
# ['0', '6', '9', 'Chicago', '116', 'True', 'K3_FULL', '13068', '2019-03-29 18:53:53', '41.91552', '', '-87.687022', '60647', 'Western Ave & Winnebago Ave', '', 'Western Ave & Winnebago Ave', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '0', '27', 'Chicago', '117', 'True', 'K3_FULL', '13069', '2019-03-29 18:53:44', '41.94018', '', '-87.65304', '60657', 'Wilton Ave & Belmont Ave', '', 'Wilton Ave & Belmont Ave', 'IN_SERVICE', '1', 'In Service', 'False', '27']
# ['0', '4', '15', 'Chicago', '118', 'True', 'K3_FULL', '13070', '2019-03-29 18:53:38', '41.911386', '', '-87.638677', '60610', 'Sedgwick St & North Ave', '', 'Sedgwick St & North Ave', 'IN_SERVICE', '1', 'In Service', 'False', '19']
# ['0', '0', '19', 'Chicago', '119', 'True', 'K3_FULL', '13073', '2019-03-29 18:50:32', '41.88592', '', '-87.66717', '60612', 'Ashland Ave & Lake St (Temp)', '', 'Ashland Ave & Lake St (Temp)', 'IN_SERVICE', '1', 'In Service', 'False', '19']
# ['0', '13', '6', 'Chicago', '120', 'True', 'K3_FULL', '13075', '2019-03-29 18:50:40', '41.853005', '', '-87.630578', '60616', 'Wentworth Ave & Cermak Rd (Temp)', '', 'Wentworth Ave & Cermak Rd (Temp)', 'IN_SERVICE', '1', 'In Service', 'False', '19']
# ['0', '6', '12', 'Chicago', '121', 'True', 'K3_FULL', '13398', '2019-03-29 18:52:58', '41.802562', '', '-87.590368', '60615', 'Blackstone Ave & Hyde Park Blvd', '', 'Blackstone Ave & Hyde Park Blvd', 'IN_SERVICE', '1', 'In Service', 'False', '19']
# ['0', '0', '15', 'Chicago', '122', 'True', 'K3_FULL', '13081', '2019-03-29 18:51:56', '41.87501', '', '-87.67328', '60612', 'Ogden Ave & Congress Pkwy', '', 'Ogden Ave & Congress Pkwy', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '14', '1', 'Chicago', '123', 'True', 'K3_FULL', '13084', '2019-03-29 18:50:45', '41.922695', '', '-87.697153', '60647', 'California Ave & Milwaukee Ave', '', 'California Ave & Milwaukee Ave', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '14', '1', 'Chicago', '124', 'True', 'K3_FULL', '13089', '2019-03-29 18:53:24', '41.855048', '', '-87.675726', '60608', 'Damen Ave & Cullerton St', '', 'Damen Ave & Cullerton St', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '13', '10', 'Chicago', '125', 'True', 'K3_FULL', '15533', '2019-03-29 18:52:20', '41.890173', '', '-87.626185', '60611', 'Rush St & Hubbard St', '', 'Rush St & Hubbard St', 'IN_SERVICE', '1', 'In Service', 'False', '23']
# ['0', '8', '7', 'Chicago', '126', 'True', 'K3_FULL', '13128', '2019-03-29 18:53:01', '41.911974', '', '-87.631942', '60614', 'Clark St & North Ave', '', 'Clark St & North Ave', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '4', '10', 'Chicago', '127', 'True', 'K3_FULL', '13131', '2019-03-29 18:53:49', '41.925905', '', '-87.64926', '60614', 'Lincoln Ave & Fullerton Ave', '', 'Lincoln Ave & Fullerton Ave', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '2', '17', 'Chicago', '128', 'True', 'K3_FULL', '13132', '2019-03-29 18:51:34', '41.895769', '', '-87.67722', '60622', 'Damen Ave & Chicago Ave', '', 'Damen Ave & Chicago Ave', 'IN_SERVICE', '1', 'In Service', 'False', '19']
# ['0', '13', '2', 'Chicago', '129', 'True', 'K3_FULL', '13135', '2019-03-29 18:51:02', '41.857556', '', '-87.661535', '60608', 'Blue Island Ave & 18th St', '', 'Blue Island Ave & 18th St', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '13', '5', 'Chicago', '130', 'True', 'K3_FULL', '13136', '2019-03-29 18:50:19', '41.903266', '', '-87.678435', '60622', 'Damen Ave & Division St', '', 'Damen Ave & Division St', 'IN_SERVICE', '1', 'In Service', 'False', '19']
# ['0', '1', '14', 'Chicago', '131', 'True', 'K3_FULL', '13140', '2019-03-29 18:54:21', '41.939365', '', '-87.668385', '60657', 'Lincoln Ave & Belmont Ave', '', 'Lincoln Ave & Belmont Ave', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '12', '3', 'Chicago', '132', 'True', 'K3_FULL', '13149', '2019-03-29 18:51:43', '41.849237', '', '-87.631715', '60616', 'Wentworth Ave & 24th St', '', 'Wentworth Ave & 24th St', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '12', '19', 'Chicago', '133', 'True', 'K3_FULL', '15532', '2019-03-29 18:54:20', '41.88917683258', '', '-87.6385057718', '60654', 'Kingsbury St & Kinzie St', '', 'Kingsbury St & Kinzie St', 'IN_SERVICE', '1', 'In Service', 'False', '31']
# ['0', '10', '9', 'Chicago', '134', 'True', 'K3_FULL', '13158', '2019-03-29 18:52:02', '41.877749', '', '-87.649633', '60607', 'Peoria St & Jackson Blvd', '', 'Peoria St & Jackson Blvd', 'IN_SERVICE', '1', 'In Service', 'False', '19']
# ['0', '1', '10', 'Chicago', '135', 'True', 'K3_FULL', '13162', '2019-03-29 18:53:54', '41.85378', '', '-87.64665', '60608', 'Halsted St & 21st St', '', 'Halsted St & 21st St', 'IN_SERVICE', '1', 'In Service', 'False', '11']
# ['0', '9', '6', 'Chicago', '136', 'True', 'K3_FULL', '13165', '2019-03-29 18:50:17', '41.865054', '', '-87.656959', '60608', 'Racine Ave & 13th St', '', 'Racine Ave & 13th St', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '9', '6', 'Chicago', '137', 'True', 'K3_FULL', '13169', '2019-03-29 18:53:45', '41.862378', '', '-87.651062', '60608', 'Morgan Ave & 14th Pl', '', 'Morgan Ave & 14th Pl', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '13', '2', 'Chicago', '138', 'True', 'K3_FULL', '13171', '2019-03-29 18:51:03', '41.904613', '', '-87.640552', '60610', 'Clybourn Ave & Division St', '', 'Clybourn Ave & Division St', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '6', '13', 'Chicago', '140', 'True', 'K3_FULL', '13173', '2019-03-29 18:50:59', '41.898969', '', '-87.629912', '60610', 'Dearborn Pkwy & Delaware Pl', '', 'Dearborn Pkwy & Delaware Pl', 'IN_SERVICE', '1', 'In Service', 'False', '19']
# ['0', '9', '13', 'Chicago', '141', 'True', 'K3_FULL', '13179', '2019-03-29 18:54:25', '41.915689', '', '-87.6346', '60614', 'Clark St & Lincoln Ave', '', 'Clark St & Lincoln Ave', 'IN_SERVICE', '1', 'In Service', 'False', '23']
# ['0', '6', '25', 'Chicago', '142', 'True', 'K3_FULL', '15531', '2019-03-29 18:52:04', '41.894503', '660 N McClurg Ct', '-87.617854', '60611', 'McClurg Ct & Erie St', '', 'McClurg Ct & Erie St', 'IN_SERVICE', '1', 'In Service', 'False', '31']
# ['0', '4', '10', 'Chicago', '143', 'True', 'K3_FULL', '13191', '2019-03-29 18:53:56', '41.922167', '', '-87.638888', '60614', 'Sedgwick St & Webster Ave', '', 'Sedgwick St & Webster Ave', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '9', '10', 'Chicago', '144', 'True', 'K3_FULL', '13193', '2019-03-29 18:50:37', '41.921822', '', '-87.64414', '60614', 'Larrabee St & Webster Ave', '', 'Larrabee St & Webster Ave', 'IN_SERVICE', '1', 'In Service', 'False', '19']
# ['0', '10', '9', 'Chicago', '145', 'True', 'K3_FULL', '15529', '2019-03-29 18:52:37', '41.8985866514', '', '-87.6219152258', '60611', 'Mies van der Rohe Way & Chestnut St', '', 'Mies van der Rohe Way & Chestnut St', 'IN_SERVICE', '1', 'In Service', 'False', '19']
# ['0', '16', '3', 'Chicago', '146', 'True', 'K3_FULL', '13206', '2019-03-29 18:50:59', '41.877945', '', '-87.662007', '60607', 'Loomis St & Jackson Blvd', '', 'Loomis St & Jackson Blvd', 'IN_SERVICE', '1', 'In Service', 'False', '19']
# ['0', '8', '7', 'Chicago', '147', 'True', 'K3_FULL', '13212', '2019-03-29 18:52:12', '41.845687', '', '-87.622481', '60616', 'Indiana Ave & 26th St', '', 'Indiana Ave & 26th St', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '7', '8', 'Chicago', '148', 'True', 'K3_FULL', '13216', '2019-03-29 18:50:49', '41.834734', '', '-87.625813', '60616', 'State St & 33rd St', '', 'State St & 33rd St', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '0', '11', 'Chicago', '149', 'True', 'K3_FULL', '13217', '2019-03-29 18:52:28', '41.8349', '', '-87.61793', '60616', 'Calumet Ave & 33rd St', '', 'Calumet Ave & 33rd St', 'IN_SERVICE', '1', 'In Service', 'False', '11']
# ['0', '13', '14', 'Chicago', '150', 'True', 'K3_FULL', '13220', '2019-03-29 18:50:29', '41.838556', '', '-87.608218', '60616', 'Fort Dearborn Dr & 31st St', '', 'Fort Dearborn Dr & 31st St', 'IN_SERVICE', '1', 'In Service', 'False', '27']
# ['0', '9', '5', 'Chicago', '152', 'True', 'K3_FULL', '13226', '2019-03-29 18:50:28', '41.932225', '', '-87.658617', '60614', 'Lincoln Ave & Diversey Pkwy', '', 'Lincoln Ave & Diversey Pkwy', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '13', '6', 'Chicago', '153', 'True', 'K3_FULL', '13228', '2019-03-29 18:53:46', '41.935733', '', '-87.663576', '60657', 'Southport Ave & Wellington Ave', '', 'Southport Ave & Wellington Ave', 'IN_SERVICE', '1', 'In Service', 'False', '19']
# ['0', '8', '7', 'Chicago', '154', 'True', 'K3_FULL', '13229', '2019-03-29 18:52:36', '41.93949', '', '-87.66378', '60657', 'Southport Ave & Belmont Ave', '', 'Southport Ave & Belmont Ave', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '14', '1', 'Chicago', '156', 'True', 'K3_FULL', '13232', '2019-03-29 18:52:29', '41.9364968219', '', '-87.6475386582', '60657', 'Clark St & Wellington Ave', '', 'Clark St & Wellington Ave', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '7', '8', 'Chicago', '157', 'True', 'K3_FULL', '13234', '2019-03-29 18:53:57', '41.936669', '', '-87.636794', '60657', 'Lake Shore Dr & Wellington Ave', '', 'Lake Shore Dr & Wellington Ave', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '7', '8', 'Chicago', '158', 'True', 'K3_FULL', '13243', '2019-03-29 18:53:38', '41.912616', '', '-87.681391', '60647', 'Milwaukee Ave & Wabansia Ave', '', 'Milwaukee Ave & Wabansia Ave', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '7', '4', 'Chicago', '159', 'True', 'K3_FULL', '13245', '2019-03-29 18:52:21', '41.907781', '', '-87.685854', '60622', '1451 N Claremont Ave', '', 'Claremont Ave & Hirsch St', 'IN_SERVICE', '1', 'In Service', 'False', '11']
# ['0', '10', '5', 'Chicago', '160', 'True', 'K3_FULL', '13257', '2019-03-29 18:50:58', '41.910535', '', '-87.689556', '60647', 'Campbell Ave & North Ave', '', 'Campbell Ave & North Ave', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '15', '8', 'Chicago', '161', 'True', 'K3_FULL', '15530', '2019-03-29 18:52:21', '41.89576474564', '', '-87.6259080327', '60611', 'Rush St & Superior St', '', 'Rush St & Superior St', 'IN_SERVICE', '1', 'In Service', 'False', '23']
# ['0', '5', '10', 'Chicago', '162', 'True', 'K3_FULL', '13268', '2019-03-29 18:51:30', '41.93588', '', '-87.67842', '60618', 'Damen Ave & Wellington Ave', '', 'Damen Ave & Wellington Ave', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '4', '11', 'Chicago', '163', 'True', 'K3_FULL', '13271', '2019-03-29 18:52:47', '41.931931', '', '-87.677856', '60614', 'Damen Ave & Clybourn Ave', '', 'Damen Ave & Clybourn Ave', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '0', '27', 'Chicago', '164', 'True', 'K3_FULL', '13272', '2019-03-29 18:51:54', '41.885837', '', '-87.6355', '60606', 'Franklin St & Lake St', '', 'Franklin St & Lake St', 'IN_SERVICE', '1', 'In Service', 'False', '27']
# ['0', '13', '9', 'Chicago', '165', 'True', 'K3_FULL', '13275', '2019-03-29 18:51:02', '41.95078', '', '-87.659172', '60613', 'Clark St & Grace St', '', 'Clark St & Grace St', 'IN_SERVICE', '1', 'In Service', 'False', '23']
# ['0', '5', '10', 'Chicago', '166', 'True', 'K3_FULL', '13296', '2019-03-29 18:53:55', '41.92883', '', '-87.668507', '60614', 'Ashland Ave & Wrightwood Ave', '', 'Ashland Ave & Wrightwood Ave', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '6', '1', 'Chicago', '167', 'True', 'K3_FULL', '13306', '2019-03-29 18:51:29', '41.8492', '', '-87.67564', '60608', 'Damen Ave & Coulter St', '', 'Damen Ave & Coulter St', 'IN_SERVICE', '1', 'In Service', 'False', '7']
# ['0', '11', '8', 'Chicago', '168', 'True', 'K3_FULL', '13310', '2019-03-29 18:50:17', '41.864059', '', '-87.623727', '60605', 'Michigan Ave & 14th St', '', 'Michigan Ave & 14th St', 'IN_SERVICE', '1', 'In Service', 'False', '19']
# ['0', '2', '13', 'Chicago', '169', 'True', 'K3_FULL', '13326', '2019-03-29 18:51:17', '41.874255', '', '-87.639573', '60607', 'Canal St & Harrison St', '', 'Canal St & Harrison St', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '4', '11', 'Chicago', '170', 'True', 'K3_FULL', '13329', '2019-03-29 18:51:03', '41.85795', '', '-87.640826', '60616', 'Clinton St & 18th St', '', 'Clinton St & 18th St', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '2', '9', 'Chicago', '171', 'True', 'K3_FULL', '13331', '2019-03-29 18:50:48', '41.855136', '', '-87.654127', '60608', 'May St & Cullerton St', '', 'May St & Cullerton St', 'IN_SERVICE', '1', 'In Service', 'False', '11']
# ['0', '10', '1', 'Chicago', '172', 'True', 'K3_FULL', '15525', '2019-03-29 18:51:05', '41.90230870122', '', '-87.627690528', '60611', 'Rush St & Cedar St', '', 'Rush St & Cedar St', 'IN_SERVICE', '1', 'In Service', 'False', '11']
# ['0', '10', '5', 'Chicago', '173', 'True', 'K3_FULL', '13338', '2019-03-29 18:52:13', '41.89691', '', '-87.621743', '60611', 'Mies van der Rohe Way & Chicago Ave', '', 'Mies van der Rohe Way & Chicago Ave', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '12', '23', 'Chicago', '174', 'True', 'K3_FULL', '13341', '2019-03-29 18:53:13', '41.882091', '', '-87.639833', '60606', 'Canal St & Madison St', '', 'Canal St & Madison St', 'IN_SERVICE', '1', 'In Service', 'False', '35']
# ['0', '8', '11', 'Chicago', '175', 'True', 'K3_FULL', '13344', '2019-03-29 18:51:08', '41.872596', '', '-87.633502', '60607', 'Wells St & Polk St', '', 'Wells St & Polk St', 'IN_SERVICE', '1', 'In Service', 'False', '19']
# ['0', '19', '20', 'Chicago', '176', 'True', 'K3_FULL', '13349', '2019-03-29 18:50:40', '41.902973', '', '-87.63128', '60610', 'Clark St & Elm St', '', 'Clark St & Elm St', 'IN_SERVICE', '1', 'In Service', 'False', '39']
# ['0', '23', '8', 'Chicago', '177', 'True', 'K3_FULL', '13350 ', '2019-03-29 18:51:45', '41.926277', '', '-87.630834', '60614', 'Theater on the Lake', '', 'Theater on the Lake', 'IN_SERVICE', '1', 'In Service', 'False', '31']
# ['0', '15', '0', 'Chicago', '178', 'True', 'K3_FULL', '13408', '2019-03-29 18:50:37', '41.856594', '', '-87.627542', '60616', 'State St & 19th St', '', 'State St & 19th St', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '6', '9', 'Chicago', '179', 'True', 'K3_FULL', '13420', '2019-03-29 18:52:28', '41.8246', 'Off Steet', '-87.61678', '60653', 'MLK Jr Dr & Pershing Rd', 'Formerly MLK Jr Dr & Oakwood Blvd', 'MLK Jr Dr & Pershing Rd', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '15', '0', 'Chicago', '180', 'True', 'K3_FULL', '15523', '2019-03-29 18:53:53', '41.906866', '', '-87.626217', '60610', 'Ritchie Ct & Banks St', '', 'Ritchie Ct & Banks St', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '24', '7', 'Chicago', '181', 'True', 'K3_FULL', '13430', '2019-03-29 18:50:36', '41.890762', 'On Street', '-87.631697', '60654', 'LaSalle St & Illinois St', '', 'LaSalle St & Illinois St', 'IN_SERVICE', '1', 'In Service', 'False', '31']
# ['0', '13', '10', 'Chicago', '182', 'True', 'K3_FULL', '15522', '2019-03-29 18:51:18', '41.903222', '', '-87.634324', '60610', 'Wells St & Elm St', '', 'Wells St & Elm St', 'IN_SERVICE', '1', 'In Service', 'False', '23']
# ['0', '14', '9', 'Chicago', '183', 'True', 'K3_FULL', '13142', '2019-03-29 18:51:04', '41.901315', '', '-87.677409', '60622', 'Damen Ave & Thomas St (Augusta Blvd)', '', 'Damen Ave & Thomas St (Augusta Blvd)', 'IN_SERVICE', '1', 'In Service', 'False', '23']
# ['0', '10', '5', 'Chicago', '184', 'True', 'K3_FULL', '13082', '2019-03-29 18:50:59', '41.83104', '', '-87.62688', '60616', 'State St & 35th St', '', 'State St & 35th St', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '7', '4', 'Chicago', '185', 'True', 'K3_FULL', '13266', '2019-03-29 18:53:13', '41.917741', '', '-87.691392', '60647', 'Stave St & Armitage Ave', '', 'Stave St & Armitage Ave', 'IN_SERVICE', '1', 'In Service', 'False', '11']
# ['0', '11', '4', 'Chicago', '186', 'True', 'K3_FULL', '13194', '2019-03-29 18:51:16', '41.891795', '', '-87.658751', '60642', 'Ogden Ave & Race Ave', '', 'Ogden Ave & Race Ave', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '15', '0', 'Chicago', '188', 'True', 'K3_FULL', '13295', '2019-03-29 18:50:56', '41.92533', '', '-87.6658', '60614', 'Greenview Ave & Fullerton Ave', '', 'Greenview Ave & Fullerton Ave', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '12', '3', 'Chicago', '190', 'True', 'K3_FULL', '13298', '2019-03-29 18:53:44', '41.928773', '', '-87.663913', '60614', 'Southport Ave & Wrightwood Ave', '', 'Southport Ave & Wrightwood Ave', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '7', '21', 'Chicago', '191', 'True', 'K3_FULL', '13056', '2019-03-29 18:50:15', '41.880381', '', '-87.639507', '60661', 'Canal St & Monroe St (*)', '', 'Canal St & Monroe St (*)', 'IN_SERVICE', '1', 'In Service', 'False', '28']
# ['0', '35', '12', 'Chicago', '192', 'True', 'K3_FULL', '13011', '2019-03-29 18:50:35', '41.879255', '', '-87.639904', '60661', 'Canal St & Adams St', '', 'Canal St & Adams St', 'IN_SERVICE', '1', 'In Service', 'False', '47']
# ['0', '4', '7', 'Chicago', '193', 'True', 'K3_FULL', '13213', '2019-03-29 18:50:24', '41.841707', '', '-87.626938', '60616', 'State St & 29th St', '', 'State St & 29th St', 'IN_SERVICE', '1', 'In Service', 'False', '11']
# ['0', '1', '18', 'Chicago', '194', 'True', 'K3_FULL', '13339', '2019-03-29 18:53:40', '41.886875', '', '-87.62603', '60601', 'Wabash Ave & Wacker Pl', '', 'Wabash Ave & Wacker Pl', 'IN_SERVICE', '1', 'In Service', 'False', '19']
# ['0', '25', '30', 'Chicago', '195', 'True', 'K3_FULL', '13263', '2019-03-29 18:51:36', '41.884728', '', '-87.619521', '60601', 'Columbus Dr & Randolph St', '', 'Columbus Dr & Randolph St', 'IN_SERVICE', '1', 'In Service', 'False', '55']
# ['0', '4', '27', 'Chicago', '196', 'True', 'K3_FULL', '13427', '2019-03-29 18:51:42', '41.890573', '', '-87.622072', '60611', 'Cityfront Plaza Dr & Pioneer Ct', '', 'Cityfront Plaza Dr & Pioneer Ct', 'IN_SERVICE', '1', 'In Service', 'False', '31']
# ['0', '9', '10', 'Chicago', '197', 'True', 'K3_FULL', '13036', '2019-03-29 18:50:11', '41.882134', '', '-87.625125', '60602', 'Michigan Ave & Madison St', '', 'Michigan Ave & Madison St', 'IN_SERVICE', '1', 'In Service', 'False', '19']
# ['0', '20', '7', 'Chicago', '198', 'True', 'K3_FULL', '13159', '2019-03-29 18:50:33', '41.881892', '', '-87.648789', '60661', 'Green St & Madison St', '', 'Green St & Madison St', 'IN_SERVICE', '1', 'In Service', 'False', '27']
# ['0', '1', '30', 'Chicago', '199', 'True', 'K3_FULL', '13004', '2019-03-29 18:52:17', '41.891466', '', '-87.626761', '60611', 'Wabash Ave & Grand Ave', '', 'Wabash Ave & Grand Ave', 'IN_SERVICE', '1', 'In Service', 'False', '31']
# ['0', '1', '10', 'Chicago', '200', 'True', 'K3_FULL', '13090', '2019-03-29 18:52:47', '41.809851', '', '-87.616279', '60653', 'MLK Jr Dr & 47th St', '', 'MLK Jr Dr & 47th St', 'IN_SERVICE', '1', 'In Service', 'False', '11']
# ['0', '5', '6', 'Chicago', '201', 'True', 'K3_FULL', '13083', '2019-03-29 18:51:36', '41.82168', '', '-87.6216', '60653', 'Indiana Ave & 40th St', '', 'Indiana Ave & 40th St', 'IN_SERVICE', '1', 'In Service', 'False', '11']
# ['0', '6', '9', 'Chicago', '202', 'True', 'K3_FULL', '13099', '2019-03-29 18:54:09', '41.857499', '', '-87.646277', '60616', 'Halsted St & 18th St', '', 'Halsted St & 18th St', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '3', '12', 'Chicago', '203', 'True', 'K3_FULL', '13091', '2019-03-29 18:50:50', '41.854109', '', '-87.685838', '60608', 'Western Ave & 21st St', '', 'Western Ave & 21st St', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '1', '10', 'Chicago', '204', 'True', 'K3_FULL', '13101', '2019-03-29 18:53:22', '41.794853', '', '-87.618691', '60637', 'Prairie Ave & Garfield Blvd', '', 'Prairie Ave & Garfield Blvd', 'IN_SERVICE', '1', 'In Service', 'False', '11']
# ['0', '2', '13', 'Chicago', '205', 'True', 'K3_FULL', '13088', '2019-03-29 18:52:08', '41.857901', '', '-87.668745', '60608', 'Paulina St & 18th St', '', 'Paulina St & 18th St', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '4', '11', 'Chicago', '206', 'True', 'K3_FULL', '13098', '2019-03-29 18:52:52', '41.847203', '', '-87.646795', '60608', 'Halsted St & Archer Ave', '', 'Halsted St & Archer Ave', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '3', '12', 'Chicago', '207', 'True', 'K3_FULL', '13399', '2019-03-29 18:50:32', '41.84358', '', '-87.645368', '60616', 'Emerald Ave & 28th St', '', 'Emerald Ave & 28th St', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '12', '3', 'Chicago', '208', 'True', 'K3_FULL', '13307', '2019-03-29 18:53:47', '41.85381', '', '-87.665897', '60608', 'Ashland Ave & 21st St', '', 'Ashland Ave & 21st St', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '8', '3', 'Chicago', '209', 'True', 'K3_FULL', '13308', '2019-03-29 18:53:35', '41.849527', '', '-87.640591', '60616', 'Normal Ave & Archer Ave', '', 'Normal Ave & Archer Ave', 'IN_SERVICE', '1', 'In Service', 'False', '11']
# ['0', '8', '19', 'Chicago', '210', 'True', 'K3_FULL', '13061', '2019-03-29 18:51:14', '41.90345', '', '-87.667747', '60622', 'Ashland Ave & Division St', '', 'Ashland Ave & Division St', 'IN_SERVICE', '1', 'In Service', 'False', '27']
# ['0', '15', '4', 'Chicago', '211', 'True', 'K3_FULL', '13016', '2019-03-29 18:53:50', '41.894448', '', '-87.622663', '60611', 'St. Clair St & Erie St', '', 'St. Clair St & Erie St', 'IN_SERVICE', '1', 'In Service', 'False', '19']
# ['0', '10', '20', 'Chicago', '212', 'True', 'K3_FULL', '13264', '2019-03-29 18:53:41', '41.889906', '', '-87.634266', '60654', 'Wells St & Hubbard St', '', 'Wells St & Hubbard St', 'IN_SERVICE', '1', 'In Service', 'False', '31']
# ['0', '2', '13', 'Chicago', '213', 'True', 'K3_FULL', '13244', '2019-03-29 18:53:45', '41.910153', '', '-87.68229', '60622', 'Leavitt St & North Ave', '', 'Leavitt St & North Ave', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '12', '11', 'Chicago', '214', 'True', 'K3_FULL', '13141', '2019-03-29 18:52:11', '41.89122', '', '-87.67686', '60622', 'Damen Ave & Grand Ave', '', 'Damen Ave & Grand Ave', 'IN_SERVICE', '1', 'In Service', 'False', '23']
# ['0', '5', '10', 'Chicago', '215', 'True', 'K3_FULL', '13134', '2019-03-29 18:50:19', '41.88137', '', '-87.67493', '60612', 'Damen Ave & Madison St', '', 'Damen Ave & Madison St', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '14', '1', 'Chicago', '216', 'True', 'K3_FULL', '13256', '2019-03-29 18:53:12', '41.903029', '', '-87.697474', '60622', 'California Ave & Division St', '', 'California Ave & Division St', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '4', '11', 'Chicago', '217', 'True', 'K3_FULL', '13197', '2019-03-29 18:51:05', '41.886926', '', '-87.656919', '60607', 'Racine Ave (May St) & Fulton St', '', 'Racine Ave (May St) & Fulton St', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '5', '6', 'Chicago', '218', 'True', 'K3_FULL', '13180', '2019-03-29 18:52:25', '41.856802', '', '-87.633879', '60616', 'Wells St & 19th St', '', 'Wells St & 19th St', 'IN_SERVICE', '1', 'In Service', 'False', '11']
# ['0', '15', '4', 'Chicago', '219', 'True', 'K3_FULL', '13133', '2019-03-29 18:51:02', '41.915983', '', '-87.677335', '60622', 'Damen Ave & Cortland St', '', 'Damen Ave & Cortland St', 'IN_SERVICE', '1', 'In Service', 'False', '19']
# ...
# ['0', '1', '10', 'Chicago', '583', 'True', 'K3_FULL', '16975', '2019-03-29 18:52:13', '41.746559', '', '-87.586005', '60617', 'Stony Island Ave & 82nd St', '', 'Stony Island Ave & 82nd St', 'IN_SERVICE', '1', 'In Service', 'False', '11']
# ['0', '3', '8', 'Chicago', '584', 'True', 'K3_FULL', '16976', '2019-03-29 18:54:26', '41.744123', '', '-87.599034', '60619', 'Ellis Ave & 83rd St', '', 'Ellis Ave & 83rd St', 'IN_SERVICE', '1', 'In Service', 'False', '11']
# ['0', '4', '7', 'Chicago', '585', 'True', 'K3_FULL', '16977', '2019-03-29 18:51:13', '41.744053', '', '-87.604786', '60619', 'Cottage Grove Ave & 83rd St', '', 'Cottage Grove Ave & 83rd St', 'IN_SERVICE', '1', 'In Service', 'False', '11']
# ['0', '6', '5', 'Chicago', '586', 'True', 'K3_FULL', '16978', '2019-03-29 18:51:51', '41.743116', '', '-87.6148', '60619', 'MLK Jr Dr & 83rd St', '', 'MLK Jr Dr & 83rd St', 'IN_SERVICE', '1', 'In Service', 'False', '11']
# ['0', '4', '7', 'Chicago', '587', 'True', 'K3_FULL', '16979', '2019-03-29 18:50:19', '41.743316', '', '-87.622849', '60619', 'Wabash Ave & 83rd St', '', 'Wabash Ave & 83rd St', 'IN_SERVICE', '1', 'In Service', 'False', '11']
# ['0', '4', '7', 'Chicago', '588', 'True', 'K3_FULL', '16980', '2019-03-29 18:52:35', '41.743921', '', '-87.575225', '60617', 'South Chicago Ave & 83rd St', '', 'South Chicago Ave & 83rd St', 'IN_SERVICE', '1', 'In Service', 'False', '11']
# ['0', '7', '4', 'Chicago', '589', 'True', 'K3_FULL', '16991', '2019-03-29 18:51:32', '41.954468', '', '-87.749594', '60641', 'Milwaukee Ave & Cuyler Ave', '', 'Milwaukee Ave & Cuyler Ave', 'IN_SERVICE', '1', 'In Service', 'False', '11']
# ['0', '4', '7', 'Chicago', '590', 'True', 'K3_FULL', '16992', '2019-03-29 18:51:07', '41.953733', '', '-87.740569', '60641', 'Kilbourn Ave & Irving Park Rd', '', 'Kilbourn Ave & Irving Park Rd', 'IN_SERVICE', '1', 'In Service', 'False', '11']
# ['0', '7', '8', 'Chicago', '591', 'True', 'K3_FULL', '16994', '2019-03-29 18:50:41', '41.948818', '', '-87.74002', '60641', 'Kilbourn Ave & Milwaukee Ave', '', 'Kilbourn Ave & Milwaukee Ave', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '2', '9', 'Chicago', '592', 'True', 'K3_FULL', '16001', '2019-03-29 18:53:33', '41.960631', '', '-87.745359', '60641', 'Knox Ave & Montrose Ave', '', 'Knox Ave & Montrose Ave', 'IN_SERVICE', '1', 'In Service', 'False', '11']
# ['0', '5', '5', 'Chicago', '593', 'True', 'K3_FULL', '16005', '2019-03-29 18:51:01', '41.787539', '', '-87.644874', '60621', 'Halsted St & 59th St', '', 'Halsted St & 59th St', 'IN_SERVICE', '1', 'In Service', 'False', '11']
# ['0', '2', '9', 'Chicago', '594', 'True', 'K3_FULL', '16008', '2019-03-29 18:50:24', '41.805661', '', '-87.683392', '60609', 'Western Blvd & 48th Pl', '', 'Western Blvd & 48th Pl', 'IN_SERVICE', '1', 'In Service', 'False', '11']
# ['0', '4', '7', 'Chicago', '595', 'True', 'K3_FULL', '16009', '2019-03-29 18:51:58', '41.736646', '', '-87.622634', '60619', 'Wabash Ave & 87th St', '', 'Wabash Ave & 87th St', 'IN_SERVICE', '1', 'In Service', 'False', '11']
# ['0', '14', '1', 'Evanston', '596', 'True', 'K3_FULL', 'E001', '2019-03-29 18:50:31', '42.048214', '', '-87.683485', '0', 'Benson Ave & Church St', '', 'Benson Ave & Church St', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '0', '15', 'Evanston', '597', 'True', 'K3_FULL', 'E002', '2019-03-29 18:52:43', '42.032562', '', '-87.679101', '0', 'Chicago Ave & Washington St', '', 'Chicago Ave & Washington St', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '2', '13', 'Evanston', '598', 'True', 'K3_FULL', 'E003', '2019-03-29 18:53:20', '42.025784', '', '-87.684107', '60202', 'Elmwood Ave & Austin St', '', 'Elmwood Ave & Austin St', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '9', '6', 'Evanston', '599', 'True', 'K3_FULL', 'E004', '2019-03-29 18:50:42', '42.039742', '', '-87.699413', '60202', 'Valli Produce - Evanston Plaza', '', 'Valli Produce - Evanston Plaza', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '0', '15', 'Evanston', '600', 'True', 'K3_FULL', 'E005', '2019-03-29 18:53:58', '42.048308', '', '-87.698224', '0', 'Dodge Ave & Church St', '', 'Dodge Ave & Church St', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '9', '6', 'Evanston', '601', 'True', 'K3_FULL', 'E006', '2019-03-29 18:54:25', '42.063598', '', '-87.69873', '0', 'Central St Metra', '', 'Central St Metra', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '0', '15', 'Evanston', '602', 'True', 'K3_FULL', 'E007', '2019-03-29 18:53:07', '42.064313', '', '-87.686152', '60201', 'Central St & Girard Ave', '', 'Central St & Girard Ave', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '6', '8', 'Evanston', '603', 'True', 'K3_FULL', 'E008', '2019-03-29 18:50:21', '42.050491', '', '-87.677821', '60201', 'Chicago Ave & Sheridan Rd', '', 'Chicago Ave & Sheridan Rd', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '5', '10', 'Evanston', '604', 'True', 'K3_FULL', 'E009', '2019-03-29 18:50:10', '42.058239', '', '-87.677432', '60208', 'Sheridan Rd & Noyes St (NU)', '', 'Sheridan Rd & Noyes St (NU)', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '5', '10', 'Evanston', '605', 'True', 'K3_FULL', 'E010', '2019-03-29 18:52:24', '42.052939', '', '-87.673447', '60208', 'University Library (NU)', '', 'University Library (NU)', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '1', '10', 'Chicago', '619', 'True', 'K3_FULL', '16010', '2019-03-29 18:54:13', '41.924377', '', '-87.728231', '60639', 'Keystone Ave & Fullerton Ave', '', 'Keystone Ave & Fullerton Ave', 'IN_SERVICE', '1', 'In Service', 'False', '11']
# ['0', '4', '9', 'Chicago', '620', 'True', 'K3_FULL', '16011', '2019-03-29 18:53:44', '41.898203', '', '-87.637536', '60610', 'Orleans St & Chestnut St (NEXT Apts)', '', 'Orleans St & Chestnut St (NEXT Apts)', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '14', '0', 'Chicago', '621', 'True', 'K3_FULL', '18062', '2019-03-29 18:52:25', '41.884114', '', '-87.654264', '60607', 'Aberdeen St & Randolph St', '', 'Aberdeen St & Randolph St', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '7', '8', 'Chicago', '622', 'True', 'K3_FULL', '17660', '2019-03-29 18:54:11', '41.900363', '', '-87.696704', '60622', 'California Ave & Cortez St', '', 'California Ave & Cortez St', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '3', '40', 'Chicago', '623', 'True', 'K3_FULL', '17541', '2019-03-29 18:53:33', '41.872773', '', '-87.623981', '60605', 'Michigan Ave & 8th St', '', 'Michigan Ave & 8th St', 'IN_SERVICE', '1', 'In Service', 'False', '43']
# ['0', '4', '12', 'Chicago', '624', 'True', 'K3_FULL', '17013', '2019-03-29 18:52:04', '41.876268', '417 S Dearborn St', '-87.629155', '60605', 'Dearborn St & Van Buren St (*)', '', 'Dearborn St & Van Buren St (*)', 'IN_SERVICE', '1', 'In Service', 'False', '16']
# ['0', '8', '7', 'Evanston', '625', 'True', 'K3_FULL', 'E011', '2019-03-29 18:52:40', '42.041691', '', '-87.680687', '60201', 'Chicago Ave & Dempster St', '1312 Chicago Ave', 'Chicago Ave & Dempster St', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '3', '15', 'Chicago', '626', 'True', 'K3_FULL', '17043', '2019-03-29 18:53:17', '41.867491', '', '-87.63219', '60605', 'Delano Ct & Roosevelt Rd', 'Roosevelt Collection Shops', 'Delano Ct & Roosevelt Rd', 'IN_SERVICE', '1', 'In Service', 'False', '19']
# ['0', '19', '1', 'Chicago', '627', 'True', 'K3_FULL', '18064', '2019-03-29 18:50:31', '41.894877', '', '-87.632326', '60654', 'LaSalle Dr & Huron St(*)', '', 'LaSalle Dr & Huron St (*)', 'IN_SERVICE', '1', 'In Service', 'False', '20']
# ['0', '7', '16', 'Chicago', '628', 'True', 'K3_FULL', '18067', '2019-03-29 18:53:16', '41.91461', 'Off-Street', '-87.667968', '60622', 'Walsh Park', 'Walsh Park', 'Walsh Park', 'IN_SERVICE', '1', 'In Service', 'False', '23']
# ['0', '5', '10', 'Chicago', '630', 'True', 'K3_FULL', '18015', '2019-03-29 18:52:20', '41.96108', 'On-Street', '-87.73569', '60630', 'Kildare Ave & Montrose Ave', '', 'Kildare Ave & Montrose Ave', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '2', '17', 'Chicago', '631', 'True', 'K3_FULL', '18045', '2019-03-29 18:50:23', '41.877618', '', '-87.673895', '60612', 'Malcolm X College', '', 'Malcolm X College', 'IN_SERVICE', '1', 'In Service', 'False', '19']
# ['0', '10', '5', 'Chicago', '632', 'True', 'K3_FULL', '18001', '2019-03-29 18:50:08', '41.94454', '', '-87.654678', '60657', 'Clark St & Newport St', '', 'Clark St & Newport St', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '0', '12', 'Chicago', '635', 'True', 'K3_FULL', '18003', '2019-03-29 18:52:54', '41.895748', '', '-87.620104', '60611', 'Fairbanks St & Superior St (*)', '', 'Fairbanks St & Superior St (*)', 'IN_SERVICE', '1', 'In Service', 'False', '12']
# ['0', '7', '5', 'Chicago', '636', 'True', 'K3_FULL', '18005', '2019-03-29 18:52:29', '41.890028', '', '-87.636618', '60654', 'Orleans St & Hubbard St (*)', '', 'Orleans St & Hubbard St (*)', 'IN_SERVICE', '1', 'In Service', 'False', '12']
# ['0', '7', '9', 'Chicago', '637', 'True', 'K3_FULL', '18006', '2019-03-29 18:52:33', '41.895634', '', '-87.672069', '60622', 'Wood St & Chicago Ave (*)', '', 'Wood St & Chicago Ave (*)', 'IN_SERVICE', '1', 'In Service', 'False', '16']
# ['0', '23', '9', 'Chicago', '638', 'True', 'K3_FULL', '18012', '2019-03-29 18:51:47', '41.878419', '', '-87.640977', '60661', 'Clinton St & Jackson Blvd (*)', '', 'Clinton St & Jackson Blvd (*)', 'IN_SERVICE', '1', 'In Service', 'False', '32']
# ['0', '14', '1', 'Chicago', '639', 'True', 'K3_FULL', '18014', '2019-03-29 18:51:37', '41.965845', '', '-87.645361', '60640', 'Lakefront Trail & Wilson Ave', '', 'Lakefront Trail & Wilson Ave', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '0', '11', 'Chicago', '640', 'True', 'K3_FULL', '18016', '2019-03-29 18:53:57', '41.949923', '', '-87.713949', '60618', 'Bernard St & Elston Ave', '', 'Bernard St & Elston Ave', 'IN_SERVICE', '1', 'In Service', 'False', '11']
# ['0', '9', '2', 'Chicago', '641', 'True', 'K3_FULL', '18017', '2019-03-29 18:52:54', '41.914166', '', '-87.716755', '60647', 'Central Park Ave & Bloomingdale Ave', '', 'Central Park Ave & Bloomingdale Ave', 'IN_SERVICE', '1', 'In Service', 'False', '11']
# ['0', '5', '2', 'Chicago', '642', 'True', 'K3_FULL', '18018', '2019-03-29 18:54:18', '41.894745', '', '-87.756895', '60644', 'Latrobe Ave & Chicago Ave', '', 'Latrobe Ave & Chicago Ave', 'IN_SERVICE', '1', 'In Service', 'False', '7']
# ['0', '7', '9', 'Chicago', '643', 'True', 'K3_FULL', '18019', '2019-03-29 18:53:11', '41.892048', '', '-87.689397', '60612', 'Smith Park (*)', '', 'Smith Park (*)', 'IN_SERVICE', '1', 'In Service', 'False', '16']
# ['0', '10', '2', 'Chicago', '644', 'True', 'K3_FULL', '18021', '2019-03-29 18:51:43', '41.868563', '', '-87.686234', '60612', 'Western Ave & Fillmore St (*)', '', 'Western Ave & Fillmore St (*)', 'IN_SERVICE', '1', 'In Service', 'False', '12']
# ['0', '2', '10', 'Chicago', '645', 'True', 'K3_FULL', '18022', '2019-03-29 18:52:02', '41.826712', '', '-87.683144', '60609', 'Archer (Damen) Ave & 37th St (*)', '', 'Archer (Damen) Ave & 37th St (*)', 'IN_SERVICE', '1', 'In Service', 'False', '12']
# ['0', '1', '10', 'Chicago', '646', 'True', 'K3_FULL', '18023', '2019-03-29 18:52:33', '41.796642', '', '-87.625923', '60609', 'State St & 54th St', '', 'State St & 54th St', 'IN_SERVICE', '1', 'In Service', 'False', '11']
# ['0', '3', '4', 'Chicago', '647', 'True', 'K3_FULL', '18024', '2019-03-29 18:52:24', '41.786691', '', '-87.655859', '60636', 'Elizabeth St & 59th St', '', 'Elizabeth St & 59th St', 'IN_SERVICE', '1', 'In Service', 'False', '7']
# ['0', '3', '4', 'Chicago', '648', 'True', 'K3_FULL', '18025', '2019-03-29 18:51:25', '41.77987', '', '-87.650919', '60621', 'Carpenter St & 63rd St', '', 'Carpenter St & 63rd St', 'IN_SERVICE', '1', 'In Service', 'False', '7']
# ['0', '4', '8', 'Chicago', '649', 'True', 'K3_FULL', '18026', '2019-03-29 18:54:17', '41.779835', '', '-87.634774', '60621', 'Stewart Ave & 63rd St (*)', '', 'Stewart Ave & 63rd St (*)', 'IN_SERVICE', '1', 'In Service', 'False', '12']
# ['0', '4', '8', 'Chicago', '650', 'True', 'K3_FULL', '18027', '2019-03-29 18:52:27', '41.768898', '', '-87.635876', '60621', 'Eggleston Ave & 69th St (*)', '', 'Eggleston Ave & 69th St (*)', 'IN_SERVICE', '1', 'In Service', 'False', '12']
# ['0', '3', '4', 'Chicago', '651', 'True', 'K3_FULL', '18028', '2019-03-29 18:50:52', '41.765286', '', '-87.621748', '60619', 'Michigan Ave & 71st St', '', 'Michigan Ave & 71st St', 'IN_SERVICE', '1', 'In Service', 'False', '7']
# ['0', '3', '8', 'Chicago', '652', 'True', 'K3_FULL', '18029', '2019-03-29 18:53:43', '41.766', '', '-87.611726', '60637', 'Rhodes Ave & 71st St', '', 'Rhodes Ave & 71st St', 'IN_SERVICE', '1', 'In Service', 'False', '11']
# ['0', '4', '6', 'Chicago', '653', 'True', 'K3_FULL', '18030', '2019-03-29 18:52:30', '41.780595', '', '-87.584846', '60649', 'Cornell Dr & Hayes Dr', '', 'Cornell Dr & Hayes Dr', 'IN_SERVICE', '1', 'In Service', 'False', '11']
# ['0', '9', '3', 'Chicago', '654', 'True', 'K3_FULL', '18046', '2019-03-29 18:51:34', '41.883073', '', '-87.656952', '60607', 'Racine Ave & Washington Blvd (*)', '', 'Racine Ave & Washington Blvd (*)', 'IN_SERVICE', '1', 'In Service', 'False', '12']
# ['0', '4', '11', 'Chicago', '655', 'True', 'K3_FULL', '18047', '2019-03-29 18:52:54', '41.979851', '', '-87.681932', '60625', 'Hoyne Ave & Balmoral Ave', '', 'Hoyne Ave & Balmoral Ave', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '1', '15', 'Chicago', '656', 'True', 'K3_FULL', '18054', '2019-03-29 18:50:19', '41.885951', '', '-87.677009', '60612', 'Damen Ave & Walnut (Lake) St (*)', '', 'Damen Ave & Walnut (Lake) St (*)', 'IN_SERVICE', '1', 'In Service', 'False', '16']
# ['0', '6', '9', 'Chicago', '657', 'True', 'K3_FULL', '18056', '2019-03-29 18:51:38', '41.899181', '', '-87.6722', '60622', 'Wood St & Augusta Blvd', '', 'Wood St & Augusta Blvd', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '11', '5', 'Chicago', '658', 'True', 'K3_FULL', '18057', '2019-03-29 18:51:35', '41.902997', '', '-87.683825', '60622', 'Leavitt St & Division St (*)', '', 'Leavitt St & Division St (*)', 'IN_SERVICE', '1', 'In Service', 'False', '16']
# ['0', '8', '7', 'Chicago', '659', 'True', 'K3_FULL', '18058', '2019-03-29 18:50:05', '41.895501', '', '-87.682017', '60612', 'Leavitt St & Chicago Ave', '', 'Leavitt St & Chicago Ave', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '12', '3', 'Chicago', '660', 'True', 'K3_FULL', '18066', '2019-03-29 18:54:06', '42.004583', '', '-87.661406', '60626', 'Sheridan Rd & Columbia Ave', '', 'Sheridan Rd & Columbia Ave', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '6', '9', 'Evanston', '661', 'True', 'K3_FULL', 'E012', '2019-03-29 18:51:00', '42.057044', '', '-87.686554', '60201', 'Evanston Civic Center', '', 'Evanston Civic Center', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '5', '10', 'Evanston', '662', 'True', 'K3_FULL', 'E013', '2019-03-29 18:50:14', '42.023463', '', '-87.699595', '60201', 'Dodge Ave & Mulford St', '', 'Dodge Ave & Mulford St', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '11', '4', 'Evanston', '663', 'True', 'K3_FULL', 'E014', '2019-03-29 18:50:46', '42.064854', '', '-87.715297', '60201', 'Lincolnwood Dr & Central St', '', 'Lincolnwood Dr & Central St', 'IN_SERVICE', '1', 'In Service', 'False', '15']
# ['0', '11', '5', 'Chicago', '664', 'True', 'K3_FULL', '18068', '2019-03-29 18:51:22', '41.939354', '', '-87.683282', '60618', 'Leavitt St & Belmont Ave (*)', '', 'Leavitt St & Belmont Ave (*)', 'IN_SERVICE', '1', 'In Service', 'False', '16']
# ['0', '3', '4', 'Chicago', '665', 'True', 'K3_FULL', '19031', '2019-03-29 18:50:34', '41.747363', '', '-87.580046', '60617', 'South Chicago Ave & Elliot Ave', '', 'South Chicago Ave & Elliot Ave', 'IN_SERVICE', '1', 'In Service', 'False', '7']

# %% [markdown]
# ### Lets add the spatial type for the location as Where_IS and store the ST_POINT(latitude,longitude)

# %%
cursor.execute("UPDATE divvy_stations_status SET Where_IS = ST_POINT(latitude,longitude);")

# %%
cursor.execute("UPDATE divvy_stations_logs SET Where_IS = ST_POINT(latitude,longitude);")

# %%
db_connection.commit()

# %% [markdown]
# ### The following is the Heartbeat Loop - Pulls data from divvy every 2 minutes in order to get realtime updates for the different divvy stations

# %%
import time

while True:
    # Get divvy statations status
    # Status is returned as a json reply
    response = urllib.request.urlopen('https://feeds.divvybikes.com/stations/stations.json')

    # Extract the body of the reply
    response_body = response.read()

    # Decode the format in json format
    stations_json = json.loads(response_body.decode("utf-8"))
    
    # load data file into a dataframe
    df__stations = pd.DataFrame(stations_json['stationBeanList'])
    
    # Clean the BLANKs from the data
    df__stations['altitude'] = df__stations['altitude'].apply(lambda x: 0 if x == '' else x)
    df__stations['postalCode'] = df__stations['postalCode'].apply(lambda x: 0 if x == '' else x)
    
    #Remove the whitespace from the end of hte city name
    df__stations['city'] = df__stations['city'].apply(lambda x: 'Chicago' if x == 'Chicago ' else x)

    # store the data in a file in case needed it for realtime debugging
    df__stations.to_csv('divvy_stations_status.csv',sep=',', encoding='utf-8', index=False)
    df__stations.to_csv('divvy_stations_logs.csv',sep=',', encoding='utf-8', index=False)

    # delete existing data in the table
    cursor.execute("DELETE FROM divvy_stations_status")
    db_connection.commit()


    cursor.execute( "INSERT INTO divvy_stations_status VALUES (%s, %s, %s, %s, %s,    %s, %s, %s, %s,%s,   %s, %s, %s, %s,%s,   %s, %s, %s, %s,%s,  %s, NULL)", row)
    cursor.execute( "INSERT INTO divvy_stations_logs VALUES (%s, %s, %s, %s, %s,    %s, %s, %s, %s,%s,   %s, %s, %s, %s,%s,   %s, %s, %s, %s,%s,  %s, NULL)", row)
    
    # Now we will connect to the database and store divvy data
    with open('divvy_stations_status.csv', 'r') as f:
        reader = csv.reader(f)
        next(reader)  # Skip the header row.
        for row in reader:
            cursor.execute( "INSERT INTO divvy_stations_status VALUES (%s, %s, %s, %s, %s,    %s, %s, %s, %s,%s,   %s, %s, %s, %s,%s,   %s, %s, %s, %s,%s,  %s, NULL)", row)
            
    with open('divvy_stations_logs.csv', 'r') as f:
        reader = csv.reader(f)
        next(reader)  # Skip the header row.
        for row in reader:
            cursor.execute( "INSERT INTO divvy_stations_logs VALUES (%s, %s, %s, %s, %s,    %s, %s, %s, %s,%s,   %s, %s, %s, %s,%s,   %s, %s, %s, %s,%s,  %s, NULL)", row)

    
    
    db_connection.commit()
    
    cursor.execute("UPDATE divvy_stations_status SET Where_IS = ST_POINT(latitude,longitude);")
    cursor.execute("UPDATE divvy_stations_logs SET Where_IS = ST_POINT(latitude,longitude);")
    db_connection.commit()
    
    # Sleep for 3 minutes; divvy updates its stations status every 2 minutes
    print('Sent Heartbeat to Divvy Servers and Going to sleep for 3 minutes now ...')
    time.sleep(180)    
    continue
# Out:
# Sent Heartbeat to Divvy Servers and Going to sleep for 3 minutes now ...
# Sent Heartbeat to Divvy Servers and Going to sleep for 3 minutes now ...
# Sent Heartbeat to Divvy Servers and Going to sleep for 3 minutes now ...
# Sent Heartbeat to Divvy Servers and Going to sleep for 3 minutes now ...
# Sent Heartbeat to Divvy Servers and Going to sleep for 3 minutes now ...
# Sent Heartbeat to Divvy Servers and Going to sleep for 3 minutes now ...
# Sent Heartbeat to Divvy Servers and Going to sleep for 3 minutes now ...
# Sent Heartbeat to Divvy Servers and Going to sleep for 3 minutes now ...
# Sent Heartbeat to Divvy Servers and Going to sleep for 3 minutes now ...
# Sent Heartbeat to Divvy Servers and Going to sleep for 3 minutes now ...
# Sent Heartbeat to Divvy Servers and Going to sleep for 3 minutes now ...
# Sent Heartbeat to Divvy Servers and Going to sleep for 3 minutes now ...
# Sent Heartbeat to Divvy Servers and Going to sleep for 3 minutes now ...
# Sent Heartbeat to Divvy Servers and Going to sleep for 3 minutes now ...
# Sent Heartbeat to Divvy Servers and Going to sleep for 3 minutes now ...
# Sent Heartbeat to Divvy Servers and Going to sleep for 3 minutes now ...
# Sent Heartbeat to Divvy Servers and Going to sleep for 3 minutes now ...
# Sent Heartbeat to Divvy Servers and Going to sleep for 3 minutes now ...
# Sent Heartbeat to Divvy Servers and Going to sleep for 3 minutes now ...
# Sent Heartbeat to Divvy Servers and Going to sleep for 3 minutes now ...
# Sent Heartbeat to Divvy Servers and Going to sleep for 3 minutes now ...
# Sent Heartbeat to Divvy Servers and Going to sleep for 3 minutes now ...
# Sent Heartbeat to Divvy Servers and Going to sleep for 3 minutes now ...
# Sent Heartbeat to Divvy Servers and Going to sleep for 3 minutes now ...
# Sent Heartbeat to Divvy Servers and Going to sleep for 3 minutes now ...
# Sent Heartbeat to Divvy Servers and Going to sleep for 3 minutes now ...
# Sent Heartbeat to Divvy Servers and Going to sleep for 3 minutes now ...
# Sent Heartbeat to Divvy Servers and Going to sleep for 3 minutes now ...
# Sent Heartbeat to Divvy Servers and Going to sleep for 3 minutes now ...
# Sent Heartbeat to Divvy Servers and Going to sleep for 3 minutes now ...
# Sent Heartbeat to Divvy Servers and Going to sleep for 3 minutes now ...
# Sent Heartbeat to Divvy Servers and Going to sleep for 3 minutes now ...
# Sent Heartbeat to Divvy Servers and Going to sleep for 3 minutes now ...
# Sent Heartbeat to Divvy Servers and Going to sleep for 3 minutes now ...
# Sent Heartbeat to Divvy Servers and Going to sleep for 3 minutes now ...
# Sent Heartbeat to Divvy Servers and Going to sleep for 3 minutes now ...
# Sent Heartbeat to Divvy Servers and Going to sleep for 3 minutes now ...
# Sent Heartbeat to Divvy Servers and Going to sleep for 3 minutes now ...
# Sent Heartbeat to Divvy Servers and Going to sleep for 3 minutes now ...
# Sent Heartbeat to Divvy Servers and Going to sleep for 3 minutes now ...
# Sent Heartbeat to Divvy Servers and Going to sleep for 3 minutes now ...
# Sent Heartbeat to Divvy Servers and Going to sleep for 3 minutes now ...
# Sent Heartbeat to Divvy Servers and Going to sleep for 3 minutes now ...
# Sent Heartbeat to Divvy Servers and Going to sleep for 3 minutes now ...

# %%
# close connection at the end of the script

db_connection.close()

# %%
##################################################################################################
##################################################################################################


### This file and the source code provided can be used only for the projects and assignments  
### of this course


##################################################################################################

# %% [markdown]
# ## Divvy
#
# **Divvy** is a bicycle sharing system in the City of Chicago.
#
# Click __[here](https://en.wikipedia.org/wiki/Divvy)__ to read more about **Divvy**
#
#
# Click __[here](https://www.divvybikes.com/)__ to visit the official website for **Divvy**

# %% [markdown]
# This script will send a heartbeat every 2 minutes to divvy to collect their stations status in the City of Chicago.

# %%
import json
import requests
import datetime
import time
import os
import pandas as pd
import urllib.request
import json
import csv

from pprint import pprint

# %%
# Get divvy stations status
# Status is returned as a json reply

response = urllib.request.urlopen('https://feeds.divvybikes.com/stations/stations.json')

# Extract the body of the reply
response_body = response.read()

# %%
# Decode the format in json format
stations_json = json.loads(response_body.decode("utf-8"))

# %%
type(stations_json)
# Out:
# dict

# %%
pprint(stations_json)
# Out:
# {'executionTime': '2019-05-16 13:20:20',
#  'stationBeanList': [{'altitude': '',
#                       'availableBikes': 13,
#                       'availableDocks': 26,
#                       'city': 'Chicago',
#                       'id': 2,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '15541',
#                       'lastCommunicationTime': '2019-05-16 13:18:23',
#                       'latitude': 41.87647,
#                       'location': '',
#                       'longitude': -87.62034,
#                       'postalCode': '60605',
#                       'stAddress1': 'Buckingham Fountain',
#                       'stAddress2': '',
#                       'stationName': 'Buckingham Fountain',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 39},
#                      {'altitude': '',
#                       'availableBikes': 6,
#                       'availableDocks': 49,
#                       'city': 'Chicago',
#                       'id': 3,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '15544',
#                       'lastCommunicationTime': '2019-05-16 13:17:09',
#                       'latitude': 41.86722595682,
#                       'location': '',
#                       'longitude': -87.6153553902,
#                       'postalCode': '',
#                       'stAddress1': 'Shedd Aquarium',
#                       'stAddress2': '',
#                       'stationName': 'Shedd Aquarium',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 55},
#                      {'altitude': '',
#                       'availableBikes': 12,
#                       'availableDocks': 11,
#                       'city': 'Chicago',
#                       'id': 4,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '15545',
#                       'lastCommunicationTime': '2019-05-16 13:17:46',
#                       'latitude': 41.856268,
#                       'location': '',
#                       'longitude': -87.613348,
#                       'postalCode': '',
#                       'stAddress1': 'Burnham Harbor',
#                       'stAddress2': '',
#                       'stationName': 'Burnham Harbor',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 23},
#                      {'altitude': '',
#                       'availableBikes': 0,
#                       'availableDocks': 22,
#                       'city': 'Chicago',
#                       'id': 5,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '13030',
#                       'lastCommunicationTime': '2019-05-16 13:18:46',
#                       'latitude': 41.874053,
#                       'location': '620 S. State St.',
#                       'longitude': -87.627716,
#                       'postalCode': '60605',
#                       'stAddress1': 'State St & Harrison St',
#                       'stAddress2': '',
#                       'stationName': 'State St & Harrison St',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 23},
#                      {'altitude': '',
#                       'availableBikes': 1,
#                       'availableDocks': 38,
#                       'city': 'Chicago',
#                       'id': 6,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '15548',
#                       'lastCommunicationTime': '2019-05-16 13:16:08',
#                       'latitude': 41.886976,
#                       'location': '',
#                       'longitude': -87.612813,
#                       'postalCode': '60601',
#                       'stAddress1': 'Dusable Harbor',
#                       'stAddress2': '',
#                       'stationName': 'Dusable Harbor',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 39},
#                      {'altitude': '',
#                       'availableBikes': 0,
#                       'availableDocks': 19,
#                       'city': 'Chicago',
#                       'id': 7,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '15534',
#                       'lastCommunicationTime': '2019-05-16 13:15:52',
#                       'latitude': 41.88634906269,
#                       'location': '',
#                       'longitude': -87.6175165471,
#                       'postalCode': '60601',
#                       'stAddress1': 'Field Blvd & South Water St',
#                       'stAddress2': '',
#                       'stationName': 'Field Blvd & South Water St',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 19},
#                      {'altitude': '',
#                       'availableBikes': 3,
#                       'availableDocks': 12,
#                       'city': 'Chicago',
#                       'id': 9,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '15695',
#                       'lastCommunicationTime': '2019-05-16 13:17:56',
#                       'latitude': 41.82879201994,
#                       'location': 'NA1',
#                       'longitude': -87.6806044594,
#                       'postalCode': '60609',
#                       'stAddress1': 'Leavitt St & Archer Ave',
#                       'stAddress2': '',
#                       'stationName': 'Leavitt St & Archer Ave',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 15},
#                      {'altitude': '',
#                       'availableBikes': 10,
#                       'availableDocks': 1,
#                       'city': 'Chicago',
#                       'id': 11,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '15496',
#                       'lastCommunicationTime': '2019-05-16 13:19:55',
#                       'latitude': 41.76663823695,
#                       'location': '',
#                       'longitude': -87.5764501141,
#                       'postalCode': '60649',
#                       'stAddress1': 'Jeffery Blvd & 71st St',
#                       'stAddress2': '',
#                       'stationName': 'Jeffery Blvd & 71st St',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 11},
#                      {'altitude': '',
#                       'availableBikes': 6,
#                       'availableDocks': 9,
#                       'city': 'Chicago',
#                       'id': 12,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '15497',
#                       'lastCommunicationTime': '2019-05-16 13:18:56',
#                       'latitude': 41.7664094567,
#                       'location': 'MLSW',
#                       'longitude': -87.5656875719,
#                       'postalCode': '60649',
#                       'stAddress1': 'South Shore Dr & 71st St',
#                       'stAddress2': '',
#                       'stationName': 'South Shore Dr & 71st St',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 15},
#                      {'altitude': '',
#                       'availableBikes': 15,
#                       'availableDocks': 20,
#                       'city': 'Chicago',
#                       'id': 13,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '13066',
#                       'lastCommunicationTime': '2019-05-16 13:17:44',
#                       'latitude': 41.932418,
#                       'location': '2790 N.Wilton Ave',
#                       'longitude': -87.652705,
#                       'postalCode': '60614',
#                       'stAddress1': 'Wilton Ave & Diversey Pkwy',
#                       'stAddress2': '',
#                       'stationName': 'Wilton Ave & Diversey Pkwy',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 35},
#                      {'altitude': '',
#                       'availableBikes': 3,
#                       'availableDocks': 12,
#                       'city': 'Chicago',
#                       'id': 14,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '13163',
#                       'lastCommunicationTime': '2019-05-16 13:19:52',
#                       'latitude': 41.858086,
#                       'location': '962 W. 18th St',
#                       'longitude': -87.651073,
#                       'postalCode': '60608',
#                       'stAddress1': 'Morgan St & 18th St',
#                       'stAddress2': '',
#                       'stationName': 'Morgan St & 18th St',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 15},
#                      {'altitude': '',
#                       'availableBikes': 2,
#                       'availableDocks': 13,
#                       'city': 'Chicago',
#                       'id': 15,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '13164',
#                       'lastCommunicationTime': '2019-05-16 13:18:10',
#                       'latitude': 41.858166,
#                       'location': '1726 S Racine Ave',
#                       'longitude': -87.656495,
#                       'postalCode': '60608',
#                       'stAddress1': 'Racine Ave & 18th St',
#                       'stAddress2': '',
#                       'stationName': 'Racine Ave & 18th St',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 15},
#                      {'altitude': '',
#                       'availableBikes': 3,
#                       'availableDocks': 12,
#                       'city': 'Chicago',
#                       'id': 16,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '13223',
#                       'lastCommunicationTime': '2019-05-16 13:18:43',
#                       'latitude': 41.910337,
#                       'location': '1575 N Paulina Ave',
#                       'longitude': -87.670072,
#                       'postalCode': '60622',
#                       'stAddress1': 'Paulina Ave & North Ave',
#                       'stAddress2': '',
#                       'stationName': 'Paulina Ave & North Ave',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 15},
#                      {'altitude': '',
#                       'availableBikes': 4,
#                       'availableDocks': 19,
#                       'city': 'Chicago',
#                       'id': 17,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '13246',
#                       'lastCommunicationTime': '2019-05-16 13:18:08',
#                       'latitude': 41.903119,
#                       'location': ' W. Divison St',
#                       'longitude': -87.673935,
#                       'postalCode': '60622',
#                       'stAddress1': 'Honore St & Division St',
#                       'stAddress2': '',
#                       'stationName': 'Honore St & Division St',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 23},
#                      {'altitude': '',
#                       'availableBikes': 14,
#                       'availableDocks': 5,
#                       'city': 'Chicago',
#                       'id': 18,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '15536',
#                       'lastCommunicationTime': '2019-05-16 13:19:21',
#                       'latitude': 41.883132,
#                       'location': '',
#                       'longitude': -87.637321,
#                       'postalCode': '60606',
#                       'stAddress1': 'Wacker Dr & Washington St',
#                       'stAddress2': '',
#                       'stationName': 'Wacker Dr & Washington St',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 19},
#                      {'altitude': '',
#                       'availableBikes': 0,
#                       'availableDocks': 16,
#                       'city': 'Chicago',
#                       'id': 19,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '13139',
#                       'lastCommunicationTime': '2019-05-16 13:16:09',
#                       'latitude': 41.868968,
#                       'location': '',
#                       'longitude': -87.659141,
#                       'postalCode': '60607',
#                       'stAddress1': 'Loomis St & Taylor St (*)',
#                       'stAddress2': '',
#                       'stationName': 'Loomis St & Taylor St (*)',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 16},
#                      {'altitude': '',
#                       'availableBikes': 7,
#                       'availableDocks': 8,
#                       'city': 'Chicago',
#                       'id': 20,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '13154',
#                       'lastCommunicationTime': '2019-05-16 13:18:01',
#                       'latitude': 41.910522,
#                       'location': '',
#                       'longitude': -87.653106,
#                       'postalCode': '60642',
#                       'stAddress1': 'Sheffield Ave & Kingsbury St',
#                       'stAddress2': '',
#                       'stationName': 'Sheffield Ave & Kingsbury St',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 15},
#                      {'altitude': '',
#                       'availableBikes': 2,
#                       'availableDocks': 21,
#                       'city': 'Chicago',
#                       'id': 21,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '13157',
#                       'lastCommunicationTime': '2019-05-16 13:18:17',
#                       'latitude': 41.87772613,
#                       'location': '1103 W.Jackson Blvd',
#                       'longitude': -87.65478743,
#                       'postalCode': '60607',
#                       'stAddress1': 'Aberdeen St & Jackson Blvd',
#                       'stAddress2': '',
#                       'stationName': 'Aberdeen St & Jackson Blvd',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 23},
#                      {'altitude': '',
#                       'availableBikes': 3,
#                       'availableDocks': 12,
#                       'city': 'Chicago',
#                       'id': 22,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '13160',
#                       'lastCommunicationTime': '2019-05-16 13:17:44',
#                       'latitude': 41.8694821,
#                       'location': '1134 W. Taylor St',
#                       'longitude': -87.6554864,
#                       'postalCode': '60607',
#                       'stAddress1': 'May St & Taylor St',
#                       'stAddress2': '',
#                       'stationName': 'May St & Taylor St',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 15},
#                      {'altitude': '',
#                       'availableBikes': 0,
#                       'availableDocks': 16,
#                       'city': 'Chicago',
#                       'id': 23,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '13172',
#                       'lastCommunicationTime': '2019-05-16 13:18:32',
#                       'latitude': 41.902924,
#                       'location': '350 W. Elm st',
#                       'longitude': -87.637715,
#                       'postalCode': '60610',
#                       'stAddress1': 'Orleans St & Elm St (*)',
#                       'stAddress2': '',
#                       'stationName': 'Orleans St & Elm St (*)',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 16},
#                      {'altitude': '',
#                       'availableBikes': 14,
#                       'availableDocks': 1,
#                       'city': 'Chicago',
#                       'id': 24,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '13262',
#                       'lastCommunicationTime': '2019-05-16 13:20:07',
#                       'latitude': 41.89186,
#                       'location': '240 E.Grand Ave.',
#                       'longitude': -87.62062,
#                       'postalCode': '60611',
#                       'stAddress1': 'Fairbanks Ct & Grand Ave',
#                       'stAddress2': '',
#                       'stationName': 'Fairbanks Ct & Grand Ave',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 15},
#                      {'altitude': '',
#                       'availableBikes': 13,
#                       'availableDocks': 10,
#                       'city': 'Chicago',
#                       'id': 25,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '13034',
#                       'lastCommunicationTime': '2019-05-16 13:15:27',
#                       'latitude': 41.89766,
#                       'location': '150 E.Pearson st',
#                       'longitude': -87.62351,
#                       'postalCode': '60611',
#                       'stAddress1': 'Michigan Ave & Pearson St',
#                       'stAddress2': '',
#                       'stationName': 'Michigan Ave & Pearson St',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 23},
#                      {'altitude': '',
#                       'availableBikes': 9,
#                       'availableDocks': 22,
#                       'city': 'Chicago',
#                       'id': 26,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '13051',
#                       'lastCommunicationTime': '2019-05-16 13:17:54',
#                       'latitude': 41.890359,
#                       'location': '',
#                       'longitude': -87.617532,
#                       'postalCode': '60611',
#                       'stAddress1': 'McClurg Ct & Illinois St',
#                       'stAddress2': '',
#                       'stationName': 'McClurg Ct & Illinois St',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 31},
#                      {'altitude': '',
#                       'availableBikes': 8,
#                       'availableDocks': 11,
#                       'city': 'Chicago',
#                       'id': 27,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '13174',
#                       'lastCommunicationTime': '2019-05-16 13:17:01',
#                       'latitude': 41.91021,
#                       'location': '1530 N.Larrabee st',
#                       'longitude': -87.6435,
#                       'postalCode': '60610',
#                       'stAddress1': 'Larrabee St & North Ave',
#                       'stAddress2': '',
#                       'stationName': 'Larrabee St & North Ave',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 19},
#                      {'altitude': '',
#                       'availableBikes': 2,
#                       'availableDocks': 12,
#                       'city': 'Chicago',
#                       'id': 28,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '13282',
#                       'lastCommunicationTime': '2019-05-16 13:16:33',
#                       'latitude': 41.91468,
#                       'location': '590 W. Menomonee',
#                       'longitude': -87.64332,
#                       'postalCode': '60614',
#                       'stAddress1': 'Larrabee St & Menomonee St',
#                       'stAddress2': '',
#                       'stationName': 'Larrabee St & Menomonee St',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 15},
#                      {'altitude': '',
#                       'availableBikes': 5,
#                       'availableDocks': 9,
#                       'city': 'Chicago',
#                       'id': 29,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '13290',
#                       'lastCommunicationTime': '2019-05-16 13:19:50',
#                       'latitude': 41.90068,
#                       'location': '1016 N. Noble St',
#                       'longitude': -87.6626,
#                       'postalCode': '60642',
#                       'stAddress1': 'Noble St & Milwaukee Ave',
#                       'stAddress2': '',
#                       'stationName': 'Noble St & Milwaukee Ave',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 15},
#                      {'altitude': '',
#                       'availableBikes': 0,
#                       'availableDocks': 15,
#                       'city': 'Chicago',
#                       'id': 30,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '13248',
#                       'lastCommunicationTime': '2019-05-16 13:16:02',
#                       'latitude': 41.899643,
#                       'location': '1611 W. Augusta Blvd',
#                       'longitude': -87.6677,
#                       'postalCode': '60642',
#                       'stAddress1': 'Ashland Ave & Augusta Blvd',
#                       'stAddress2': '',
#                       'stationName': 'Ashland Ave & Augusta Blvd',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 15},
#                      {'altitude': '',
#                       'availableBikes': 18,
#                       'availableDocks': 5,
#                       'city': 'Chicago',
#                       'id': 31,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '13017',
#                       'lastCommunicationTime': '2019-05-16 13:17:57',
#                       'latitude': 41.896776,
#                       'location': '805 N. Franklin St',
#                       'longitude': -87.635633,
#                       'postalCode': '60654',
#                       'stAddress1': 'Franklin St & Chicago Ave',
#                       'stAddress2': '',
#                       'stationName': 'Franklin St & Chicago Ave',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 23},
#                      {'altitude': '',
#                       'availableBikes': 5,
#                       'availableDocks': 14,
#                       'city': 'Chicago',
#                       'id': 32,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '13076',
#                       'lastCommunicationTime': '2019-05-16 13:20:17',
#                       'latitude': 41.87464,
#                       'location': '550 S. Racine',
#                       'longitude': -87.65703,
#                       'postalCode': '60607',
#                       'stAddress1': 'Racine Ave & Congress Pkwy',
#                       'stAddress2': '',
#                       'stationName': 'Racine Ave & Congress Pkwy',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 19},
#                      {'altitude': '',
#                       'availableBikes': 9,
#                       'availableDocks': 18,
#                       'city': 'Chicago',
#                       'id': 33,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '13003',
#                       'lastCommunicationTime': '2019-05-16 13:20:02',
#                       'latitude': 41.877181,
#                       'location': '360 S State St',
#                       'longitude': -87.627844,
#                       'postalCode': '60604',
#                       'stAddress1': 'State St & Van Buren St',
#                       'stAddress2': '',
#                       'stationName': 'State St & Van Buren St',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 27},
#                      {'altitude': '',
#                       'availableBikes': 7,
#                       'availableDocks': 8,
#                       'city': 'Chicago',
#                       'id': 34,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '13124',
#                       'lastCommunicationTime': '2019-05-16 13:17:05',
#                       'latitude': 41.9267559875,
#                       'location': '2432 N. Cannon Dr.',
#                       'longitude': -87.6344287848,
#                       'postalCode': '60614',
#                       'stAddress1': 'Cannon Dr & Fullerton Ave',
#                       'stAddress2': '',
#                       'stationName': 'Cannon Dr & Fullerton Ave',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 15},
#                      {'altitude': '',
#                       'availableBikes': 26,
#                       'availableDocks': 21,
#                       'city': 'Chicago',
#                       'id': 35,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '13022',
#                       'lastCommunicationTime': '2019-05-16 13:18:00',
#                       'latitude': 41.892278,
#                       'location': 'Navy Pier',
#                       'longitude': -87.612043,
#                       'postalCode': '60611',
#                       'stAddress1': 'Streeter Dr & Grand Ave',
#                       'stAddress2': '',
#                       'stationName': 'Streeter Dr & Grand Ave',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 47},
#                      {'altitude': '',
#                       'availableBikes': 38,
#                       'availableDocks': 1,
#                       'city': 'Chicago',
#                       'id': 36,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '13019',
#                       'lastCommunicationTime': '2019-05-16 13:20:06',
#                       'latitude': 41.8777079559,
#                       'location': '340 S. Franklin St',
#                       'longitude': -87.6353211408,
#                       'postalCode': '60606',
#                       'stAddress1': 'Franklin St & Jackson Blvd',
#                       'stAddress2': '',
#                       'stationName': 'Franklin St & Jackson Blvd',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 39},
#                      {'altitude': '',
#                       'availableBikes': 15,
#                       'availableDocks': 4,
#                       'city': 'Chicago',
#                       'id': 37,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '13020',
#                       'lastCommunicationTime': '2019-05-16 13:16:18',
#                       'latitude': 41.8793563587,
#                       'location': '59 W. Adams St ',
#                       'longitude': -87.6297910363,
#                       'postalCode': '60603',
#                       'stAddress1': 'Dearborn St & Adams St',
#                       'stAddress2': '',
#                       'stationName': 'Dearborn St & Adams St',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 19},
#                      {'altitude': '',
#                       'availableBikes': 22,
#                       'availableDocks': 5,
#                       'city': 'Chicago',
#                       'id': 38,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '15547',
#                       'lastCommunicationTime': '2019-05-16 13:19:42',
#                       'latitude': 41.88602082773,
#                       'location': '',
#                       'longitude': -87.6308760584,
#                       'postalCode': '60601',
#                       'stAddress1': 'Clark St & Lake St',
#                       'stAddress2': '',
#                       'stationName': 'Clark St & Lake St',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 27},
#                      {'altitude': '',
#                       'availableBikes': 13,
#                       'availableDocks': 9,
#                       'city': 'Chicago',
#                       'id': 39,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '15538',
#                       'lastCommunicationTime': '2019-05-16 13:16:40',
#                       'latitude': 41.87947235235,
#                       'location': '',
#                       'longitude': -87.6256886059,
#                       'postalCode': '60603',
#                       'stAddress1': 'Wabash Ave & Adams St',
#                       'stAddress2': '',
#                       'stationName': 'Wabash Ave & Adams St',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 23},
#                      {'altitude': '',
#                       'availableBikes': 15,
#                       'availableDocks': 0,
#                       'city': 'Chicago',
#                       'id': 40,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '15537',
#                       'lastCommunicationTime': '2019-05-16 13:18:35',
#                       'latitude': 41.87934437346,
#                       'location': '',
#                       'longitude': -87.6319852213,
#                       'postalCode': '60603',
#                       'stAddress1': 'LaSalle St & Adams St',
#                       'stAddress2': '',
#                       'stationName': 'LaSalle St & Adams St',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 15},
#                      {'altitude': '',
#                       'availableBikes': 2,
#                       'availableDocks': 17,
#                       'city': 'Chicago',
#                       'id': 41,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '15543',
#                       'lastCommunicationTime': '2019-05-16 13:17:18',
#                       'latitude': 41.87207763285,
#                       'location': '',
#                       'longitude': -87.6295437729,
#                       'postalCode': '60605',
#                       'stAddress1': 'Federal St & Polk St',
#                       'stAddress2': '',
#                       'stationName': 'Federal St & Polk St',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 19},
#                      {'altitude': '',
#                       'availableBikes': 7,
#                       'availableDocks': 4,
#                       'city': 'Chicago',
#                       'id': 42,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '13170',
#                       'lastCommunicationTime': '2019-05-16 13:19:28',
#                       'latitude': 41.852619,
#                       'location': '13 E Cermak Rd',
#                       'longitude': -87.626488,
#                       'postalCode': '60616',
#                       'stAddress1': 'Wabash Ave & Cermak Rd',
#                       'stAddress2': 'CTA Green Line - Cermak Stop',
#                       'stationName': 'Wabash Ave & Cermak Rd',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 11},
#                      {'altitude': '',
#                       'availableBikes': 41,
#                       'availableDocks': 2,
#                       'city': 'Chicago',
#                       'id': 43,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '13001',
#                       'lastCommunicationTime': '2019-05-16 13:18:19',
#                       'latitude': 41.88355,
#                       'location': '120 N Michigan',
#                       'longitude': -87.62418,
#                       'postalCode': '60602',
#                       'stAddress1': 'Michigan Ave & Washington St',
#                       'stAddress2': '',
#                       'stationName': 'Michigan Ave & Washington St',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 43},
#                      {'altitude': '',
#                       'availableBikes': 25,
#                       'availableDocks': 1,
#                       'city': 'Chicago',
#                       'id': 44,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '13002',
#                       'lastCommunicationTime': '2019-05-16 13:19:50',
#                       'latitude': 41.8847302006,
#                       'location': '',
#                       'longitude': -87.6277335692,
#                       'postalCode': '60601',
#                       'stAddress1': 'State St & Randolph St',
#                       'stAddress2': '',
#                       'stationName': 'State St & Randolph St',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 27},
#                      {'altitude': '',
#                       'availableBikes': 3,
#                       'availableDocks': 12,
#                       'city': 'Chicago',
#                       'id': 45,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '13040',
#                       'lastCommunicationTime': '2019-05-16 13:19:14',
#                       'latitude': 41.876243,
#                       'location': '420 w. Michigan',
#                       'longitude': -87.624426,
#                       'postalCode': '60605',
#                       'stAddress1': 'Michigan Ave & Ida B Wells Dr',
#                       'stAddress2': '',
#                       'stationName': 'Michigan Ave & Ida B Wells Dr',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 15},
#                      {'altitude': '',
#                       'availableBikes': 0,
#                       'availableDocks': 19,
#                       'city': 'Chicago',
#                       'id': 46,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '13046',
#                       'lastCommunicationTime': '2019-05-16 13:19:28',
#                       'latitude': 41.89993001,
#                       'location': '932 N Wells St',
#                       'longitude': -87.63443007,
#                       'postalCode': '60610',
#                       'stAddress1': 'Wells St & Walton St',
#                       'stAddress2': '',
#                       'stationName': 'Wells St & Walton St',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 19},
#                      {'altitude': '',
#                       'availableBikes': 15,
#                       'availableDocks': 16,
#                       'city': 'Chicago',
#                       'id': 47,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '13050',
#                       'lastCommunicationTime': '2019-05-16 13:17:16',
#                       'latitude': 41.889187,
#                       'location': '5 E Kinzie St',
#                       'longitude': -87.627754,
#                       'postalCode': '60654',
#                       'stAddress1': 'State St & Kinzie St',
#                       'stAddress2': '',
#                       'stationName': 'State St & Kinzie St',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 31},
#                      {'altitude': '',
#                       'availableBikes': 42,
#                       'availableDocks': 1,
#                       'city': 'Chicago',
#                       'id': 48,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '13012',
#                       'lastCommunicationTime': '2019-05-16 13:17:03',
#                       'latitude': 41.897764,
#                       'location': '840 N Larrabee St',
#                       'longitude': -87.642884,
#                       'postalCode': '60610',
#                       'stAddress1': 'Larrabee St & Kingsbury St',
#                       'stAddress2': '',
#                       'stationName': 'Larrabee St & Kingsbury St',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 43},
#                      {'altitude': '',
#                       'availableBikes': 37,
#                       'availableDocks': 1,
#                       'city': 'Chicago',
#                       'id': 49,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '13049',
#                       'lastCommunicationTime': '2019-05-16 13:17:38',
#                       'latitude': 41.881319815,
#                       'location': '80 S Dearborn St',
#                       'longitude': -87.6295209193,
#                       'postalCode': '60603',
#                       'stAddress1': 'Dearborn St & Monroe St',
#                       'stAddress2': '',
#                       'stationName': 'Dearborn St & Monroe St',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 39},
#                      {'altitude': '',
#                       'availableBikes': 7,
#                       'availableDocks': 28,
#                       'city': 'Chicago',
#                       'id': 50,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '13009',
#                       'lastCommunicationTime': '2019-05-16 13:19:46',
#                       'latitude': 41.8759326655,
#                       'location': '',
#                       'longitude': -87.6305845355,
#                       'postalCode': '60605',
#                       'stAddress1': 'Clark St & Ida B Wells Dr',
#                       'stAddress2': '',
#                       'stationName': 'Clark St & Ida B Wells Dr',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 35},
#                      {'altitude': '',
#                       'availableBikes': 37,
#                       'availableDocks': 2,
#                       'city': 'Chicago',
#                       'id': 51,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '13005',
#                       'lastCommunicationTime': '2019-05-16 13:18:07',
#                       'latitude': 41.884576228,
#                       'location': '120 W. Randolph St.',
#                       'longitude': -87.63188991,
#                       'postalCode': '60601',
#                       'stAddress1': 'Clark St & Randolph St',
#                       'stAddress2': '',
#                       'stationName': 'Clark St & Randolph St',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 39},
#                      {'altitude': '',
#                       'availableBikes': 35,
#                       'availableDocks': 0,
#                       'city': 'Chicago',
#                       'id': 52,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '13043',
#                       'lastCommunicationTime': '2019-05-16 13:16:22',
#                       'latitude': 41.886024,
#                       'location': '203 N Michigan Ave',
#                       'longitude': -87.624117,
#                       'postalCode': '60601',
#                       'stAddress1': 'Michigan Ave & Lake St',
#                       'stAddress2': '',
#                       'stationName': 'Michigan Ave & Lake St',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 35},
#                      {'altitude': '',
#                       'availableBikes': 3,
#                       'availableDocks': 24,
#                       'city': 'Chicago',
#                       'id': 53,
#                       'is_renting': True,
# ...
#                       'location': '',
#                       'longitude': -87.634774,
#                       'postalCode': '60621',
#                       'stAddress1': 'Stewart Ave & 63rd St (*)',
#                       'stAddress2': '',
#                       'stationName': 'Stewart Ave & 63rd St (*)',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 12},
#                      {'altitude': '',
#                       'availableBikes': 5,
#                       'availableDocks': 7,
#                       'city': 'Chicago',
#                       'id': 650,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '18027',
#                       'lastCommunicationTime': '2019-05-16 13:19:13',
#                       'latitude': 41.768898,
#                       'location': '',
#                       'longitude': -87.635876,
#                       'postalCode': '60621',
#                       'stAddress1': 'Eggleston Ave & 69th St (*)',
#                       'stAddress2': '',
#                       'stationName': 'Eggleston Ave & 69th St (*)',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 12},
#                      {'altitude': '',
#                       'availableBikes': 4,
#                       'availableDocks': 3,
#                       'city': 'Chicago',
#                       'id': 651,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '18028',
#                       'lastCommunicationTime': '2019-05-16 13:18:20',
#                       'latitude': 41.765286,
#                       'location': '',
#                       'longitude': -87.621748,
#                       'postalCode': '60619',
#                       'stAddress1': 'Michigan Ave & 71st St',
#                       'stAddress2': '',
#                       'stationName': 'Michigan Ave & 71st St',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 7},
#                      {'altitude': '',
#                       'availableBikes': 3,
#                       'availableDocks': 8,
#                       'city': 'Chicago',
#                       'id': 652,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '18029',
#                       'lastCommunicationTime': '2019-05-16 13:17:18',
#                       'latitude': 41.766,
#                       'location': '',
#                       'longitude': -87.611726,
#                       'postalCode': '60637',
#                       'stAddress1': 'Rhodes Ave & 71st St',
#                       'stAddress2': '',
#                       'stationName': 'Rhodes Ave & 71st St',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 11},
#                      {'altitude': '',
#                       'availableBikes': 7,
#                       'availableDocks': 4,
#                       'city': 'Chicago',
#                       'id': 653,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '18030',
#                       'lastCommunicationTime': '2019-05-16 13:17:02',
#                       'latitude': 41.780595,
#                       'location': '',
#                       'longitude': -87.584846,
#                       'postalCode': '60649',
#                       'stAddress1': 'Cornell Dr & Hayes Dr',
#                       'stAddress2': '',
#                       'stationName': 'Cornell Dr & Hayes Dr',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 11},
#                      {'altitude': '',
#                       'availableBikes': 0,
#                       'availableDocks': 12,
#                       'city': 'Chicago',
#                       'id': 654,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '18046',
#                       'lastCommunicationTime': '2019-05-16 13:19:24',
#                       'latitude': 41.883073,
#                       'location': '',
#                       'longitude': -87.656952,
#                       'postalCode': '60607',
#                       'stAddress1': 'Racine Ave & Washington Blvd (*)',
#                       'stAddress2': '',
#                       'stationName': 'Racine Ave & Washington Blvd (*)',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 12},
#                      {'altitude': '',
#                       'availableBikes': 6,
#                       'availableDocks': 9,
#                       'city': 'Chicago',
#                       'id': 655,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '18047',
#                       'lastCommunicationTime': '2019-05-16 13:18:47',
#                       'latitude': 41.979851,
#                       'location': '',
#                       'longitude': -87.681932,
#                       'postalCode': '60625',
#                       'stAddress1': 'Hoyne Ave & Balmoral Ave',
#                       'stAddress2': '',
#                       'stationName': 'Hoyne Ave & Balmoral Ave',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 15},
#                      {'altitude': '',
#                       'availableBikes': 9,
#                       'availableDocks': 7,
#                       'city': 'Chicago',
#                       'id': 656,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '18054',
#                       'lastCommunicationTime': '2019-05-16 13:16:35',
#                       'latitude': 41.885951,
#                       'location': '',
#                       'longitude': -87.677009,
#                       'postalCode': '60612',
#                       'stAddress1': 'Damen Ave & Walnut (Lake) St (*)',
#                       'stAddress2': '',
#                       'stationName': 'Damen Ave & Walnut (Lake) St (*)',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 16},
#                      {'altitude': '',
#                       'availableBikes': 0,
#                       'availableDocks': 15,
#                       'city': 'Chicago',
#                       'id': 657,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '18056',
#                       'lastCommunicationTime': '2019-05-16 13:19:36',
#                       'latitude': 41.899181,
#                       'location': '',
#                       'longitude': -87.6722,
#                       'postalCode': '60622',
#                       'stAddress1': 'Wood St & Augusta Blvd',
#                       'stAddress2': '',
#                       'stationName': 'Wood St & Augusta Blvd',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 15},
#                      {'altitude': '',
#                       'availableBikes': 6,
#                       'availableDocks': 10,
#                       'city': 'Chicago',
#                       'id': 658,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '18057',
#                       'lastCommunicationTime': '2019-05-16 13:17:18',
#                       'latitude': 41.902997,
#                       'location': '',
#                       'longitude': -87.683825,
#                       'postalCode': '60622',
#                       'stAddress1': 'Leavitt St & Division St (*)',
#                       'stAddress2': '',
#                       'stationName': 'Leavitt St & Division St (*)',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 16},
#                      {'altitude': '',
#                       'availableBikes': 2,
#                       'availableDocks': 12,
#                       'city': 'Chicago',
#                       'id': 659,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '18058',
#                       'lastCommunicationTime': '2019-05-16 13:16:11',
#                       'latitude': 41.895501,
#                       'location': '',
#                       'longitude': -87.682017,
#                       'postalCode': '60612',
#                       'stAddress1': 'Leavitt St & Chicago Ave',
#                       'stAddress2': '',
#                       'stationName': 'Leavitt St & Chicago Ave',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 15},
#                      {'altitude': '',
#                       'availableBikes': 9,
#                       'availableDocks': 6,
#                       'city': 'Chicago',
#                       'id': 660,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '18066',
#                       'lastCommunicationTime': '2019-05-16 13:17:26',
#                       'latitude': 42.004583,
#                       'location': '',
#                       'longitude': -87.661406,
#                       'postalCode': '60626',
#                       'stAddress1': 'Sheridan Rd & Columbia Ave',
#                       'stAddress2': '',
#                       'stationName': 'Sheridan Rd & Columbia Ave',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 15},
#                      {'altitude': '',
#                       'availableBikes': 8,
#                       'availableDocks': 7,
#                       'city': 'Evanston',
#                       'id': 661,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': 'E012',
#                       'lastCommunicationTime': '2019-05-16 13:16:55',
#                       'latitude': 42.057044,
#                       'location': '',
#                       'longitude': -87.686554,
#                       'postalCode': '60201',
#                       'stAddress1': 'Evanston Civic Center',
#                       'stAddress2': '',
#                       'stationName': 'Evanston Civic Center',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 15},
#                      {'altitude': '',
#                       'availableBikes': 7,
#                       'availableDocks': 8,
#                       'city': 'Evanston',
#                       'id': 662,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': 'E013',
#                       'lastCommunicationTime': '2019-05-16 13:18:30',
#                       'latitude': 42.023463,
#                       'location': '',
#                       'longitude': -87.699595,
#                       'postalCode': '60201',
#                       'stAddress1': 'Dodge Ave & Mulford St',
#                       'stAddress2': '',
#                       'stationName': 'Dodge Ave & Mulford St',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 15},
#                      {'altitude': '',
#                       'availableBikes': 6,
#                       'availableDocks': 9,
#                       'city': 'Evanston',
#                       'id': 663,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': 'E014',
#                       'lastCommunicationTime': '2019-05-16 13:18:23',
#                       'latitude': 42.064854,
#                       'location': '',
#                       'longitude': -87.715297,
#                       'postalCode': '60201',
#                       'stAddress1': 'Lincolnwood Dr & Central St',
#                       'stAddress2': '',
#                       'stationName': 'Lincolnwood Dr & Central St',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 15},
#                      {'altitude': '',
#                       'availableBikes': 4,
#                       'availableDocks': 12,
#                       'city': 'Chicago',
#                       'id': 664,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '18068',
#                       'lastCommunicationTime': '2019-05-16 13:20:11',
#                       'latitude': 41.939354,
#                       'location': '',
#                       'longitude': -87.683282,
#                       'postalCode': '60618',
#                       'stAddress1': 'Leavitt St & Belmont Ave (*)',
#                       'stAddress2': '',
#                       'stationName': 'Leavitt St & Belmont Ave (*)',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 16},
#                      {'altitude': '',
#                       'availableBikes': 4,
#                       'availableDocks': 3,
#                       'city': 'Chicago',
#                       'id': 665,
#                       'is_renting': True,
#                       'kioskType': 'K3_FULL',
#                       'landMark': '19031',
#                       'lastCommunicationTime': '2019-05-16 13:17:00',
#                       'latitude': 41.747363,
#                       'location': '',
#                       'longitude': -87.580046,
#                       'postalCode': '60617',
#                       'stAddress1': 'South Chicago Ave & Elliot Ave',
#                       'stAddress2': '',
#                       'stationName': 'South Chicago Ave & Elliot Ave',
#                       'status': 'IN_SERVICE',
#                       'statusKey': 1,
#                       'statusValue': 'In Service',
#                       'testStation': False,
#                       'totalDocks': 7}]}

# %%
# load data file into a dataframe
df__stations = pd.DataFrame(stations_json['stationBeanList'])

# %% [markdown]
# **Data preparation and cleaning**
# - We need to do some Data preparation and cleaning work
# - Notice the alltitude is BLANK below
# - And sometimes we have BLANK zip code

# %%
df__stations.tail()
# Out:
#     altitude  availableBikes  availableDocks      city   id  is_renting  \
# 603                        8               7  Evanston  661        True
# 604                        7               8  Evanston  662        True
# 605                        6               9  Evanston  663        True
# 606                        4              12   Chicago  664        True
# 607                        4               3   Chicago  665        True
#
#     kioskType landMark lastCommunicationTime   latitude     ...      \
# 603   K3_FULL     E012   2019-05-16 13:16:55  42.057044     ...
# 604   K3_FULL     E013   2019-05-16 13:18:30  42.023463     ...
# 605   K3_FULL     E014   2019-05-16 13:18:23  42.064854     ...
# 606   K3_FULL    18068   2019-05-16 13:20:11  41.939354     ...
# 607   K3_FULL    19031   2019-05-16 13:17:00  41.747363     ...
#
#      longitude  postalCode                      stAddress1 stAddress2  \
# 603 -87.686554       60201           Evanston Civic Center
# 604 -87.699595       60201          Dodge Ave & Mulford St
# 605 -87.715297       60201     Lincolnwood Dr & Central St
# 606 -87.683282       60618    Leavitt St & Belmont Ave (*)
# 607 -87.580046       60617  South Chicago Ave & Elliot Ave
#
#                         stationName      status statusKey  statusValue  \
# 603           Evanston Civic Center  IN_SERVICE         1   In Service
# 604          Dodge Ave & Mulford St  IN_SERVICE         1   In Service
# 605     Lincolnwood Dr & Central St  IN_SERVICE         1   In Service
# 606    Leavitt St & Belmont Ave (*)  IN_SERVICE         1   In Service
# 607  South Chicago Ave & Elliot Ave  IN_SERVICE         1   In Service
#
#     testStation  totalDocks
# 603       False          15
# 604       False          15
# 605       False          15
# 606       False          16
# 607       False           7
#
# [5 rows x 21 columns]

# %%
# Clean the BLANKs from the data

df__stations['altitude'] = df__stations['altitude'].apply(lambda x: 0 if x == '' else x)
df__stations['postalCode'] = df__stations['postalCode'].apply(lambda x: 0 if x == '' else x)

# %% [markdown]
# ## Note:
# - There is a bug in the divvy data feed ...
# - Sometimes they add an extra space to the city name
# - See the following two records from divvy feed; compare the city names
#
#
# ['0', '14', '13', **'Chicago'**, '111', 'True', 'K3_FULL', '13052', '2018-12-26 19:20:34', '41.894666', '', '-87.638437', '60654', 'Sedgwick St & Huron St', '', 'Sedgwick St & Huron St', 'IN_SERVICE', '1', 'In Service', 'False', '27']
#
# ['0', '7', '8', **'Chicago '**, '112', 'True', 'K3_FULL', '13053', '2018-12-26 19:20:49', '41.883668', '', '-87.64867', '60607', 'Green St & Randolph St', '', 'Green St & Randolph St', 'IN_SERVICE', '1', 'In Service', 'False', '15']

# %%
df__stations.city.value_counts()
# Out:
# Chicago     553
# Chicago      41
# Evanston     14
# Name: city, dtype: int64

# %%
#Remove the whitespace from the end of the city name

df__stations['city'] = df__stations['city'].apply(lambda x: 'Chicago' if x == 'Chicago ' else x)

# %%
#Sanity Test
df__stations.city.value_counts()
# Out:
# Chicago     594
# Evanston     14
# Name: city, dtype: int64

# %%
df__stations.head()
# Out:
#    altitude  availableBikes  availableDocks     city  id  is_renting  \
# 0         0              13              26  Chicago   2        True
# 1         0               6              49  Chicago   3        True
# 2         0              12              11  Chicago   4        True
# 3         0               0              22  Chicago   5        True
# 4         0               1              38  Chicago   6        True
#
#   kioskType landMark lastCommunicationTime   latitude     ...      longitude  \
# 0   K3_FULL    15541   2019-05-16 13:18:23  41.876470     ...     -87.620340
# 1   K3_FULL    15544   2019-05-16 13:17:09  41.867226     ...     -87.615355
# 2   K3_FULL    15545   2019-05-16 13:17:46  41.856268     ...     -87.613348
# 3   K3_FULL    13030   2019-05-16 13:18:46  41.874053     ...     -87.627716
# 4   K3_FULL    15548   2019-05-16 13:16:08  41.886976     ...     -87.612813
#
#    postalCode              stAddress1 stAddress2             stationName  \
# 0       60605     Buckingham Fountain                Buckingham Fountain
# 1           0          Shedd Aquarium                     Shedd Aquarium
# 2           0          Burnham Harbor                     Burnham Harbor
# 3       60605  State St & Harrison St             State St & Harrison St
# 4       60601          Dusable Harbor                     Dusable Harbor
#
#        status statusKey  statusValue testStation  totalDocks
# 0  IN_SERVICE         1   In Service       False          39
# 1  IN_SERVICE         1   In Service       False          55
# 2  IN_SERVICE         1   In Service       False          23
# 3  IN_SERVICE         1   In Service       False          23
# 4  IN_SERVICE         1   In Service       False          39
#
# [5 rows x 21 columns]

# %%
df__stations.dtypes
# Out:
# altitude                   int64
# availableBikes             int64
# availableDocks             int64
# city                      object
# id                         int64
# is_renting                  bool
# kioskType                 object
# landMark                  object
# lastCommunicationTime     object
# latitude                 float64
# location                  object
# longitude                float64
# postalCode                object
# stAddress1                object
# stAddress2                object
# stationName               object
# status                    object
# statusKey                  int64
# statusValue               object
# testStation                 bool
# totalDocks                 int64
# dtype: object

# %%
# lets store our data subset into a file
# This way you have a copy of data stored in a file 
# that you could use in case you want to debug a problem on the orginal data received

df__stations.to_csv('divvy_stations_logs.csv',sep=',', encoding='utf-8', index=False)

# %%
df_stations_json = df__stations.to_json(orient='records')

# %%
df_stations_json = json.loads(df_stations_json)

# %%
for station in df_stations_json:
    pprint(station)
# Out:
# {'altitude': 0,
#  'availableBikes': 13,
#  'availableDocks': 26,
#  'city': 'Chicago',
#  'id': 2,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '15541',
#  'lastCommunicationTime': '2019-05-16 13:18:23',
#  'latitude': 41.87647,
#  'location': '',
#  'longitude': -87.62034,
#  'postalCode': '60605',
#  'stAddress1': 'Buckingham Fountain',
#  'stAddress2': '',
#  'stationName': 'Buckingham Fountain',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 39}
# {'altitude': 0,
#  'availableBikes': 6,
#  'availableDocks': 49,
#  'city': 'Chicago',
#  'id': 3,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '15544',
#  'lastCommunicationTime': '2019-05-16 13:17:09',
#  'latitude': 41.8672259568,
#  'location': '',
#  'longitude': -87.6153553902,
#  'postalCode': 0,
#  'stAddress1': 'Shedd Aquarium',
#  'stAddress2': '',
#  'stationName': 'Shedd Aquarium',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 55}
# {'altitude': 0,
#  'availableBikes': 12,
#  'availableDocks': 11,
#  'city': 'Chicago',
#  'id': 4,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '15545',
#  'lastCommunicationTime': '2019-05-16 13:17:46',
#  'latitude': 41.856268,
#  'location': '',
#  'longitude': -87.613348,
#  'postalCode': 0,
#  'stAddress1': 'Burnham Harbor',
#  'stAddress2': '',
#  'stationName': 'Burnham Harbor',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 23}
# {'altitude': 0,
#  'availableBikes': 0,
#  'availableDocks': 22,
#  'city': 'Chicago',
#  'id': 5,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '13030',
#  'lastCommunicationTime': '2019-05-16 13:18:46',
#  'latitude': 41.874053,
#  'location': '620 S. State St.',
#  'longitude': -87.627716,
#  'postalCode': '60605',
#  'stAddress1': 'State St & Harrison St',
#  'stAddress2': '',
#  'stationName': 'State St & Harrison St',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 23}
# {'altitude': 0,
#  'availableBikes': 1,
#  'availableDocks': 38,
#  'city': 'Chicago',
#  'id': 6,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '15548',
#  'lastCommunicationTime': '2019-05-16 13:16:08',
#  'latitude': 41.886976,
#  'location': '',
#  'longitude': -87.612813,
#  'postalCode': '60601',
#  'stAddress1': 'Dusable Harbor',
#  'stAddress2': '',
#  'stationName': 'Dusable Harbor',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 39}
# {'altitude': 0,
#  'availableBikes': 0,
#  'availableDocks': 19,
#  'city': 'Chicago',
#  'id': 7,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '15534',
#  'lastCommunicationTime': '2019-05-16 13:15:52',
#  'latitude': 41.8863490627,
#  'location': '',
#  'longitude': -87.6175165471,
#  'postalCode': '60601',
#  'stAddress1': 'Field Blvd & South Water St',
#  'stAddress2': '',
#  'stationName': 'Field Blvd & South Water St',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 19}
# {'altitude': 0,
#  'availableBikes': 3,
#  'availableDocks': 12,
#  'city': 'Chicago',
#  'id': 9,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '15695',
#  'lastCommunicationTime': '2019-05-16 13:17:56',
#  'latitude': 41.8287920199,
#  'location': 'NA1',
#  'longitude': -87.6806044594,
#  'postalCode': '60609',
#  'stAddress1': 'Leavitt St & Archer Ave',
#  'stAddress2': '',
#  'stationName': 'Leavitt St & Archer Ave',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 15}
# {'altitude': 0,
#  'availableBikes': 10,
#  'availableDocks': 1,
#  'city': 'Chicago',
#  'id': 11,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '15496',
#  'lastCommunicationTime': '2019-05-16 13:19:55',
#  'latitude': 41.766638237,
#  'location': '',
#  'longitude': -87.5764501141,
#  'postalCode': '60649',
#  'stAddress1': 'Jeffery Blvd & 71st St',
#  'stAddress2': '',
#  'stationName': 'Jeffery Blvd & 71st St',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 11}
# {'altitude': 0,
#  'availableBikes': 6,
#  'availableDocks': 9,
#  'city': 'Chicago',
#  'id': 12,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '15497',
#  'lastCommunicationTime': '2019-05-16 13:18:56',
#  'latitude': 41.7664094567,
#  'location': 'MLSW',
#  'longitude': -87.5656875719,
#  'postalCode': '60649',
#  'stAddress1': 'South Shore Dr & 71st St',
#  'stAddress2': '',
#  'stationName': 'South Shore Dr & 71st St',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 15}
# {'altitude': 0,
#  'availableBikes': 15,
#  'availableDocks': 20,
#  'city': 'Chicago',
#  'id': 13,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '13066',
#  'lastCommunicationTime': '2019-05-16 13:17:44',
#  'latitude': 41.932418,
#  'location': '2790 N.Wilton Ave',
#  'longitude': -87.652705,
#  'postalCode': '60614',
#  'stAddress1': 'Wilton Ave & Diversey Pkwy',
#  'stAddress2': '',
#  'stationName': 'Wilton Ave & Diversey Pkwy',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 35}
# {'altitude': 0,
#  'availableBikes': 3,
#  'availableDocks': 12,
#  'city': 'Chicago',
#  'id': 14,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '13163',
#  'lastCommunicationTime': '2019-05-16 13:19:52',
#  'latitude': 41.858086,
#  'location': '962 W. 18th St',
#  'longitude': -87.651073,
#  'postalCode': '60608',
#  'stAddress1': 'Morgan St & 18th St',
#  'stAddress2': '',
#  'stationName': 'Morgan St & 18th St',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 15}
# {'altitude': 0,
#  'availableBikes': 2,
#  'availableDocks': 13,
#  'city': 'Chicago',
#  'id': 15,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '13164',
#  'lastCommunicationTime': '2019-05-16 13:18:10',
#  'latitude': 41.858166,
#  'location': '1726 S Racine Ave',
#  'longitude': -87.656495,
#  'postalCode': '60608',
#  'stAddress1': 'Racine Ave & 18th St',
#  'stAddress2': '',
#  'stationName': 'Racine Ave & 18th St',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 15}
# {'altitude': 0,
#  'availableBikes': 3,
#  'availableDocks': 12,
#  'city': 'Chicago',
#  'id': 16,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '13223',
#  'lastCommunicationTime': '2019-05-16 13:18:43',
#  'latitude': 41.910337,
#  'location': '1575 N Paulina Ave',
#  'longitude': -87.670072,
#  'postalCode': '60622',
#  'stAddress1': 'Paulina Ave & North Ave',
#  'stAddress2': '',
#  'stationName': 'Paulina Ave & North Ave',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 15}
# {'altitude': 0,
#  'availableBikes': 4,
#  'availableDocks': 19,
#  'city': 'Chicago',
#  'id': 17,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '13246',
#  'lastCommunicationTime': '2019-05-16 13:18:08',
#  'latitude': 41.903119,
#  'location': ' W. Divison St',
#  'longitude': -87.673935,
#  'postalCode': '60622',
#  'stAddress1': 'Honore St & Division St',
#  'stAddress2': '',
#  'stationName': 'Honore St & Division St',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 23}
# {'altitude': 0,
#  'availableBikes': 14,
#  'availableDocks': 5,
#  'city': 'Chicago',
#  'id': 18,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '15536',
#  'lastCommunicationTime': '2019-05-16 13:19:21',
#  'latitude': 41.883132,
#  'location': '',
#  'longitude': -87.637321,
#  'postalCode': '60606',
#  'stAddress1': 'Wacker Dr & Washington St',
#  'stAddress2': '',
#  'stationName': 'Wacker Dr & Washington St',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 19}
# {'altitude': 0,
#  'availableBikes': 0,
#  'availableDocks': 16,
#  'city': 'Chicago',
#  'id': 19,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '13139',
#  'lastCommunicationTime': '2019-05-16 13:16:09',
#  'latitude': 41.868968,
#  'location': '',
#  'longitude': -87.659141,
#  'postalCode': '60607',
#  'stAddress1': 'Loomis St & Taylor St (*)',
#  'stAddress2': '',
#  'stationName': 'Loomis St & Taylor St (*)',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 16}
# {'altitude': 0,
#  'availableBikes': 7,
#  'availableDocks': 8,
#  'city': 'Chicago',
#  'id': 20,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '13154',
#  'lastCommunicationTime': '2019-05-16 13:18:01',
#  'latitude': 41.910522,
#  'location': '',
#  'longitude': -87.653106,
#  'postalCode': '60642',
#  'stAddress1': 'Sheffield Ave & Kingsbury St',
#  'stAddress2': '',
#  'stationName': 'Sheffield Ave & Kingsbury St',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 15}
# {'altitude': 0,
#  'availableBikes': 2,
#  'availableDocks': 21,
#  'city': 'Chicago',
#  'id': 21,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '13157',
#  'lastCommunicationTime': '2019-05-16 13:18:17',
#  'latitude': 41.87772613,
#  'location': '1103 W.Jackson Blvd',
#  'longitude': -87.65478743,
#  'postalCode': '60607',
#  'stAddress1': 'Aberdeen St & Jackson Blvd',
#  'stAddress2': '',
#  'stationName': 'Aberdeen St & Jackson Blvd',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 23}
# {'altitude': 0,
#  'availableBikes': 3,
#  'availableDocks': 12,
#  'city': 'Chicago',
#  'id': 22,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '13160',
#  'lastCommunicationTime': '2019-05-16 13:17:44',
#  'latitude': 41.8694821,
#  'location': '1134 W. Taylor St',
#  'longitude': -87.6554864,
#  'postalCode': '60607',
#  'stAddress1': 'May St & Taylor St',
#  'stAddress2': '',
#  'stationName': 'May St & Taylor St',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 15}
# {'altitude': 0,
#  'availableBikes': 0,
#  'availableDocks': 16,
#  'city': 'Chicago',
#  'id': 23,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '13172',
#  'lastCommunicationTime': '2019-05-16 13:18:32',
#  'latitude': 41.902924,
#  'location': '350 W. Elm st',
#  'longitude': -87.637715,
#  'postalCode': '60610',
#  'stAddress1': 'Orleans St & Elm St (*)',
#  'stAddress2': '',
#  'stationName': 'Orleans St & Elm St (*)',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 16}
# {'altitude': 0,
#  'availableBikes': 14,
#  'availableDocks': 1,
#  'city': 'Chicago',
#  'id': 24,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '13262',
#  'lastCommunicationTime': '2019-05-16 13:20:07',
#  'latitude': 41.89186,
#  'location': '240 E.Grand Ave.',
#  'longitude': -87.62062,
#  'postalCode': '60611',
#  'stAddress1': 'Fairbanks Ct & Grand Ave',
#  'stAddress2': '',
#  'stationName': 'Fairbanks Ct & Grand Ave',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 15}
# {'altitude': 0,
#  'availableBikes': 13,
#  'availableDocks': 10,
#  'city': 'Chicago',
#  'id': 25,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '13034',
#  'lastCommunicationTime': '2019-05-16 13:15:27',
#  'latitude': 41.89766,
#  'location': '150 E.Pearson st',
#  'longitude': -87.62351,
#  'postalCode': '60611',
#  'stAddress1': 'Michigan Ave & Pearson St',
#  'stAddress2': '',
#  'stationName': 'Michigan Ave & Pearson St',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 23}
# {'altitude': 0,
#  'availableBikes': 9,
#  'availableDocks': 22,
#  'city': 'Chicago',
#  'id': 26,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '13051',
#  'lastCommunicationTime': '2019-05-16 13:17:54',
#  'latitude': 41.890359,
#  'location': '',
#  'longitude': -87.617532,
#  'postalCode': '60611',
#  'stAddress1': 'McClurg Ct & Illinois St',
#  'stAddress2': '',
#  'stationName': 'McClurg Ct & Illinois St',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 31}
# {'altitude': 0,
#  'availableBikes': 8,
#  'availableDocks': 11,
#  'city': 'Chicago',
#  'id': 27,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '13174',
#  'lastCommunicationTime': '2019-05-16 13:17:01',
#  'latitude': 41.91021,
#  'location': '1530 N.Larrabee st',
#  'longitude': -87.6435,
#  'postalCode': '60610',
#  'stAddress1': 'Larrabee St & North Ave',
#  'stAddress2': '',
#  'stationName': 'Larrabee St & North Ave',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 19}
# {'altitude': 0,
#  'availableBikes': 2,
#  'availableDocks': 12,
#  'city': 'Chicago',
#  'id': 28,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '13282',
#  'lastCommunicationTime': '2019-05-16 13:16:33',
#  'latitude': 41.91468,
#  'location': '590 W. Menomonee',
#  'longitude': -87.64332,
#  'postalCode': '60614',
#  'stAddress1': 'Larrabee St & Menomonee St',
#  'stAddress2': '',
#  'stationName': 'Larrabee St & Menomonee St',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 15}
# {'altitude': 0,
#  'availableBikes': 5,
#  'availableDocks': 9,
#  'city': 'Chicago',
#  'id': 29,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '13290',
#  'lastCommunicationTime': '2019-05-16 13:19:50',
#  'latitude': 41.90068,
#  'location': '1016 N. Noble St',
#  'longitude': -87.6626,
#  'postalCode': '60642',
#  'stAddress1': 'Noble St & Milwaukee Ave',
#  'stAddress2': '',
#  'stationName': 'Noble St & Milwaukee Ave',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 15}
# {'altitude': 0,
#  'availableBikes': 0,
#  'availableDocks': 15,
#  'city': 'Chicago',
#  'id': 30,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '13248',
#  'lastCommunicationTime': '2019-05-16 13:16:02',
#  'latitude': 41.899643,
#  'location': '1611 W. Augusta Blvd',
#  'longitude': -87.6677,
#  'postalCode': '60642',
#  'stAddress1': 'Ashland Ave & Augusta Blvd',
#  'stAddress2': '',
#  'stationName': 'Ashland Ave & Augusta Blvd',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 15}
# {'altitude': 0,
#  'availableBikes': 18,
#  'availableDocks': 5,
#  'city': 'Chicago',
#  'id': 31,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '13017',
#  'lastCommunicationTime': '2019-05-16 13:17:57',
#  'latitude': 41.896776,
#  'location': '805 N. Franklin St',
#  'longitude': -87.635633,
#  'postalCode': '60654',
#  'stAddress1': 'Franklin St & Chicago Ave',
#  'stAddress2': '',
#  'stationName': 'Franklin St & Chicago Ave',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 23}
# {'altitude': 0,
#  'availableBikes': 5,
#  'availableDocks': 14,
#  'city': 'Chicago',
#  'id': 32,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '13076',
#  'lastCommunicationTime': '2019-05-16 13:20:17',
#  'latitude': 41.87464,
#  'location': '550 S. Racine',
#  'longitude': -87.65703,
#  'postalCode': '60607',
#  'stAddress1': 'Racine Ave & Congress Pkwy',
#  'stAddress2': '',
#  'stationName': 'Racine Ave & Congress Pkwy',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 19}
# {'altitude': 0,
#  'availableBikes': 9,
#  'availableDocks': 18,
#  'city': 'Chicago',
#  'id': 33,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '13003',
#  'lastCommunicationTime': '2019-05-16 13:20:02',
#  'latitude': 41.877181,
#  'location': '360 S State St',
#  'longitude': -87.627844,
#  'postalCode': '60604',
#  'stAddress1': 'State St & Van Buren St',
#  'stAddress2': '',
#  'stationName': 'State St & Van Buren St',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 27}
# {'altitude': 0,
#  'availableBikes': 7,
#  'availableDocks': 8,
#  'city': 'Chicago',
#  'id': 34,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '13124',
#  'lastCommunicationTime': '2019-05-16 13:17:05',
#  'latitude': 41.9267559875,
#  'location': '2432 N. Cannon Dr.',
#  'longitude': -87.6344287848,
#  'postalCode': '60614',
#  'stAddress1': 'Cannon Dr & Fullerton Ave',
#  'stAddress2': '',
#  'stationName': 'Cannon Dr & Fullerton Ave',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 15}
# {'altitude': 0,
#  'availableBikes': 26,
#  'availableDocks': 21,
#  'city': 'Chicago',
#  'id': 35,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '13022',
#  'lastCommunicationTime': '2019-05-16 13:18:00',
#  'latitude': 41.892278,
#  'location': 'Navy Pier',
#  'longitude': -87.612043,
#  'postalCode': '60611',
#  'stAddress1': 'Streeter Dr & Grand Ave',
#  'stAddress2': '',
#  'stationName': 'Streeter Dr & Grand Ave',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 47}
# {'altitude': 0,
#  'availableBikes': 38,
#  'availableDocks': 1,
#  'city': 'Chicago',
#  'id': 36,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '13019',
#  'lastCommunicationTime': '2019-05-16 13:20:06',
#  'latitude': 41.8777079559,
#  'location': '340 S. Franklin St',
#  'longitude': -87.6353211408,
#  'postalCode': '60606',
#  'stAddress1': 'Franklin St & Jackson Blvd',
#  'stAddress2': '',
#  'stationName': 'Franklin St & Jackson Blvd',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 39}
# {'altitude': 0,
#  'availableBikes': 15,
#  'availableDocks': 4,
#  'city': 'Chicago',
#  'id': 37,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '13020',
#  'lastCommunicationTime': '2019-05-16 13:16:18',
#  'latitude': 41.8793563587,
#  'location': '59 W. Adams St ',
#  'longitude': -87.6297910363,
#  'postalCode': '60603',
#  'stAddress1': 'Dearborn St & Adams St',
#  'stAddress2': '',
#  'stationName': 'Dearborn St & Adams St',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 19}
# {'altitude': 0,
#  'availableBikes': 22,
#  'availableDocks': 5,
#  'city': 'Chicago',
#  'id': 38,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '15547',
#  'lastCommunicationTime': '2019-05-16 13:19:42',
#  'latitude': 41.8860208277,
#  'location': '',
#  'longitude': -87.6308760584,
#  'postalCode': '60601',
#  'stAddress1': 'Clark St & Lake St',
#  'stAddress2': '',
#  'stationName': 'Clark St & Lake St',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 27}
# {'altitude': 0,
#  'availableBikes': 13,
#  'availableDocks': 9,
#  'city': 'Chicago',
#  'id': 39,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '15538',
#  'lastCommunicationTime': '2019-05-16 13:16:40',
#  'latitude': 41.8794723523,
#  'location': '',
#  'longitude': -87.6256886059,
#  'postalCode': '60603',
#  'stAddress1': 'Wabash Ave & Adams St',
#  'stAddress2': '',
#  'stationName': 'Wabash Ave & Adams St',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 23}
# {'altitude': 0,
#  'availableBikes': 15,
#  'availableDocks': 0,
#  'city': 'Chicago',
#  'id': 40,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '15537',
#  'lastCommunicationTime': '2019-05-16 13:18:35',
#  'latitude': 41.8793443735,
#  'location': '',
#  'longitude': -87.6319852213,
#  'postalCode': '60603',
#  'stAddress1': 'LaSalle St & Adams St',
#  'stAddress2': '',
#  'stationName': 'LaSalle St & Adams St',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 15}
# {'altitude': 0,
#  'availableBikes': 2,
#  'availableDocks': 17,
#  'city': 'Chicago',
#  'id': 41,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '15543',
#  'lastCommunicationTime': '2019-05-16 13:17:18',
#  'latitude': 41.8720776329,
#  'location': '',
#  'longitude': -87.6295437729,
#  'postalCode': '60605',
#  'stAddress1': 'Federal St & Polk St',
#  'stAddress2': '',
#  'stationName': 'Federal St & Polk St',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 19}
# {'altitude': 0,
#  'availableBikes': 7,
#  'availableDocks': 4,
#  'city': 'Chicago',
#  'id': 42,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '13170',
#  'lastCommunicationTime': '2019-05-16 13:19:28',
#  'latitude': 41.852619,
#  'location': '13 E Cermak Rd',
#  'longitude': -87.626488,
#  'postalCode': '60616',
#  'stAddress1': 'Wabash Ave & Cermak Rd',
#  'stAddress2': 'CTA Green Line - Cermak Stop',
#  'stationName': 'Wabash Ave & Cermak Rd',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 11}
# {'altitude': 0,
#  'availableBikes': 41,
#  'availableDocks': 2,
#  'city': 'Chicago',
#  'id': 43,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '13001',
#  'lastCommunicationTime': '2019-05-16 13:18:19',
#  'latitude': 41.88355,
#  'location': '120 N Michigan',
#  'longitude': -87.62418,
#  'postalCode': '60602',
#  'stAddress1': 'Michigan Ave & Washington St',
#  'stAddress2': '',
#  'stationName': 'Michigan Ave & Washington St',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 43}
# {'altitude': 0,
#  'availableBikes': 25,
#  'availableDocks': 1,
#  'city': 'Chicago',
#  'id': 44,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '13002',
#  'lastCommunicationTime': '2019-05-16 13:19:50',
#  'latitude': 41.8847302006,
#  'location': '',
#  'longitude': -87.6277335692,
#  'postalCode': '60601',
#  'stAddress1': 'State St & Randolph St',
#  'stAddress2': '',
#  'stationName': 'State St & Randolph St',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 27}
# {'altitude': 0,
#  'availableBikes': 3,
#  'availableDocks': 12,
#  'city': 'Chicago',
#  'id': 45,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '13040',
#  'lastCommunicationTime': '2019-05-16 13:19:14',
#  'latitude': 41.876243,
#  'location': '420 w. Michigan',
#  'longitude': -87.624426,
#  'postalCode': '60605',
#  'stAddress1': 'Michigan Ave & Ida B Wells Dr',
#  'stAddress2': '',
#  'stationName': 'Michigan Ave & Ida B Wells Dr',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 15}
# {'altitude': 0,
#  'availableBikes': 0,
#  'availableDocks': 19,
#  'city': 'Chicago',
#  'id': 46,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '13046',
#  'lastCommunicationTime': '2019-05-16 13:19:28',
#  'latitude': 41.89993001,
#  'location': '932 N Wells St',
#  'longitude': -87.63443007,
#  'postalCode': '60610',
#  'stAddress1': 'Wells St & Walton St',
#  'stAddress2': '',
#  'stationName': 'Wells St & Walton St',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 19}
# {'altitude': 0,
#  'availableBikes': 15,
#  'availableDocks': 16,
#  'city': 'Chicago',
#  'id': 47,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '13050',
#  'lastCommunicationTime': '2019-05-16 13:17:16',
#  'latitude': 41.889187,
#  'location': '5 E Kinzie St',
#  'longitude': -87.627754,
#  'postalCode': '60654',
#  'stAddress1': 'State St & Kinzie St',
#  'stAddress2': '',
#  'stationName': 'State St & Kinzie St',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 31}
# {'altitude': 0,
#  'availableBikes': 42,
#  'availableDocks': 1,
#  'city': 'Chicago',
#  'id': 48,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '13012',
#  'lastCommunicationTime': '2019-05-16 13:17:03',
#  'latitude': 41.897764,
#  'location': '840 N Larrabee St',
#  'longitude': -87.642884,
#  'postalCode': '60610',
#  'stAddress1': 'Larrabee St & Kingsbury St',
#  'stAddress2': '',
#  'stationName': 'Larrabee St & Kingsbury St',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 43}
# {'altitude': 0,
#  'availableBikes': 37,
#  'availableDocks': 1,
#  'city': 'Chicago',
#  'id': 49,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '13049',
#  'lastCommunicationTime': '2019-05-16 13:17:38',
#  'latitude': 41.881319815,
#  'location': '80 S Dearborn St',
#  'longitude': -87.6295209193,
#  'postalCode': '60603',
#  'stAddress1': 'Dearborn St & Monroe St',
#  'stAddress2': '',
#  'stationName': 'Dearborn St & Monroe St',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 39}
# {'altitude': 0,
#  'availableBikes': 7,
#  'availableDocks': 28,
#  'city': 'Chicago',
#  'id': 50,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '13009',
#  'lastCommunicationTime': '2019-05-16 13:19:46',
#  'latitude': 41.8759326655,
#  'location': '',
#  'longitude': -87.6305845355,
#  'postalCode': '60605',
#  'stAddress1': 'Clark St & Ida B Wells Dr',
#  'stAddress2': '',
#  'stationName': 'Clark St & Ida B Wells Dr',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 35}
# {'altitude': 0,
#  'availableBikes': 37,
#  'availableDocks': 2,
#  'city': 'Chicago',
#  'id': 51,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '13005',
#  'lastCommunicationTime': '2019-05-16 13:18:07',
#  'latitude': 41.884576228,
#  'location': '120 W. Randolph St.',
#  'longitude': -87.63188991,
#  'postalCode': '60601',
#  'stAddress1': 'Clark St & Randolph St',
#  'stAddress2': '',
#  'stationName': 'Clark St & Randolph St',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 39}
# {'altitude': 0,
#  'availableBikes': 35,
#  'availableDocks': 0,
#  'city': 'Chicago',
#  'id': 52,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '13043',
#  'lastCommunicationTime': '2019-05-16 13:16:22',
#  'latitude': 41.886024,
#  'location': '203 N Michigan Ave',
#  'longitude': -87.624117,
#  'postalCode': '60601',
#  'stAddress1': 'Michigan Ave & Lake St',
#  'stAddress2': '',
#  'stationName': 'Michigan Ave & Lake St',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 35}
# {'altitude': 0,
#  'availableBikes': 3,
#  'availableDocks': 24,
#  'city': 'Chicago',
#  'id': 53,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '13064',
#  'lastCommunicationTime': '2019-05-16 13:20:04',
#  'latitude': 41.894722,
#  'location': '',
#  'longitude': -87.634362,
#  'postalCode': '60654',
#  'stAddress1': 'Wells St & Huron St',
#  'stAddress2': '',
#  'stationName': 'Wells St & Huron St',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 27}
# {'altitude': 0,
#  'availableBikes': 0,
#  'availableDocks': 18,
#  'city': 'Chicago',
#  'id': 54,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '13044',
#  'lastCommunicationTime': '2019-05-16 13:17:14',
#  'latitude': 41.896362458,
#  'location': '1040 W. Chicago Ave.',
#  'longitude': -87.6540612729,
#  'postalCode': '60642',
#  'stAddress1': 'Ogden Ave & Chicago Ave',
#  'stAddress2': '',
#  'stationName': 'Ogden Ave & Chicago Ave',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 19}
# {'altitude': 0,
#  'availableBikes': 9,
#  'availableDocks': 13,
#  'city': 'Chicago',
#  'id': 55,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '13166',
#  'lastCommunicationTime': '2019-05-16 13:20:01',
#  'latitude': 41.867324,
#  'location': '850 W Roosevelt Rd',
#  'longitude': -87.648625,
#  'postalCode': '60608',
#  'stAddress1': 'Halsted St & Roosevelt Rd',
#  'stAddress2': '',
#  'stationName': 'Halsted St & Roosevelt Rd',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 23}
# {'altitude': 0,
#  'availableBikes': 16,
#  'availableDocks': 11,
#  'city': 'Chicago',
#  'id': 56,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '13039',
#  'lastCommunicationTime': '2019-05-16 13:17:03',
#  'latitude': 41.888716036,
#  'location': '368 N. Desplaines St.',
#  'longitude': -87.6444478533,
#  'postalCode': '60661',
#  'stAddress1': 'Desplaines St & Kinzie St',
#  'stAddress2': '',
#  'stationName': 'Desplaines St & Kinzie St',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 27}
# {'altitude': 0,
#  'availableBikes': 2,
#  'availableDocks': 13,
#  'city': 'Chicago',
#  'id': 57,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '13327',
#  'lastCommunicationTime': '2019-05-16 13:17:14',
#  'latitude': 41.8671177825,
#  'location': '559 W Roosevelt Rd',
#  'longitude': -87.6410879593,
#  'postalCode': '60607',
#  'stAddress1': 'Clinton St & Roosevelt Rd',
#  'stAddress2': '',
#  'stationName': 'Clinton St & Roosevelt Rd',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 15}
# {'altitude': 0,
#  'availableBikes': 5,
#  'availableDocks': 17,
#  'city': 'Chicago',
#  'id': 58,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '13025',
#  'lastCommunicationTime': '2019-05-16 13:18:25',
#  'latitude': 41.916017,
#  'location': '',
#  'longitude': -87.668879,
#  'postalCode': '60622',
#  'stAddress1': 'Marshfield Ave & Cortland St',
#  'stAddress2': '',
#  'stationName': 'Marshfield Ave & Cortland St',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 23}
# {'altitude': 0,
#  'availableBikes': 0,
#  'availableDocks': 22,
#  'city': 'Chicago',
#  'id': 59,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '13031',
#  'lastCommunicationTime': '2019-05-16 13:16:12',
#  'latitude': 41.867227,
#  'location': '1210 S Wabash Ave',
#  'longitude': -87.625961,
#  'postalCode': '60605',
#  'stAddress1': 'Wabash Ave & Roosevelt Rd',
#  'stAddress2': '',
#  'stationName': 'Wabash Ave & Roosevelt Rd',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 23}
# {'altitude': 0,
#  'availableBikes': 9,
#  'availableDocks': 10,
#  'city': 'Chicago',
#  'id': 60,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '13058',
#  'lastCommunicationTime': '2019-05-16 13:17:25',
#  'latitude': 41.9105780349,
#  'location': '1575 N Dayton St',
#  'longitude': -87.6494219288,
#  'postalCode': '60642',
#  'stAddress1': 'Dayton St & North Ave',
#  'stAddress2': '',
#  'stationName': 'Dayton St & North Ave',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 19}
# {'altitude': 0,
#  'availableBikes': 6,
#  'availableDocks': 13,
#  'city': 'Chicago',
#  'id': 61,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '13221',
#  'lastCommunicationTime': '2019-05-16 13:16:45',
#  'latitude': 41.907655,
#  'location': '1416 N Wood St',
#  'longitude': -87.672552,
#  'postalCode': '60622',
#  'stAddress1': 'Wood St & Milwaukee Ave',
#  'stAddress2': '',
#  'stationName': 'Wood St & Milwaukee Ave',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 19}
# {'altitude': 0,
#  'availableBikes': 6,
#  'availableDocks': 21,
#  'city': 'Chicago',
#  'id': 62,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '13106',
#  'lastCommunicationTime': '2019-05-16 13:16:08',
#  'latitude': 41.8513751729,
#  'location': '2253 S Dr Martin Luther King Jr Dr',
#  'longitude': -87.6188346489,
#  'postalCode': '60616',
#  'stAddress1': 'McCormick Place',
#  'stAddress2': '',
#  'stationName': 'McCormick Place',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 27}
# {'altitude': 0,
#  'availableBikes': 12,
#  'availableDocks': 10,
#  'city': 'Chicago',
#  'id': 66,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '13021',
#  'lastCommunicationTime': '2019-05-16 13:15:54',
#  'latitude': 41.885637,
#  'location': '',
#  'longitude': -87.641823,
#  'postalCode': '60661',
#  'stAddress1': 'Clinton St & Lake St',
#  'stAddress2': '',
#  'stationName': 'Clinton St & Lake St',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 23}
# {'altitude': 0,
#  'availableBikes': 23,
#  'availableDocks': 4,
#  'city': 'Chicago',
#  'id': 67,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '13060',
#  'lastCommunicationTime': '2019-05-16 13:18:34',
#  'latitude': 41.9256018819,
#  'location': '2410 N Sheffield Ave',
#  'longitude': -87.6537080423,
#  'postalCode': '60614',
#  'stAddress1': 'Sheffield Ave & Fullerton Ave',
#  'stAddress2': '',
#  'stationName': 'Sheffield Ave & Fullerton Ave',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 27}
# {'altitude': 0,
#  'availableBikes': 10,
#  'availableDocks': 13,
#  'city': 'Chicago',
#  'id': 68,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '13037',
#  'lastCommunicationTime': '2019-05-16 13:20:00',
#  'latitude': 41.875885,
#  'location': '520 W Tilden St',
#  'longitude': -87.640795,
#  'postalCode': '60607',
#  'stAddress1': 'Clinton St & Tilden St',
#  'stAddress2': '',
#  'stationName': 'Clinton St & Tilden St',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 23}
# {'altitude': 0,
#  'availableBikes': 11,
#  'availableDocks': 12,
#  'city': 'Chicago',
#  'id': 69,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '13065',
#  'lastCommunicationTime': '2019-05-16 13:17:27',
#  'latitude': 41.9093960065,
#  'location': '2002 W Pierce Ave',
#  'longitude': -87.6776919292,
#  'postalCode': '60622',
#  'stAddress1': 'Damen Ave & Pierce Ave',
#  'stAddress2': '',
#  'stationName': 'Damen Ave & Pierce Ave',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 23}
# {'altitude': 0,
#  'availableBikes': 13,
#  'availableDocks': 9,
#  'city': 'Chicago',
#  'id': 71,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '13072',
#  'lastCommunicationTime': '2019-05-16 13:19:56',
#  'latitude': 41.8854833079,
#  'location': '1003 W. Lake St.',
#  'longitude': -87.6523048564,
#  'postalCode': '60607',
#  'stAddress1': 'Morgan St & Lake St',
#  'stAddress2': '',
#  'stationName': 'Morgan St & Lake St',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 23}
# {'altitude': 0,
#  'availableBikes': 11,
#  'availableDocks': 28,
#  'city': 'Chicago',
#  'id': 72,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '13148',
#  'lastCommunicationTime': '2019-05-16 13:16:17',
#  'latitude': 41.860384,
#  'location': '1590 S Wabash Ave',
#  'longitude': -87.625813,
#  'postalCode': '60605',
#  'stAddress1': 'Wabash Ave & 16th St',
#  'stAddress2': '',
#  'stationName': 'Wabash Ave & 16th St',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 39}
# {'altitude': 0,
#  'availableBikes': 16,
#  'availableDocks': 3,
#  'city': 'Chicago',
#  'id': 73,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '13038',
#  'lastCommunicationTime': '2019-05-16 13:17:19',
#  'latitude': 41.880422,
#  'location': '207 S Jefferson St',
#  'longitude': -87.642746,
#  'postalCode': '60661',
#  'stAddress1': 'Jefferson St & Monroe St',
#  'stAddress2': '',
#  'stationName': 'Jefferson St & Monroe St',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 19}
# {'altitude': 0,
#  'availableBikes': 3,
#  'availableDocks': 20,
#  'city': 'Chicago',
#  'id': 74,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '13265',
#  'lastCommunicationTime': '2019-05-16 13:15:50',
#  'latitude': 41.893626,
#  'location': '511 W Erie St',
#  'longitude': -87.641527,
#  'postalCode': '60654',
#  'stAddress1': 'Kingsbury St & Erie St',
#  'stAddress2': '',
#  'stationName': 'Kingsbury St & Erie St',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 23}
# {'altitude': 0,
#  'availableBikes': 20,
#  'availableDocks': 19,
#  'city': 'Chicago',
#  'id': 75,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '13138',
#  'lastCommunicationTime': '2019-05-16 13:19:44',
#  'latitude': 41.877245,
#  'location': '',
#  'longitude': -87.639366,
#  'postalCode': '60661',
#  'stAddress1': 'Canal St & Jackson Blvd',
#  'stAddress2': '',
#  'stationName': 'Canal St & Jackson Blvd',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 39}
# {'altitude': 0,
#  'availableBikes': 17,
#  'availableDocks': 22,
#  'city': 'Chicago',
#  'id': 76,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '13300',
#  'lastCommunicationTime': '2019-05-16 13:16:29',
#  'latitude': 41.880958,
#  'location': '402 E Monroe St',
#  'longitude': -87.616743,
#  'postalCode': '60603',
#  'stAddress1': 'Lake Shore Dr & Monroe St',
#  'stAddress2': '',
#  'stationName': 'Lake Shore Dr & Monroe St',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 39}
# {'altitude': 0,
#  'availableBikes': 8,
#  'availableDocks': 23,
#  'city': 'Chicago',
#  'id': 77,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '13301',
#  'lastCommunicationTime': '2019-05-16 13:15:59',
#  'latitude': 41.882242,
#  'location': '5 N Clinton St',
#  'longitude': -87.641066,
#  'postalCode': '60661',
#  'stAddress1': 'Clinton St & Madison St',
#  'stAddress2': '',
#  'stationName': 'Clinton St & Madison St',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 31}
# {'altitude': 0,
#  'availableBikes': 14,
#  'availableDocks': 5,
#  'city': 'Chicago',
#  'id': 80,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '13156',
#  'lastCommunicationTime': '2019-05-16 13:20:02',
#  'latitude': 41.880419,
#  'location': '',
#  'longitude': -87.655519,
#  'postalCode': '60607',
#  'stAddress1': 'Aberdeen St & Monroe St',
#  'stAddress2': '',
#  'stationName': 'Aberdeen St & Monroe St',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 19}
# {'altitude': 0,
#  'availableBikes': 22,
#  'availableDocks': 17,
#  'city': 'Chicago',
#  'id': 81,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '13023',
#  'lastCommunicationTime': '2019-05-16 13:17:57',
#  'latitude': 41.884241,
#  'location': '',
#  'longitude': -87.629634,
#  'postalCode': '60601',
#  'stAddress1': 'Daley Center Plaza',
#  'stAddress2': '',
#  'stationName': 'Daley Center Plaza',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 39}
# {'altitude': 0,
#  'availableBikes': 1,
#  'availableDocks': 18,
#  'city': 'Chicago',
#  'id': 84,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '13033',
#  'lastCommunicationTime': '2019-05-16 13:16:51',
#  'latitude': 41.891578,
#  'location': '500 N Milwaukee Ave.',
#  'longitude': -87.648384,
#  'postalCode': '60654',
#  'stAddress1': 'Milwaukee Ave & Grand Ave',
#  'stAddress2': '',
#  'stationName': 'Milwaukee Ave & Grand Ave',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 19}
# {'altitude': 0,
#  'availableBikes': 10,
#  'availableDocks': 12,
#  'city': 'Chicago',
#  'id': 85,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '13042',
#  'lastCommunicationTime': '2019-05-16 13:18:02',
#  'latitude': 41.90096039,
#  'location': '140 E Oak St',
#  'longitude': -87.62377664,
#  'postalCode': '60611',
#  'stAddress1': 'Michigan Ave & Oak St',
#  'stAddress2': '',
#  'stationName': 'Michigan Ave & Oak St',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 23}
# {'altitude': 0,
#  'availableBikes': 7,
#  'availableDocks': 12,
#  'city': 'Chicago',
#  'id': 86,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '13289',
#  'lastCommunicationTime': '2019-05-16 13:16:04',
#  'latitude': 41.89637337,
#  'location': '811 N Noble St',
#  'longitude': -87.66098386,
#  'postalCode': '60642',
#  'stAddress1': 'Eckhart Park',
#  'stAddress2': '',
#  'stationName': 'Eckhart Park',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 19}
# {'altitude': 0,
#  'availableBikes': 2,
#  'availableDocks': 17,
#  'city': 'Chicago',
#  'id': 87,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '13189',
#  'lastCommunicationTime': '2019-05-16 13:19:33',
#  'latitude': 41.92556258,
#  'location': '2411 N Racine Ave',
#  'longitude': -87.65840426,
#  'postalCode': '60614',
#  'stAddress1': 'Racine Ave & Fullerton Ave',
#  'stAddress2': '',
#  'stationName': 'Racine Ave & Fullerton Ave',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 19}
# {'altitude': 0,
#  'availableBikes': 13,
#  'availableDocks': 6,
#  'city': 'Chicago',
#  'id': 88,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '13155',
#  'lastCommunicationTime': '2019-05-16 13:18:57',
#  'latitude': 41.884069,
#  'location': '1213 W Randolph St',
#  'longitude': -87.656853,
#  'postalCode': '60607',
#  'stAddress1': 'Racine Ave & Randolph St',
#  'stAddress2': '',
#  'stationName': 'Racine Ave & Randolph St',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 19}
# {'altitude': 0,
#  'availableBikes': 0,
#  'availableDocks': 15,
#  'city': 'Chicago',
#  'id': 89,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '15540',
#  'lastCommunicationTime': '2019-05-16 13:18:32',
#  'latitude': 41.874618,
#  'location': '',
#  'longitude': -87.632882,
#  'postalCode': '60605',
#  'stAddress1': 'Financial Pl & Ida B Wells Dr (Temp)',
#  'stAddress2': '',
#  'stationName': 'Financial Pl & Ida B Wells Dr (Temp)',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 15}
# {'altitude': 0,
#  'availableBikes': 33,
#  'availableDocks': 14,
#  'city': 'Chicago',
#  'id': 90,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '13008',
#  'lastCommunicationTime': '2019-05-16 13:20:16',
#  'latitude': 41.8810317,
#  'location': '33 S Michigan Ave',
#  'longitude': -87.62408432,
#  'postalCode': '60601',
#  'stAddress1': 'Millennium Park',
#  'stAddress2': '',
#  'stationName': 'Millennium Park',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 47}
# {'altitude': 0,
#  'availableBikes': 11,
#  'availableDocks': 20,
#  'city': 'Chicago',
#  'id': 91,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '13010',
#  'lastCommunicationTime': '2019-05-16 13:17:29',
#  'latitude': 41.88338,
#  'location': '109 N Clinton St',
#  'longitude': -87.64117,
#  'postalCode': '60661',
#  'stAddress1': 'Clinton St & Washington Blvd',
#  'stAddress2': '',
#  'stationName': 'Clinton St & Washington Blvd',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 31}
# {'altitude': 0,
#  'availableBikes': 4,
#  'availableDocks': 15,
#  'city': 'Chicago',
#  'id': 92,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '13196',
#  'lastCommunicationTime': '2019-05-16 13:18:42',
#  'latitude': 41.894556,
#  'location': '',
#  'longitude': -87.653449,
#  'postalCode': '60642',
#  'stAddress1': 'Carpenter St & Huron St',
#  'stAddress2': '',
#  'stationName': 'Carpenter St & Huron St',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 19}
# {'altitude': 0,
#  'availableBikes': 5,
#  'availableDocks': 10,
#  'city': 'Chicago',
#  'id': 93,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '13190',
#  'lastCommunicationTime': '2019-05-16 13:19:30',
#  'latitude': 41.913688,
#  'location': '1740 N Sheffield Ave',
#  'longitude': -87.652855,
#  'postalCode': '60614',
#  'stAddress1': 'Sheffield Ave & Willow St',
#  'stAddress2': '',
#  'stationName': 'Sheffield Ave & Willow St',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 15}
# {'altitude': 0,
#  'availableBikes': 19,
#  'availableDocks': 11,
#  'city': 'Chicago',
#  'id': 94,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '13146',
#  'lastCommunicationTime': '2019-05-16 13:20:13',
#  'latitude': 41.918306,
#  'location': '',
#  'longitude': -87.636282,
#  'postalCode': '60614',
#  'stAddress1': 'Clark St & Armitage Ave',
#  'stAddress2': '',
#  'stationName': 'Clark St & Armitage Ave',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 31}
# {'altitude': 0,
#  'availableBikes': 4,
#  'availableDocks': 7,
#  'city': 'Chicago',
#  'id': 95,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '15490',
#  'lastCommunicationTime': '2019-05-16 13:16:11',
#  'latitude': 41.778881,
#  'location': '',
#  'longitude': -87.586647,
#  'postalCode': '60637',
#  'stAddress1': 'Stony Island Ave & 64th St',
#  'stAddress2': '',
#  'stationName': 'Stony Island Ave & 64th St',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 11}
# {'altitude': 0,
#  'availableBikes': 10,
#  'availableDocks': 13,
#  'city': 'Chicago',
#  'id': 96,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '15535',
#  'lastCommunicationTime': '2019-05-16 13:16:29',
#  'latitude': 41.8846161896,
#  'location': '',
#  'longitude': -87.6445705849,
#  'postalCode': '60661',
#  'stAddress1': 'Desplaines St & Randolph St',
#  'stAddress2': '',
#  'stationName': 'Desplaines St & Randolph St',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 23}
# {'altitude': 0,
#  'availableBikes': 8,
#  'availableDocks': 47,
#  'city': 'Chicago',
#  'id': 97,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '13029',
#  'lastCommunicationTime': '2019-05-16 13:19:55',
#  'latitude': 41.865312,
#  'location': 'Off Street',
#  'longitude': -87.617867,
#  'postalCode': '60605',
#  'stAddress1': 'Field Museum',
#  'stAddress2': '',
#  'stationName': 'Field Museum',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 55}
# {'altitude': 0,
#  'availableBikes': 14,
#  'availableDocks': 1,
#  'city': 'Chicago',
#  'id': 98,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '13006',
#  'lastCommunicationTime': '2019-05-16 13:20:00',
#  'latitude': 41.882664,
#  'location': '',
#  'longitude': -87.63253,
#  'postalCode': '60602',
#  'stAddress1': 'LaSalle St & Washington St',
#  'stAddress2': '',
#  'stationName': 'LaSalle St & Washington St',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 15}
# {'altitude': 0,
#  'availableBikes': 7,
#  'availableDocks': 12,
#  'city': 'Chicago',
#  'id': 99,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '13337',
#  'lastCommunicationTime': '2019-05-16 13:18:17',
#  'latitude': 41.89257,
#  'location': '',
#  'longitude': -87.614492,
#  'postalCode': '60611',
#  'stAddress1': 'Lake Shore Dr & Ohio St',
#  'stAddress2': '',
#  'stationName': 'Lake Shore Dr & Ohio St',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 19}
# {'altitude': 0,
#  'availableBikes': 20,
#  'availableDocks': 15,
#  'city': 'Chicago',
#  'id': 100,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '13013',
#  'lastCommunicationTime': '2019-05-16 13:19:52',
#  'latitude': 41.888243,
#  'location': '333 N Orleans St',
#  'longitude': -87.63639,
#  'postalCode': '60654',
#  'stAddress1': 'Orleans St & Merchandise Mart Plaza',
#  'stAddress2': '',
#  'stationName': 'Orleans St & Merchandise Mart Plaza',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 35}
# {'altitude': 0,
#  'availableBikes': 2,
#  'availableDocks': 13,
#  'city': 'Chicago',
#  'id': 101,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '15491',
#  'lastCommunicationTime': '2019-05-16 13:16:50',
#  'latitude': 41.781016372,
#  'location': '',
#  'longitude': -87.5761197602,
#  'postalCode': '60649',
#  'stAddress1': '63rd St Beach',
#  'stAddress2': '',
#  'stationName': '63rd St Beach',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 15}
# {'altitude': 0,
#  'availableBikes': 6,
#  'availableDocks': 5,
#  'city': 'Chicago',
#  'id': 102,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '15492',
#  'lastCommunicationTime': '2019-05-16 13:17:25',
# ...
#  'location': '',
#  'longitude': -87.620104,
#  'postalCode': '60611',
#  'stAddress1': 'Fairbanks St & Superior St (*)',
#  'stAddress2': '',
#  'stationName': 'Fairbanks St & Superior St (*)',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 12}
# {'altitude': 0,
#  'availableBikes': 7,
#  'availableDocks': 5,
#  'city': 'Chicago',
#  'id': 636,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '18005',
#  'lastCommunicationTime': '2019-05-16 13:16:08',
#  'latitude': 41.890028,
#  'location': '',
#  'longitude': -87.636618,
#  'postalCode': '60654',
#  'stAddress1': 'Orleans St & Hubbard St (*)',
#  'stAddress2': '',
#  'stationName': 'Orleans St & Hubbard St (*)',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 12}
# {'altitude': 0,
#  'availableBikes': 6,
#  'availableDocks': 10,
#  'city': 'Chicago',
#  'id': 637,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '18006',
#  'lastCommunicationTime': '2019-05-16 13:17:15',
#  'latitude': 41.895634,
#  'location': '',
#  'longitude': -87.672069,
#  'postalCode': '60622',
#  'stAddress1': 'Wood St & Chicago Ave (*)',
#  'stAddress2': '',
#  'stationName': 'Wood St & Chicago Ave (*)',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 16}
# {'altitude': 0,
#  'availableBikes': 7,
#  'availableDocks': 25,
#  'city': 'Chicago',
#  'id': 638,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '18012',
#  'lastCommunicationTime': '2019-05-16 13:18:26',
#  'latitude': 41.878419,
#  'location': '',
#  'longitude': -87.640977,
#  'postalCode': '60661',
#  'stAddress1': 'Clinton St & Jackson Blvd (*)',
#  'stAddress2': '',
#  'stationName': 'Clinton St & Jackson Blvd (*)',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 32}
# {'altitude': 0,
#  'availableBikes': 9,
#  'availableDocks': 6,
#  'city': 'Chicago',
#  'id': 639,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '18014',
#  'lastCommunicationTime': '2019-05-16 13:17:37',
#  'latitude': 41.965845,
#  'location': '',
#  'longitude': -87.645361,
#  'postalCode': '60640',
#  'stAddress1': 'Lakefront Trail & Wilson Ave',
#  'stAddress2': '',
#  'stationName': 'Lakefront Trail & Wilson Ave',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 15}
# {'altitude': 0,
#  'availableBikes': 4,
#  'availableDocks': 7,
#  'city': 'Chicago',
#  'id': 640,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '18016',
#  'lastCommunicationTime': '2019-05-16 13:18:19',
#  'latitude': 41.949923,
#  'location': '',
#  'longitude': -87.713949,
#  'postalCode': '60618',
#  'stAddress1': 'Bernard St & Elston Ave',
#  'stAddress2': '',
#  'stationName': 'Bernard St & Elston Ave',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 11}
# {'altitude': 0,
#  'availableBikes': 1,
#  'availableDocks': 10,
#  'city': 'Chicago',
#  'id': 641,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '18017',
#  'lastCommunicationTime': '2019-05-16 13:19:24',
#  'latitude': 41.914166,
#  'location': '',
#  'longitude': -87.716755,
#  'postalCode': '60647',
#  'stAddress1': 'Central Park Ave & Bloomingdale Ave',
#  'stAddress2': '',
#  'stationName': 'Central Park Ave & Bloomingdale Ave',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 11}
# {'altitude': 0,
#  'availableBikes': 1,
#  'availableDocks': 6,
#  'city': 'Chicago',
#  'id': 642,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '18018',
#  'lastCommunicationTime': '2019-05-16 13:18:23',
#  'latitude': 41.894745,
#  'location': '',
#  'longitude': -87.756895,
#  'postalCode': '60644',
#  'stAddress1': 'Latrobe Ave & Chicago Ave',
#  'stAddress2': '',
#  'stationName': 'Latrobe Ave & Chicago Ave',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 7}
# {'altitude': 0,
#  'availableBikes': 2,
#  'availableDocks': 14,
#  'city': 'Chicago',
#  'id': 643,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '18019',
#  'lastCommunicationTime': '2019-05-16 13:16:36',
#  'latitude': 41.892048,
#  'location': '',
#  'longitude': -87.689397,
#  'postalCode': '60612',
#  'stAddress1': 'Smith Park (*)',
#  'stAddress2': '',
#  'stationName': 'Smith Park (*)',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 16}
# {'altitude': 0,
#  'availableBikes': 1,
#  'availableDocks': 11,
#  'city': 'Chicago',
#  'id': 644,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '18021',
#  'lastCommunicationTime': '2019-05-16 13:16:55',
#  'latitude': 41.868563,
#  'location': '',
#  'longitude': -87.686234,
#  'postalCode': '60612',
#  'stAddress1': 'Western Ave & Fillmore St (*)',
#  'stAddress2': '',
#  'stationName': 'Western Ave & Fillmore St (*)',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 12}
# {'altitude': 0,
#  'availableBikes': 8,
#  'availableDocks': 4,
#  'city': 'Chicago',
#  'id': 645,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '18022',
#  'lastCommunicationTime': '2019-05-16 13:17:31',
#  'latitude': 41.826712,
#  'location': '',
#  'longitude': -87.683144,
#  'postalCode': '60609',
#  'stAddress1': 'Archer (Damen) Ave & 37th St (*)',
#  'stAddress2': '',
#  'stationName': 'Archer (Damen) Ave & 37th St (*)',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 12}
# {'altitude': 0,
#  'availableBikes': 4,
#  'availableDocks': 7,
#  'city': 'Chicago',
#  'id': 646,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '18023',
#  'lastCommunicationTime': '2019-05-16 13:19:04',
#  'latitude': 41.796642,
#  'location': '',
#  'longitude': -87.625923,
#  'postalCode': '60609',
#  'stAddress1': 'State St & 54th St',
#  'stAddress2': '',
#  'stationName': 'State St & 54th St',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 11}
# {'altitude': 0,
#  'availableBikes': 3,
#  'availableDocks': 4,
#  'city': 'Chicago',
#  'id': 647,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '18024',
#  'lastCommunicationTime': '2019-05-16 13:18:34',
#  'latitude': 41.786691,
#  'location': '',
#  'longitude': -87.655859,
#  'postalCode': '60636',
#  'stAddress1': 'Elizabeth St & 59th St',
#  'stAddress2': '',
#  'stationName': 'Elizabeth St & 59th St',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 7}
# {'altitude': 0,
#  'availableBikes': 3,
#  'availableDocks': 4,
#  'city': 'Chicago',
#  'id': 648,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '18025',
#  'lastCommunicationTime': '2019-05-16 13:17:28',
#  'latitude': 41.77987,
#  'location': '',
#  'longitude': -87.650919,
#  'postalCode': '60621',
#  'stAddress1': 'Carpenter St & 63rd St',
#  'stAddress2': '',
#  'stationName': 'Carpenter St & 63rd St',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 7}
# {'altitude': 0,
#  'availableBikes': 8,
#  'availableDocks': 4,
#  'city': 'Chicago',
#  'id': 649,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '18026',
#  'lastCommunicationTime': '2019-05-16 13:18:09',
#  'latitude': 41.779835,
#  'location': '',
#  'longitude': -87.634774,
#  'postalCode': '60621',
#  'stAddress1': 'Stewart Ave & 63rd St (*)',
#  'stAddress2': '',
#  'stationName': 'Stewart Ave & 63rd St (*)',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 12}
# {'altitude': 0,
#  'availableBikes': 5,
#  'availableDocks': 7,
#  'city': 'Chicago',
#  'id': 650,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '18027',
#  'lastCommunicationTime': '2019-05-16 13:19:13',
#  'latitude': 41.768898,
#  'location': '',
#  'longitude': -87.635876,
#  'postalCode': '60621',
#  'stAddress1': 'Eggleston Ave & 69th St (*)',
#  'stAddress2': '',
#  'stationName': 'Eggleston Ave & 69th St (*)',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 12}
# {'altitude': 0,
#  'availableBikes': 4,
#  'availableDocks': 3,
#  'city': 'Chicago',
#  'id': 651,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '18028',
#  'lastCommunicationTime': '2019-05-16 13:18:20',
#  'latitude': 41.765286,
#  'location': '',
#  'longitude': -87.621748,
#  'postalCode': '60619',
#  'stAddress1': 'Michigan Ave & 71st St',
#  'stAddress2': '',
#  'stationName': 'Michigan Ave & 71st St',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 7}
# {'altitude': 0,
#  'availableBikes': 3,
#  'availableDocks': 8,
#  'city': 'Chicago',
#  'id': 652,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '18029',
#  'lastCommunicationTime': '2019-05-16 13:17:18',
#  'latitude': 41.766,
#  'location': '',
#  'longitude': -87.611726,
#  'postalCode': '60637',
#  'stAddress1': 'Rhodes Ave & 71st St',
#  'stAddress2': '',
#  'stationName': 'Rhodes Ave & 71st St',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 11}
# {'altitude': 0,
#  'availableBikes': 7,
#  'availableDocks': 4,
#  'city': 'Chicago',
#  'id': 653,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '18030',
#  'lastCommunicationTime': '2019-05-16 13:17:02',
#  'latitude': 41.780595,
#  'location': '',
#  'longitude': -87.584846,
#  'postalCode': '60649',
#  'stAddress1': 'Cornell Dr & Hayes Dr',
#  'stAddress2': '',
#  'stationName': 'Cornell Dr & Hayes Dr',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 11}
# {'altitude': 0,
#  'availableBikes': 0,
#  'availableDocks': 12,
#  'city': 'Chicago',
#  'id': 654,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '18046',
#  'lastCommunicationTime': '2019-05-16 13:19:24',
#  'latitude': 41.883073,
#  'location': '',
#  'longitude': -87.656952,
#  'postalCode': '60607',
#  'stAddress1': 'Racine Ave & Washington Blvd (*)',
#  'stAddress2': '',
#  'stationName': 'Racine Ave & Washington Blvd (*)',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 12}
# {'altitude': 0,
#  'availableBikes': 6,
#  'availableDocks': 9,
#  'city': 'Chicago',
#  'id': 655,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '18047',
#  'lastCommunicationTime': '2019-05-16 13:18:47',
#  'latitude': 41.979851,
#  'location': '',
#  'longitude': -87.681932,
#  'postalCode': '60625',
#  'stAddress1': 'Hoyne Ave & Balmoral Ave',
#  'stAddress2': '',
#  'stationName': 'Hoyne Ave & Balmoral Ave',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 15}
# {'altitude': 0,
#  'availableBikes': 9,
#  'availableDocks': 7,
#  'city': 'Chicago',
#  'id': 656,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '18054',
#  'lastCommunicationTime': '2019-05-16 13:16:35',
#  'latitude': 41.885951,
#  'location': '',
#  'longitude': -87.677009,
#  'postalCode': '60612',
#  'stAddress1': 'Damen Ave & Walnut (Lake) St (*)',
#  'stAddress2': '',
#  'stationName': 'Damen Ave & Walnut (Lake) St (*)',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 16}
# {'altitude': 0,
#  'availableBikes': 0,
#  'availableDocks': 15,
#  'city': 'Chicago',
#  'id': 657,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '18056',
#  'lastCommunicationTime': '2019-05-16 13:19:36',
#  'latitude': 41.899181,
#  'location': '',
#  'longitude': -87.6722,
#  'postalCode': '60622',
#  'stAddress1': 'Wood St & Augusta Blvd',
#  'stAddress2': '',
#  'stationName': 'Wood St & Augusta Blvd',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 15}
# {'altitude': 0,
#  'availableBikes': 6,
#  'availableDocks': 10,
#  'city': 'Chicago',
#  'id': 658,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '18057',
#  'lastCommunicationTime': '2019-05-16 13:17:18',
#  'latitude': 41.902997,
#  'location': '',
#  'longitude': -87.683825,
#  'postalCode': '60622',
#  'stAddress1': 'Leavitt St & Division St (*)',
#  'stAddress2': '',
#  'stationName': 'Leavitt St & Division St (*)',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 16}
# {'altitude': 0,
#  'availableBikes': 2,
#  'availableDocks': 12,
#  'city': 'Chicago',
#  'id': 659,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '18058',
#  'lastCommunicationTime': '2019-05-16 13:16:11',
#  'latitude': 41.895501,
#  'location': '',
#  'longitude': -87.682017,
#  'postalCode': '60612',
#  'stAddress1': 'Leavitt St & Chicago Ave',
#  'stAddress2': '',
#  'stationName': 'Leavitt St & Chicago Ave',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 15}
# {'altitude': 0,
#  'availableBikes': 9,
#  'availableDocks': 6,
#  'city': 'Chicago',
#  'id': 660,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '18066',
#  'lastCommunicationTime': '2019-05-16 13:17:26',
#  'latitude': 42.004583,
#  'location': '',
#  'longitude': -87.661406,
#  'postalCode': '60626',
#  'stAddress1': 'Sheridan Rd & Columbia Ave',
#  'stAddress2': '',
#  'stationName': 'Sheridan Rd & Columbia Ave',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 15}
# {'altitude': 0,
#  'availableBikes': 8,
#  'availableDocks': 7,
#  'city': 'Evanston',
#  'id': 661,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': 'E012',
#  'lastCommunicationTime': '2019-05-16 13:16:55',
#  'latitude': 42.057044,
#  'location': '',
#  'longitude': -87.686554,
#  'postalCode': '60201',
#  'stAddress1': 'Evanston Civic Center',
#  'stAddress2': '',
#  'stationName': 'Evanston Civic Center',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 15}
# {'altitude': 0,
#  'availableBikes': 7,
#  'availableDocks': 8,
#  'city': 'Evanston',
#  'id': 662,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': 'E013',
#  'lastCommunicationTime': '2019-05-16 13:18:30',
#  'latitude': 42.023463,
#  'location': '',
#  'longitude': -87.699595,
#  'postalCode': '60201',
#  'stAddress1': 'Dodge Ave & Mulford St',
#  'stAddress2': '',
#  'stationName': 'Dodge Ave & Mulford St',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 15}
# {'altitude': 0,
#  'availableBikes': 6,
#  'availableDocks': 9,
#  'city': 'Evanston',
#  'id': 663,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': 'E014',
#  'lastCommunicationTime': '2019-05-16 13:18:23',
#  'latitude': 42.064854,
#  'location': '',
#  'longitude': -87.715297,
#  'postalCode': '60201',
#  'stAddress1': 'Lincolnwood Dr & Central St',
#  'stAddress2': '',
#  'stationName': 'Lincolnwood Dr & Central St',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 15}
# {'altitude': 0,
#  'availableBikes': 4,
#  'availableDocks': 12,
#  'city': 'Chicago',
#  'id': 664,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '18068',
#  'lastCommunicationTime': '2019-05-16 13:20:11',
#  'latitude': 41.939354,
#  'location': '',
#  'longitude': -87.683282,
#  'postalCode': '60618',
#  'stAddress1': 'Leavitt St & Belmont Ave (*)',
#  'stAddress2': '',
#  'stationName': 'Leavitt St & Belmont Ave (*)',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 16}
# {'altitude': 0,
#  'availableBikes': 4,
#  'availableDocks': 3,
#  'city': 'Chicago',
#  'id': 665,
#  'is_renting': True,
#  'kioskType': 'K3_FULL',
#  'landMark': '19031',
#  'lastCommunicationTime': '2019-05-16 13:17:00',
#  'latitude': 41.747363,
#  'location': '',
#  'longitude': -87.580046,
#  'postalCode': '60617',
#  'stAddress1': 'South Chicago Ave & Elliot Ave',
#  'stAddress2': '',
#  'stationName': 'South Chicago Ave & Elliot Ave',
#  'status': 'IN_SERVICE',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 7}

# %%
list_station_documents = []

# %%
from elasticsearch import Elasticsearch, helpers

# %%
for station in df_stations_json:
        index_station = {  
            "_index": "divvy_stations_logs",
            "_type": "logs",
            "_source": station
        }
        list_station_documents.append(index_station)                      
pprint(list_station_documents)

es = Elasticsearch()
# Out:
# [{'_index': 'divvy_stations_logs',
#   '_source': {'altitude': 0,
#               'availableBikes': 13,
#               'availableDocks': 26,
#               'city': 'Chicago',
#               'id': 2,
#               'is_renting': True,
#               'kioskType': 'K3_FULL',
#               'landMark': '15541',
#               'lastCommunicationTime': '2019-05-16 13:18:23',
#               'latitude': 41.87647,
#               'location': '',
#               'longitude': -87.62034,
#               'postalCode': '60605',
#               'stAddress1': 'Buckingham Fountain',
#               'stAddress2': '',
#               'stationName': 'Buckingham Fountain',
#               'status': 'IN_SERVICE',
#               'statusKey': 1,
#               'statusValue': 'In Service',
#               'testStation': False,
#               'totalDocks': 39},
#   '_type': 'logs'},
#  {'_index': 'divvy_stations_logs',
#   '_source': {'altitude': 0,
#               'availableBikes': 6,
#               'availableDocks': 49,
#               'city': 'Chicago',
#               'id': 3,
#               'is_renting': True,
#               'kioskType': 'K3_FULL',
#               'landMark': '15544',
#               'lastCommunicationTime': '2019-05-16 13:17:09',
#               'latitude': 41.8672259568,
#               'location': '',
#               'longitude': -87.6153553902,
#               'postalCode': 0,
#               'stAddress1': 'Shedd Aquarium',
#               'stAddress2': '',
#               'stationName': 'Shedd Aquarium',
#               'status': 'IN_SERVICE',
#               'statusKey': 1,
#               'statusValue': 'In Service',
#               'testStation': False,
#               'totalDocks': 55},
#   '_type': 'logs'},
#  {'_index': 'divvy_stations_logs',
#   '_source': {'altitude': 0,
#               'availableBikes': 12,
#               'availableDocks': 11,
#               'city': 'Chicago',
#               'id': 4,
#               'is_renting': True,
#               'kioskType': 'K3_FULL',
#               'landMark': '15545',
#               'lastCommunicationTime': '2019-05-16 13:17:46',
#               'latitude': 41.856268,
#               'location': '',
#               'longitude': -87.613348,
#               'postalCode': 0,
#               'stAddress1': 'Burnham Harbor',
#               'stAddress2': '',
#               'stationName': 'Burnham Harbor',
#               'status': 'IN_SERVICE',
#               'statusKey': 1,
#               'statusValue': 'In Service',
#               'testStation': False,
#               'totalDocks': 23},
#   '_type': 'logs'},
#  {'_index': 'divvy_stations_logs',
#   '_source': {'altitude': 0,
#               'availableBikes': 0,
#               'availableDocks': 22,
#               'city': 'Chicago',
#               'id': 5,
#               'is_renting': True,
#               'kioskType': 'K3_FULL',
#               'landMark': '13030',
#               'lastCommunicationTime': '2019-05-16 13:18:46',
#               'latitude': 41.874053,
#               'location': '620 S. State St.',
#               'longitude': -87.627716,
#               'postalCode': '60605',
#               'stAddress1': 'State St & Harrison St',
#               'stAddress2': '',
#               'stationName': 'State St & Harrison St',
#               'status': 'IN_SERVICE',
#               'statusKey': 1,
#               'statusValue': 'In Service',
#               'testStation': False,
#               'totalDocks': 23},
#   '_type': 'logs'},
#  {'_index': 'divvy_stations_logs',
#   '_source': {'altitude': 0,
#               'availableBikes': 1,
#               'availableDocks': 38,
#               'city': 'Chicago',
#               'id': 6,
#               'is_renting': True,
#               'kioskType': 'K3_FULL',
#               'landMark': '15548',
#               'lastCommunicationTime': '2019-05-16 13:16:08',
#               'latitude': 41.886976,
#               'location': '',
#               'longitude': -87.612813,
#               'postalCode': '60601',
#               'stAddress1': 'Dusable Harbor',
#               'stAddress2': '',
#               'stationName': 'Dusable Harbor',
#               'status': 'IN_SERVICE',
#               'statusKey': 1,
#               'statusValue': 'In Service',
#               'testStation': False,
#               'totalDocks': 39},
#   '_type': 'logs'},
#  {'_index': 'divvy_stations_logs',
#   '_source': {'altitude': 0,
#               'availableBikes': 0,
#               'availableDocks': 19,
#               'city': 'Chicago',
#               'id': 7,
#               'is_renting': True,
#               'kioskType': 'K3_FULL',
#               'landMark': '15534',
#               'lastCommunicationTime': '2019-05-16 13:15:52',
#               'latitude': 41.8863490627,
#               'location': '',
#               'longitude': -87.6175165471,
#               'postalCode': '60601',
#               'stAddress1': 'Field Blvd & South Water St',
#               'stAddress2': '',
#               'stationName': 'Field Blvd & South Water St',
#               'status': 'IN_SERVICE',
#               'statusKey': 1,
#               'statusValue': 'In Service',
#               'testStation': False,
#               'totalDocks': 19},
#   '_type': 'logs'},
#  {'_index': 'divvy_stations_logs',
#   '_source': {'altitude': 0,
#               'availableBikes': 3,
#               'availableDocks': 12,
#               'city': 'Chicago',
#               'id': 9,
#               'is_renting': True,
#               'kioskType': 'K3_FULL',
#               'landMark': '15695',
#               'lastCommunicationTime': '2019-05-16 13:17:56',
#               'latitude': 41.8287920199,
#               'location': 'NA1',
#               'longitude': -87.6806044594,
#               'postalCode': '60609',
#               'stAddress1': 'Leavitt St & Archer Ave',
#               'stAddress2': '',
#               'stationName': 'Leavitt St & Archer Ave',
#               'status': 'IN_SERVICE',
#               'statusKey': 1,
#               'statusValue': 'In Service',
#               'testStation': False,
#               'totalDocks': 15},
#   '_type': 'logs'},
#  {'_index': 'divvy_stations_logs',
#   '_source': {'altitude': 0,
#               'availableBikes': 10,
#               'availableDocks': 1,
#               'city': 'Chicago',
#               'id': 11,
#               'is_renting': True,
#               'kioskType': 'K3_FULL',
#               'landMark': '15496',
#               'lastCommunicationTime': '2019-05-16 13:19:55',
#               'latitude': 41.766638237,
#               'location': '',
#               'longitude': -87.5764501141,
#               'postalCode': '60649',
#               'stAddress1': 'Jeffery Blvd & 71st St',
#               'stAddress2': '',
#               'stationName': 'Jeffery Blvd & 71st St',
#               'status': 'IN_SERVICE',
#               'statusKey': 1,
#               'statusValue': 'In Service',
#               'testStation': False,
#               'totalDocks': 11},
#   '_type': 'logs'},
#  {'_index': 'divvy_stations_logs',
#   '_source': {'altitude': 0,
#               'availableBikes': 6,
#               'availableDocks': 9,
#               'city': 'Chicago',
#               'id': 12,
#               'is_renting': True,
#               'kioskType': 'K3_FULL',
#               'landMark': '15497',
#               'lastCommunicationTime': '2019-05-16 13:18:56',
#               'latitude': 41.7664094567,
#               'location': 'MLSW',
#               'longitude': -87.5656875719,
#               'postalCode': '60649',
#               'stAddress1': 'South Shore Dr & 71st St',
#               'stAddress2': '',
#               'stationName': 'South Shore Dr & 71st St',
#               'status': 'IN_SERVICE',
#               'statusKey': 1,
#               'statusValue': 'In Service',
#               'testStation': False,
#               'totalDocks': 15},
#   '_type': 'logs'},
#  {'_index': 'divvy_stations_logs',
#   '_source': {'altitude': 0,
#               'availableBikes': 15,
#               'availableDocks': 20,
#               'city': 'Chicago',
#               'id': 13,
#               'is_renting': True,
#               'kioskType': 'K3_FULL',
#               'landMark': '13066',
#               'lastCommunicationTime': '2019-05-16 13:17:44',
#               'latitude': 41.932418,
#               'location': '2790 N.Wilton Ave',
#               'longitude': -87.652705,
#               'postalCode': '60614',
#               'stAddress1': 'Wilton Ave & Diversey Pkwy',
#               'stAddress2': '',
#               'stationName': 'Wilton Ave & Diversey Pkwy',
#               'status': 'IN_SERVICE',
#               'statusKey': 1,
#               'statusValue': 'In Service',
#               'testStation': False,
#               'totalDocks': 35},
#   '_type': 'logs'},
#  {'_index': 'divvy_stations_logs',
#   '_source': {'altitude': 0,
#               'availableBikes': 3,
#               'availableDocks': 12,
#               'city': 'Chicago',
#               'id': 14,
#               'is_renting': True,
#               'kioskType': 'K3_FULL',
#               'landMark': '13163',
#               'lastCommunicationTime': '2019-05-16 13:19:52',
#               'latitude': 41.858086,
#               'location': '962 W. 18th St',
#               'longitude': -87.651073,
#               'postalCode': '60608',
#               'stAddress1': 'Morgan St & 18th St',
#               'stAddress2': '',
#               'stationName': 'Morgan St & 18th St',
#               'status': 'IN_SERVICE',
#               'statusKey': 1,
#               'statusValue': 'In Service',
#               'testStation': False,
#               'totalDocks': 15},
#   '_type': 'logs'},
#  {'_index': 'divvy_stations_logs',
#   '_source': {'altitude': 0,
#               'availableBikes': 2,
#               'availableDocks': 13,
#               'city': 'Chicago',
#               'id': 15,
#               'is_renting': True,
#               'kioskType': 'K3_FULL',
#               'landMark': '13164',
#               'lastCommunicationTime': '2019-05-16 13:18:10',
#               'latitude': 41.858166,
#               'location': '1726 S Racine Ave',
#               'longitude': -87.656495,
#               'postalCode': '60608',
#               'stAddress1': 'Racine Ave & 18th St',
#               'stAddress2': '',
#               'stationName': 'Racine Ave & 18th St',
#               'status': 'IN_SERVICE',
#               'statusKey': 1,
#               'statusValue': 'In Service',
#               'testStation': False,
#               'totalDocks': 15},
#   '_type': 'logs'},
#  {'_index': 'divvy_stations_logs',
#   '_source': {'altitude': 0,
#               'availableBikes': 3,
#               'availableDocks': 12,
#               'city': 'Chicago',
#               'id': 16,
#               'is_renting': True,
#               'kioskType': 'K3_FULL',
#               'landMark': '13223',
#               'lastCommunicationTime': '2019-05-16 13:18:43',
#               'latitude': 41.910337,
#               'location': '1575 N Paulina Ave',
#               'longitude': -87.670072,
#               'postalCode': '60622',
#               'stAddress1': 'Paulina Ave & North Ave',
#               'stAddress2': '',
#               'stationName': 'Paulina Ave & North Ave',
#               'status': 'IN_SERVICE',
#               'statusKey': 1,
#               'statusValue': 'In Service',
#               'testStation': False,
#               'totalDocks': 15},
#   '_type': 'logs'},
#  {'_index': 'divvy_stations_logs',
#   '_source': {'altitude': 0,
#               'availableBikes': 4,
#               'availableDocks': 19,
#               'city': 'Chicago',
#               'id': 17,
#               'is_renting': True,
#               'kioskType': 'K3_FULL',
#               'landMark': '13246',
#               'lastCommunicationTime': '2019-05-16 13:18:08',
#               'latitude': 41.903119,
#               'location': ' W. Divison St',
#               'longitude': -87.673935,
#               'postalCode': '60622',
#               'stAddress1': 'Honore St & Division St',
#               'stAddress2': '',
#               'stationName': 'Honore St & Division St',
#               'status': 'IN_SERVICE',
#               'statusKey': 1,
#               'statusValue': 'In Service',
#               'testStation': False,
#               'totalDocks': 23},
#   '_type': 'logs'},
#  {'_index': 'divvy_stations_logs',
#   '_source': {'altitude': 0,
#               'availableBikes': 14,
#               'availableDocks': 5,
#               'city': 'Chicago',
#               'id': 18,
#               'is_renting': True,
#               'kioskType': 'K3_FULL',
#               'landMark': '15536',
#               'lastCommunicationTime': '2019-05-16 13:19:21',
#               'latitude': 41.883132,
#               'location': '',
#               'longitude': -87.637321,
#               'postalCode': '60606',
#               'stAddress1': 'Wacker Dr & Washington St',
#               'stAddress2': '',
#               'stationName': 'Wacker Dr & Washington St',
#               'status': 'IN_SERVICE',
#               'statusKey': 1,
#               'statusValue': 'In Service',
#               'testStation': False,
#               'totalDocks': 19},
#   '_type': 'logs'},
#  {'_index': 'divvy_stations_logs',
#   '_source': {'altitude': 0,
#               'availableBikes': 0,
#               'availableDocks': 16,
#               'city': 'Chicago',
#               'id': 19,
#               'is_renting': True,
#               'kioskType': 'K3_FULL',
#               'landMark': '13139',
#               'lastCommunicationTime': '2019-05-16 13:16:09',
#               'latitude': 41.868968,
#               'location': '',
#               'longitude': -87.659141,
#               'postalCode': '60607',
#               'stAddress1': 'Loomis St & Taylor St (*)',
#               'stAddress2': '',
#               'stationName': 'Loomis St & Taylor St (*)',
#               'status': 'IN_SERVICE',
#               'statusKey': 1,
#               'statusValue': 'In Service',
#               'testStation': False,
#               'totalDocks': 16},
#   '_type': 'logs'},
#  {'_index': 'divvy_stations_logs',
#   '_source': {'altitude': 0,
#               'availableBikes': 7,
#               'availableDocks': 8,
#               'city': 'Chicago',
#               'id': 20,
#               'is_renting': True,
#               'kioskType': 'K3_FULL',
#               'landMark': '13154',
#               'lastCommunicationTime': '2019-05-16 13:18:01',
#               'latitude': 41.910522,
#               'location': '',
#               'longitude': -87.653106,
#               'postalCode': '60642',
#               'stAddress1': 'Sheffield Ave & Kingsbury St',
#               'stAddress2': '',
#               'stationName': 'Sheffield Ave & Kingsbury St',
#               'status': 'IN_SERVICE',
#               'statusKey': 1,
#               'statusValue': 'In Service',
#               'testStation': False,
#               'totalDocks': 15},
#   '_type': 'logs'},
#  {'_index': 'divvy_stations_logs',
#   '_source': {'altitude': 0,
#               'availableBikes': 2,
#               'availableDocks': 21,
#               'city': 'Chicago',
#               'id': 21,
#               'is_renting': True,
#               'kioskType': 'K3_FULL',
#               'landMark': '13157',
#               'lastCommunicationTime': '2019-05-16 13:18:17',
#               'latitude': 41.87772613,
#               'location': '1103 W.Jackson Blvd',
#               'longitude': -87.65478743,
#               'postalCode': '60607',
#               'stAddress1': 'Aberdeen St & Jackson Blvd',
#               'stAddress2': '',
#               'stationName': 'Aberdeen St & Jackson Blvd',
#               'status': 'IN_SERVICE',
#               'statusKey': 1,
#               'statusValue': 'In Service',
#               'testStation': False,
#               'totalDocks': 23},
#   '_type': 'logs'},
#  {'_index': 'divvy_stations_logs',
#   '_source': {'altitude': 0,
#               'availableBikes': 3,
#               'availableDocks': 12,
#               'city': 'Chicago',
#               'id': 22,
#               'is_renting': True,
#               'kioskType': 'K3_FULL',
#               'landMark': '13160',
#               'lastCommunicationTime': '2019-05-16 13:17:44',
#               'latitude': 41.8694821,
#               'location': '1134 W. Taylor St',
#               'longitude': -87.6554864,
#               'postalCode': '60607',
#               'stAddress1': 'May St & Taylor St',
#               'stAddress2': '',
#               'stationName': 'May St & Taylor St',
#               'status': 'IN_SERVICE',
#               'statusKey': 1,
#               'statusValue': 'In Service',
#               'testStation': False,
#               'totalDocks': 15},
#   '_type': 'logs'},
#  {'_index': 'divvy_stations_logs',
#   '_source': {'altitude': 0,
#               'availableBikes': 0,
#               'availableDocks': 16,
#               'city': 'Chicago',
#               'id': 23,
#               'is_renting': True,
#               'kioskType': 'K3_FULL',
#               'landMark': '13172',
#               'lastCommunicationTime': '2019-05-16 13:18:32',
#               'latitude': 41.902924,
#               'location': '350 W. Elm st',
#               'longitude': -87.637715,
#               'postalCode': '60610',
#               'stAddress1': 'Orleans St & Elm St (*)',
#               'stAddress2': '',
#               'stationName': 'Orleans St & Elm St (*)',
#               'status': 'IN_SERVICE',
#               'statusKey': 1,
#               'statusValue': 'In Service',
#               'testStation': False,
#               'totalDocks': 16},
#   '_type': 'logs'},
#  {'_index': 'divvy_stations_logs',
#   '_source': {'altitude': 0,
#               'availableBikes': 14,
#               'availableDocks': 1,
#               'city': 'Chicago',
#               'id': 24,
#               'is_renting': True,
#               'kioskType': 'K3_FULL',
#               'landMark': '13262',
#               'lastCommunicationTime': '2019-05-16 13:20:07',
#               'latitude': 41.89186,
#               'location': '240 E.Grand Ave.',
#               'longitude': -87.62062,
#               'postalCode': '60611',
#               'stAddress1': 'Fairbanks Ct & Grand Ave',
#               'stAddress2': '',
#               'stationName': 'Fairbanks Ct & Grand Ave',
#               'status': 'IN_SERVICE',
#               'statusKey': 1,
#               'statusValue': 'In Service',
#               'testStation': False,
#               'totalDocks': 15},
#   '_type': 'logs'},
#  {'_index': 'divvy_stations_logs',
#   '_source': {'altitude': 0,
#               'availableBikes': 13,
#               'availableDocks': 10,
#               'city': 'Chicago',
#               'id': 25,
#               'is_renting': True,
#               'kioskType': 'K3_FULL',
#               'landMark': '13034',
#               'lastCommunicationTime': '2019-05-16 13:15:27',
#               'latitude': 41.89766,
#               'location': '150 E.Pearson st',
#               'longitude': -87.62351,
#               'postalCode': '60611',
#               'stAddress1': 'Michigan Ave & Pearson St',
#               'stAddress2': '',
#               'stationName': 'Michigan Ave & Pearson St',
#               'status': 'IN_SERVICE',
#               'statusKey': 1,
#               'statusValue': 'In Service',
#               'testStation': False,
#               'totalDocks': 23},
#   '_type': 'logs'},
#  {'_index': 'divvy_stations_logs',
#   '_source': {'altitude': 0,
#               'availableBikes': 9,
#               'availableDocks': 22,
#               'city': 'Chicago',
#               'id': 26,
#               'is_renting': True,
#               'kioskType': 'K3_FULL',
#               'landMark': '13051',
#               'lastCommunicationTime': '2019-05-16 13:17:54',
#               'latitude': 41.890359,
#               'location': '',
#               'longitude': -87.617532,
#               'postalCode': '60611',
#               'stAddress1': 'McClurg Ct & Illinois St',
#               'stAddress2': '',
#               'stationName': 'McClurg Ct & Illinois St',
#               'status': 'IN_SERVICE',
#               'statusKey': 1,
#               'statusValue': 'In Service',
#               'testStation': False,
#               'totalDocks': 31},
#   '_type': 'logs'},
#  {'_index': 'divvy_stations_logs',
#   '_source': {'altitude': 0,
#               'availableBikes': 8,
#               'availableDocks': 11,
#               'city': 'Chicago',
#               'id': 27,
#               'is_renting': True,
#               'kioskType': 'K3_FULL',
#               'landMark': '13174',
#               'lastCommunicationTime': '2019-05-16 13:17:01',
#               'latitude': 41.91021,
#               'location': '1530 N.Larrabee st',
#               'longitude': -87.6435,
#               'postalCode': '60610',
#               'stAddress1': 'Larrabee St & North Ave',
#               'stAddress2': '',
#               'stationName': 'Larrabee St & North Ave',
#               'status': 'IN_SERVICE',
#               'statusKey': 1,
#               'statusValue': 'In Service',
#               'testStation': False,
#               'totalDocks': 19},
#   '_type': 'logs'},
#  {'_index': 'divvy_stations_logs',
#   '_source': {'altitude': 0,
#               'availableBikes': 2,
#               'availableDocks': 12,
#               'city': 'Chicago',
#               'id': 28,
#               'is_renting': True,
#               'kioskType': 'K3_FULL',
#               'landMark': '13282',
#               'lastCommunicationTime': '2019-05-16 13:16:33',
#               'latitude': 41.91468,
#               'location': '590 W. Menomonee',
#               'longitude': -87.64332,
#               'postalCode': '60614',
#               'stAddress1': 'Larrabee St & Menomonee St',
#               'stAddress2': '',
#               'stationName': 'Larrabee St & Menomonee St',
#               'status': 'IN_SERVICE',
#               'statusKey': 1,
#               'statusValue': 'In Service',
#               'testStation': False,
#               'totalDocks': 15},
#   '_type': 'logs'},
#  {'_index': 'divvy_stations_logs',
#   '_source': {'altitude': 0,
#               'availableBikes': 5,
#               'availableDocks': 9,
#               'city': 'Chicago',
#               'id': 29,
#               'is_renting': True,
#               'kioskType': 'K3_FULL',
#               'landMark': '13290',
#               'lastCommunicationTime': '2019-05-16 13:19:50',
#               'latitude': 41.90068,
#               'location': '1016 N. Noble St',
#               'longitude': -87.6626,
#               'postalCode': '60642',
#               'stAddress1': 'Noble St & Milwaukee Ave',
#               'stAddress2': '',
#               'stationName': 'Noble St & Milwaukee Ave',
#               'status': 'IN_SERVICE',
#               'statusKey': 1,
#               'statusValue': 'In Service',
#               'testStation': False,
#               'totalDocks': 15},
#   '_type': 'logs'},
#  {'_index': 'divvy_stations_logs',
#   '_source': {'altitude': 0,
#               'availableBikes': 0,
#               'availableDocks': 15,
#               'city': 'Chicago',
#               'id': 30,
#               'is_renting': True,
#               'kioskType': 'K3_FULL',
#               'landMark': '13248',
#               'lastCommunicationTime': '2019-05-16 13:16:02',
#               'latitude': 41.899643,
#               'location': '1611 W. Augusta Blvd',
#               'longitude': -87.6677,
#               'postalCode': '60642',
#               'stAddress1': 'Ashland Ave & Augusta Blvd',
#               'stAddress2': '',
#               'stationName': 'Ashland Ave & Augusta Blvd',
#               'status': 'IN_SERVICE',
#               'statusKey': 1,
#               'statusValue': 'In Service',
#               'testStation': False,
#               'totalDocks': 15},
#   '_type': 'logs'},
#  {'_index': 'divvy_stations_logs',
#   '_source': {'altitude': 0,
#               'availableBikes': 18,
#               'availableDocks': 5,
#               'city': 'Chicago',
#               'id': 31,
#               'is_renting': True,
#               'kioskType': 'K3_FULL',
#               'landMark': '13017',
#               'lastCommunicationTime': '2019-05-16 13:17:57',
#               'latitude': 41.896776,
#               'location': '805 N. Franklin St',
#               'longitude': -87.635633,
#               'postalCode': '60654',
#               'stAddress1': 'Franklin St & Chicago Ave',
#               'stAddress2': '',
#               'stationName': 'Franklin St & Chicago Ave',
#               'status': 'IN_SERVICE',
#               'statusKey': 1,
#               'statusValue': 'In Service',
#               'testStation': False,
#               'totalDocks': 23},
#   '_type': 'logs'},
#  {'_index': 'divvy_stations_logs',
#   '_source': {'altitude': 0,
#               'availableBikes': 5,
#               'availableDocks': 14,
#               'city': 'Chicago',
#               'id': 32,
#               'is_renting': True,
#               'kioskType': 'K3_FULL',
#               'landMark': '13076',
#               'lastCommunicationTime': '2019-05-16 13:20:17',
#               'latitude': 41.87464,
#               'location': '550 S. Racine',
#               'longitude': -87.65703,
#               'postalCode': '60607',
#               'stAddress1': 'Racine Ave & Congress Pkwy',
#               'stAddress2': '',
#               'stationName': 'Racine Ave & Congress Pkwy',
#               'status': 'IN_SERVICE',
#               'statusKey': 1,
#               'statusValue': 'In Service',
#               'testStation': False,
#               'totalDocks': 19},
#   '_type': 'logs'},
#  {'_index': 'divvy_stations_logs',
#   '_source': {'altitude': 0,
#               'availableBikes': 9,
#               'availableDocks': 18,
#               'city': 'Chicago',
#               'id': 33,
#               'is_renting': True,
#               'kioskType': 'K3_FULL',
#               'landMark': '13003',
#               'lastCommunicationTime': '2019-05-16 13:20:02',
#               'latitude': 41.877181,
#               'location': '360 S State St',
#               'longitude': -87.627844,
#               'postalCode': '60604',
#               'stAddress1': 'State St & Van Buren St',
#               'stAddress2': '',
#               'stationName': 'State St & Van Buren St',
#               'status': 'IN_SERVICE',
#               'statusKey': 1,
#               'statusValue': 'In Service',
#               'testStation': False,
#               'totalDocks': 27},
#   '_type': 'logs'},
#  {'_index': 'divvy_stations_logs',
#   '_source': {'altitude': 0,
#               'availableBikes': 7,
#               'availableDocks': 8,
#               'city': 'Chicago',
#               'id': 34,
#               'is_renting': True,
#               'kioskType': 'K3_FULL',
#               'landMark': '13124',
#               'lastCommunicationTime': '2019-05-16 13:17:05',
#               'latitude': 41.9267559875,
#               'location': '2432 N. Cannon Dr.',
#               'longitude': -87.6344287848,
#               'postalCode': '60614',
#               'stAddress1': 'Cannon Dr & Fullerton Ave',
#               'stAddress2': '',
#               'stationName': 'Cannon Dr & Fullerton Ave',
#               'status': 'IN_SERVICE',
#               'statusKey': 1,
#               'statusValue': 'In Service',
#               'testStation': False,
#               'totalDocks': 15},
#   '_type': 'logs'},
#  {'_index': 'divvy_stations_logs',
#   '_source': {'altitude': 0,
#               'availableBikes': 26,
#               'availableDocks': 21,
#               'city': 'Chicago',
#               'id': 35,
#               'is_renting': True,
#               'kioskType': 'K3_FULL',
#               'landMark': '13022',
#               'lastCommunicationTime': '2019-05-16 13:18:00',
#               'latitude': 41.892278,
#               'location': 'Navy Pier',
#               'longitude': -87.612043,
#               'postalCode': '60611',
#               'stAddress1': 'Streeter Dr & Grand Ave',
#               'stAddress2': '',
#               'stationName': 'Streeter Dr & Grand Ave',
#               'status': 'IN_SERVICE',
#               'statusKey': 1,
#               'statusValue': 'In Service',
#               'testStation': False,
#               'totalDocks': 47},
#   '_type': 'logs'},
#  {'_index': 'divvy_stations_logs',
#   '_source': {'altitude': 0,
#               'availableBikes': 38,
#               'availableDocks': 1,
#               'city': 'Chicago',
#               'id': 36,
#               'is_renting': True,
#               'kioskType': 'K3_FULL',
#               'landMark': '13019',
#               'lastCommunicationTime': '2019-05-16 13:20:06',
#               'latitude': 41.8777079559,
#               'location': '340 S. Franklin St',
#               'longitude': -87.6353211408,
#               'postalCode': '60606',
#               'stAddress1': 'Franklin St & Jackson Blvd',
#               'stAddress2': '',
#               'stationName': 'Franklin St & Jackson Blvd',
#               'status': 'IN_SERVICE',
#               'statusKey': 1,
#               'statusValue': 'In Service',
#               'testStation': False,
#               'totalDocks': 39},
#   '_type': 'logs'},
#  {'_index': 'divvy_stations_logs',
#   '_source': {'altitude': 0,
#               'availableBikes': 15,
#               'availableDocks': 4,
#               'city': 'Chicago',
#               'id': 37,
#               'is_renting': True,
#               'kioskType': 'K3_FULL',
#               'landMark': '13020',
#               'lastCommunicationTime': '2019-05-16 13:16:18',
#               'latitude': 41.8793563587,
#               'location': '59 W. Adams St ',
#               'longitude': -87.6297910363,
#               'postalCode': '60603',
#               'stAddress1': 'Dearborn St & Adams St',
#               'stAddress2': '',
#               'stationName': 'Dearborn St & Adams St',
#               'status': 'IN_SERVICE',
#               'statusKey': 1,
#               'statusValue': 'In Service',
#               'testStation': False,
#               'totalDocks': 19},
#   '_type': 'logs'},
#  {'_index': 'divvy_stations_logs',
#   '_source': {'altitude': 0,
#               'availableBikes': 22,
#               'availableDocks': 5,
#               'city': 'Chicago',
#               'id': 38,
#               'is_renting': True,
#               'kioskType': 'K3_FULL',
#               'landMark': '15547',
#               'lastCommunicationTime': '2019-05-16 13:19:42',
#               'latitude': 41.8860208277,
#               'location': '',
#               'longitude': -87.6308760584,
#               'postalCode': '60601',
#               'stAddress1': 'Clark St & Lake St',
#               'stAddress2': '',
#               'stationName': 'Clark St & Lake St',
#               'status': 'IN_SERVICE',
#               'statusKey': 1,
#               'statusValue': 'In Service',
#               'testStation': False,
#               'totalDocks': 27},
#   '_type': 'logs'},
#  {'_index': 'divvy_stations_logs',
#   '_source': {'altitude': 0,
#               'availableBikes': 13,
#               'availableDocks': 9,
#               'city': 'Chicago',
#               'id': 39,
#               'is_renting': True,
#               'kioskType': 'K3_FULL',
#               'landMark': '15538',
#               'lastCommunicationTime': '2019-05-16 13:16:40',
#               'latitude': 41.8794723523,
#               'location': '',
#               'longitude': -87.6256886059,
#               'postalCode': '60603',
#               'stAddress1': 'Wabash Ave & Adams St',
#               'stAddress2': '',
#               'stationName': 'Wabash Ave & Adams St',
#               'status': 'IN_SERVICE',
#               'statusKey': 1,
#               'statusValue': 'In Service',
#               'testStation': False,
#               'totalDocks': 23},
#   '_type': 'logs'},
#  {'_index': 'divvy_stations_logs',
#   '_source': {'altitude': 0,
#               'availableBikes': 15,
#               'availableDocks': 0,
#               'city': 'Chicago',
#               'id': 40,
#               'is_renting': True,
#               'kioskType': 'K3_FULL',
#               'landMark': '15537',
#               'lastCommunicationTime': '2019-05-16 13:18:35',
#               'latitude': 41.8793443735,
#               'location': '',
#               'longitude': -87.6319852213,
#               'postalCode': '60603',
#               'stAddress1': 'LaSalle St & Adams St',
#               'stAddress2': '',
#               'stationName': 'LaSalle St & Adams St',
#               'status': 'IN_SERVICE',
#               'statusKey': 1,
#               'statusValue': 'In Service',
#               'testStation': False,
#               'totalDocks': 15},
#   '_type': 'logs'},
#  {'_index': 'divvy_stations_logs',
#   '_source': {'altitude': 0,
#               'availableBikes': 2,
#               'availableDocks': 17,
#               'city': 'Chicago',
#               'id': 41,
#               'is_renting': True,
#               'kioskType': 'K3_FULL',
#               'landMark': '15543',
#               'lastCommunicationTime': '2019-05-16 13:17:18',
#               'latitude': 41.8720776329,
#               'location': '',
#               'longitude': -87.6295437729,
#               'postalCode': '60605',
#               'stAddress1': 'Federal St & Polk St',
#               'stAddress2': '',
#               'stationName': 'Federal St & Polk St',
#               'status': 'IN_SERVICE',
#               'statusKey': 1,
#               'statusValue': 'In Service',
#               'testStation': False,
#               'totalDocks': 19},
#   '_type': 'logs'},
#  {'_index': 'divvy_stations_logs',
#   '_source': {'altitude': 0,
#               'availableBikes': 7,
#               'availableDocks': 4,
#               'city': 'Chicago',
#               'id': 42,
#               'is_renting': True,
#               'kioskType': 'K3_FULL',
#               'landMark': '13170',
#               'lastCommunicationTime': '2019-05-16 13:19:28',
#               'latitude': 41.852619,
#               'location': '13 E Cermak Rd',
#               'longitude': -87.626488,
#               'postalCode': '60616',
#               'stAddress1': 'Wabash Ave & Cermak Rd',
#               'stAddress2': 'CTA Green Line - Cermak Stop',
#               'stationName': 'Wabash Ave & Cermak Rd',
#               'status': 'IN_SERVICE',
#               'statusKey': 1,
#               'statusValue': 'In Service',
#               'testStation': False,
#               'totalDocks': 11},
#   '_type': 'logs'},
#  {'_index': 'divvy_stations_logs',
#   '_source': {'altitude': 0,
#               'availableBikes': 41,
#               'availableDocks': 2,
#               'city': 'Chicago',
#               'id': 43,
#               'is_renting': True,
#               'kioskType': 'K3_FULL',
#               'landMark': '13001',
#               'lastCommunicationTime': '2019-05-16 13:18:19',
#               'latitude': 41.88355,
#               'location': '120 N Michigan',
#               'longitude': -87.62418,
#               'postalCode': '60602',
#               'stAddress1': 'Michigan Ave & Washington St',
#               'stAddress2': '',
#               'stationName': 'Michigan Ave & Washington St',
#               'status': 'IN_SERVICE',
#               'statusKey': 1,
#               'statusValue': 'In Service',
#               'testStation': False,
#               'totalDocks': 43},
#   '_type': 'logs'},
#  {'_index': 'divvy_stations_logs',
#   '_source': {'altitude': 0,
#               'availableBikes': 25,
#               'availableDocks': 1,
#               'city': 'Chicago',
#               'id': 44,
#               'is_renting': True,
#               'kioskType': 'K3_FULL',
#               'landMark': '13002',
#               'lastCommunicationTime': '2019-05-16 13:19:50',
#               'latitude': 41.8847302006,
#               'location': '',
#               'longitude': -87.6277335692,
#               'postalCode': '60601',
#               'stAddress1': 'State St & Randolph St',
#               'stAddress2': '',
#               'stationName': 'State St & Randolph St',
#               'status': 'IN_SERVICE',
#               'statusKey': 1,
#               'statusValue': 'In Service',
#               'testStation': False,
#               'totalDocks': 27},
#   '_type': 'logs'},
#  {'_index': 'divvy_stations_logs',
#   '_source': {'altitude': 0,
#               'availableBikes': 3,
#               'availableDocks': 12,
#               'city': 'Chicago',
#               'id': 45,
#               'is_renting': True,
#               'kioskType': 'K3_FULL',
#               'landMark': '13040',
#               'lastCommunicationTime': '2019-05-16 13:19:14',
#               'latitude': 41.876243,
#               'location': '420 w. Michigan',
#               'longitude': -87.624426,
#               'postalCode': '60605',
#               'stAddress1': 'Michigan Ave & Ida B Wells Dr',
#               'stAddress2': '',
#               'stationName': 'Michigan Ave & Ida B Wells Dr',
#               'status': 'IN_SERVICE',
#               'statusKey': 1,
#               'statusValue': 'In Service',
#               'testStation': False,
#               'totalDocks': 15},
#   '_type': 'logs'},
#  {'_index': 'divvy_stations_logs',
#   '_source': {'altitude': 0,
#               'availableBikes': 0,
#               'availableDocks': 19,
#               'city': 'Chicago',
#               'id': 46,
#               'is_renting': True,
#               'kioskType': 'K3_FULL',
#               'landMark': '13046',
#               'lastCommunicationTime': '2019-05-16 13:19:28',
#               'latitude': 41.89993001,
#               'location': '932 N Wells St',
#               'longitude': -87.63443007,
#               'postalCode': '60610',
#               'stAddress1': 'Wells St & Walton St',
#               'stAddress2': '',
#               'stationName': 'Wells St & Walton St',
#               'status': 'IN_SERVICE',
#               'statusKey': 1,
#               'statusValue': 'In Service',
#               'testStation': False,
#               'totalDocks': 19},
#   '_type': 'logs'},
#  {'_index': 'divvy_stations_logs',
#   '_source': {'altitude': 0,
#               'availableBikes': 15,
#               'availableDocks': 16,
#               'city': 'Chicago',
#               'id': 47,
#               'is_renting': True,
#               'kioskType': 'K3_FULL',
#               'landMark': '13050',
#               'lastCommunicationTime': '2019-05-16 13:17:16',
#               'latitude': 41.889187,
#               'location': '5 E Kinzie St',
#               'longitude': -87.627754,
#               'postalCode': '60654',
#               'stAddress1': 'State St & Kinzie St',
#               'stAddress2': '',
#               'stationName': 'State St & Kinzie St',
#               'status': 'IN_SERVICE',
#               'statusKey': 1,
#               'statusValue': 'In Service',
#               'testStation': False,
#               'totalDocks': 31},
#   '_type': 'logs'},
#  {'_index': 'divvy_stations_logs',
#   '_source': {'altitude': 0,
#               'availableBikes': 42,
#               'availableDocks': 1,
#               'city': 'Chicago',
#               'id': 48,
#               'is_renting': True,
#               'kioskType': 'K3_FULL',
#               'landMark': '13012',
#               'lastCommunicationTime': '2019-05-16 13:17:03',
#               'latitude': 41.897764,
#               'location': '840 N Larrabee St',
#               'longitude': -87.642884,
#               'postalCode': '60610',
#               'stAddress1': 'Larrabee St & Kingsbury St',
#               'stAddress2': '',
#               'stationName': 'Larrabee St & Kingsbury St',
#               'status': 'IN_SERVICE',
#               'statusKey': 1,
#               'statusValue': 'In Service',
#               'testStation': False,
#               'totalDocks': 43},
#   '_type': 'logs'},
#  {'_index': 'divvy_stations_logs',
#   '_source': {'altitude': 0,
#               'availableBikes': 37,
#               'availableDocks': 1,
#               'city': 'Chicago',
#               'id': 49,
#               'is_renting': True,
#               'kioskType': 'K3_FULL',
#               'landMark': '13049',
#               'lastCommunicationTime': '2019-05-16 13:17:38',
#               'latitude': 41.881319815,
#               'location': '80 S Dearborn St',
#               'longitude': -87.6295209193,
#               'postalCode': '60603',
#               'stAddress1': 'Dearborn St & Monroe St',
#               'stAddress2': '',
#               'stationName': 'Dearborn St & Monroe St',
#               'status': 'IN_SERVICE',
#               'statusKey': 1,
#               'statusValue': 'In Service',
#               'testStation': False,
#               'totalDocks': 39},
#   '_type': 'logs'},
#  {'_index': 'divvy_stations_logs',
#   '_source': {'altitude': 0,
#               'availableBikes': 7,
#               'availableDocks': 28,
#               'city': 'Chicago',
#               'id': 50,
#               'is_renting': True,
#               'kioskType': 'K3_FULL',
#               'landMark': '13009',
#               'lastCommunicationTime': '2019-05-16 13:19:46',
#               'latitude': 41.8759326655,
#               'location': '',
#               'longitude': -87.6305845355,
#               'postalCode': '60605',
#               'stAddress1': 'Clark St & Ida B Wells Dr',
#               'stAddress2': '',
#               'stationName': 'Clark St & Ida B Wells Dr',
#               'status': 'IN_SERVICE',
#               'statusKey': 1,
#               'statusValue': 'In Service',
#               'testStation': False,
#               'totalDocks': 35},
#   '_type': 'logs'},
#  {'_index': 'divvy_stations_logs',
#   '_source': {'altitude': 0,
#               'availableBikes': 37,
#               'availableDocks': 2,
#               'city': 'Chicago',
#               'id': 51,
#               'is_renting': True,
#               'kioskType': 'K3_FULL',
#               'landMark': '13005',
#               'lastCommunicationTime': '2019-05-16 13:18:07',
#               'latitude': 41.884576228,
#               'location': '120 W. Randolph St.',
#               'longitude': -87.63188991,
#               'postalCode': '60601',
#               'stAddress1': 'Clark St & Randolph St',
#               'stAddress2': '',
#               'stationName': 'Clark St & Randolph St',
#               'status': 'IN_SERVICE',
#               'statusKey': 1,
#               'statusValue': 'In Service',
#               'testStation': False,
#               'totalDocks': 39},
#   '_type': 'logs'},
#  {'_index': 'divvy_stations_logs',
#   '_source': {'altitude': 0,
#               'availableBikes': 35,
#               'availableDocks': 0,
#               'city': 'Chicago',
#               'id': 52,
#               'is_renting': True,
#               'kioskType': 'K3_FULL',
#               'landMark': '13043',
#               'lastCommunicationTime': '2019-05-16 13:16:22',
#               'latitude': 41.886024,
#               'location': '203 N Michigan Ave',
#               'longitude': -87.624117,
#               'postalCode': '60601',
#               'stAddress1': 'Michigan Ave & Lake St',
#               'stAddress2': '',
#               'stationName': 'Michigan Ave & Lake St',
#               'status': 'IN_SERVICE',
#               'statusKey': 1,
#               'statusValue': 'In Service',
#               'testStation': False,
#               'totalDocks': 35},
#   '_type': 'logs'},
#  {'_index': 'divvy_stations_logs',
#   '_source': {'altitude': 0,
#               'availableBikes': 3,
#               'availableDocks': 24,
#               'city': 'Chicago',
#               'id': 53,
#               'is_renting': True,
#               'kioskType': 'K3_FULL',
#               'landMark': '13064',
#               'lastCommunicationTime': '2019-05-16 13:20:04',
#               'latitude': 41.894722,
#               'location': '',
#               'longitude': -87.634362,
#               'postalCode': '60654',
#               'stAddress1': 'Wells St & Huron St',
#               'stAddress2': '',
#               'stationName': 'Wells St & Huron St',
#               'status': 'IN_SERVICE',
#               'statusKey': 1,
#               'statusValue': 'In Service',
#               'testStation': False,
#               'totalDocks': 27},
#   '_type': 'logs'},
#  {'_index': 'divvy_stations_logs',
#   '_source': {'altitude': 0,
#               'availableBikes': 0,
#               'availableDocks': 18,
#               'city': 'Chicago',
#               'id': 54,
#               'is_renting': True,
#               'kioskType': 'K3_FULL',
#               'landMark': '13044',
#               'lastCommunicationTime': '2019-05-16 13:17:14',
#               'latitude': 41.896362458,
#               'location': '1040 W. Chicago Ave.',
#               'longitude': -87.6540612729,
#               'postalCode': '60642',
#               'stAddress1': 'Ogden Ave & Chicago Ave',
#               'stAddress2': '',
#               'stationName': 'Ogden Ave & Chicago Ave',
#               'status': 'IN_SERVICE',
#               'statusKey': 1,
#               'statusValue': 'In Service',
#               'testStation': False,
#               'totalDocks': 19},
#   '_type': 'logs'},
#  {'_index': 'divvy_stations_logs',
#   '_source': {'altitude': 0,
#               'availableBikes': 9,
#               'availableDocks': 13,
#               'city': 'Chicago',
#               'id': 55,
#               'is_renting': True,
#               'kioskType': 'K3_FULL',
#               'landMark': '13166',
#               'lastCommunicationTime': '2019-05-16 13:20:01',
#               'latitude': 41.867324,
#               'location': '850 W Roosevelt Rd',
#               'longitude': -87.648625,
#               'postalCode': '60608',
#               'stAddress1': 'Halsted St & Roosevelt Rd',
#               'stAddress2': '',
#               'stationName': 'Halsted St & Roosevelt Rd',
#               'status': 'IN_SERVICE',
#               'statusKey': 1,
#               'statusValue': 'In Service',
#               'testStation': False,
#               'totalDocks': 23},
#   '_type': 'logs'},
#  {'_index': 'divvy_stations_logs',
#   '_source': {'altitude': 0,
#               'availableBikes': 16,
#               'availableDocks': 11,
#               'city': 'Chicago',
#               'id': 56,
#               'is_renting': True,
#               'kioskType': 'K3_FULL',
#               'landMark': '13039',
#               'lastCommunicationTime': '2019-05-16 13:17:03',
#               'latitude': 41.888716036,
#               'location': '368 N. Desplaines St.',
#               'longitude': -87.6444478533,
#               'postalCode': '60661',
#               'stAddress1': 'Desplaines St & Kinzie St',
#               'stAddress2': '',
#               'stationName': 'Desplaines St & Kinzie St',
#               'status': 'IN_SERVICE',
#               'statusKey': 1,
#               'statusValue': 'In Service',
#               'testStation': False,
#               'totalDocks': 27},
#   '_type': 'logs'},
#  {'_index': 'divvy_stations_logs',
#   '_source': {'altitude': 0,
#               'availableBikes': 2,
#               'availableDocks': 13,
#               'city': 'Chicago',
#               'id': 57,
#               'is_renting': True,
#               'kioskType': 'K3_FULL',
#               'landMark': '13327',
#               'lastCommunicationTime': '2019-05-16 13:17:14',
#               'latitude': 41.8671177825,
#               'location': '559 W Roosevelt Rd',
#               'longitude': -87.6410879593,
#               'postalCode': '60607',
#               'stAddress1': 'Clinton St & Roosevelt Rd',
#               'stAddress2': '',
#               'stationName': 'Clinton St & Roosevelt Rd',
#               'status': 'IN_SERVICE',
#               'statusKey': 1,
#               'statusValue': 'In Service',
#               'testStation': False,
#               'totalDocks': 15},
#   '_type': 'logs'},
#  {'_index': 'divvy_stations_logs',
#   '_source': {'altitude': 0,
#               'availableBikes': 5,
#               'availableDocks': 17,
#               'city': 'Chicago',
#               'id': 58,
#               'is_renting': True,
#               'kioskType': 'K3_FULL',
#               'landMark': '13025',
#               'lastCommunicationTime': '2019-05-16 13:18:25',
#               'latitude': 41.916017,
#               'location': '',
#               'longitude': -87.668879,
#               'postalCode': '60622',
#               'stAddress1': 'Marshfield Ave & Cortland St',
#               'stAddress2': '',
#               'stationName': 'Marshfield Ave & Cortland St',
#               'status': 'IN_SERVICE',
#               'statusKey': 1,
#               'statusValue': 'In Service',
#               'testStation': False,
#               'totalDocks': 23},
#   '_type': 'logs'},
#  {'_index': 'divvy_stations_logs',
#   '_source': {'altitude': 0,
#               'availableBikes': 0,
#               'availableDocks': 22,
#               'city': 'Chicago',
#               'id': 59,
#               'is_renting': True,
#               'kioskType': 'K3_FULL',
#               'landMark': '13031',
#               'lastCommunicationTime': '2019-05-16 13:16:12',
#               'latitude': 41.867227,
#               'location': '1210 S Wabash Ave',
#               'longitude': -87.625961,
#               'postalCode': '60605',
#               'stAddress1': 'Wabash Ave & Roosevelt Rd',
#               'stAddress2': '',
#               'stationName': 'Wabash Ave & Roosevelt Rd',
# ...
#               'id': 647,
#               'is_renting': True,
#               'kioskType': 'K3_FULL',
#               'landMark': '18024',
#               'lastCommunicationTime': '2019-05-16 13:18:34',
#               'latitude': 41.786691,
#               'location': '',
#               'longitude': -87.655859,
#               'postalCode': '60636',
#               'stAddress1': 'Elizabeth St & 59th St',
#               'stAddress2': '',
#               'stationName': 'Elizabeth St & 59th St',
#               'status': 'IN_SERVICE',
#               'statusKey': 1,
#               'statusValue': 'In Service',
#               'testStation': False,
#               'totalDocks': 7},
#   '_type': 'logs'},
#  {'_index': 'divvy_stations_logs',
#   '_source': {'altitude': 0,
#               'availableBikes': 3,
#               'availableDocks': 4,
#               'city': 'Chicago',
#               'id': 648,
#               'is_renting': True,
#               'kioskType': 'K3_FULL',
#               'landMark': '18025',
#               'lastCommunicationTime': '2019-05-16 13:17:28',
#               'latitude': 41.77987,
#               'location': '',
#               'longitude': -87.650919,
#               'postalCode': '60621',
#               'stAddress1': 'Carpenter St & 63rd St',
#               'stAddress2': '',
#               'stationName': 'Carpenter St & 63rd St',
#               'status': 'IN_SERVICE',
#               'statusKey': 1,
#               'statusValue': 'In Service',
#               'testStation': False,
#               'totalDocks': 7},
#   '_type': 'logs'},
#  {'_index': 'divvy_stations_logs',
#   '_source': {'altitude': 0,
#               'availableBikes': 8,
#               'availableDocks': 4,
#               'city': 'Chicago',
#               'id': 649,
#               'is_renting': True,
#               'kioskType': 'K3_FULL',
#               'landMark': '18026',
#               'lastCommunicationTime': '2019-05-16 13:18:09',
#               'latitude': 41.779835,
#               'location': '',
#               'longitude': -87.634774,
#               'postalCode': '60621',
#               'stAddress1': 'Stewart Ave & 63rd St (*)',
#               'stAddress2': '',
#               'stationName': 'Stewart Ave & 63rd St (*)',
#               'status': 'IN_SERVICE',
#               'statusKey': 1,
#               'statusValue': 'In Service',
#               'testStation': False,
#               'totalDocks': 12},
#   '_type': 'logs'},
#  {'_index': 'divvy_stations_logs',
#   '_source': {'altitude': 0,
#               'availableBikes': 5,
#               'availableDocks': 7,
#               'city': 'Chicago',
#               'id': 650,
#               'is_renting': True,
#               'kioskType': 'K3_FULL',
#               'landMark': '18027',
#               'lastCommunicationTime': '2019-05-16 13:19:13',
#               'latitude': 41.768898,
#               'location': '',
#               'longitude': -87.635876,
#               'postalCode': '60621',
#               'stAddress1': 'Eggleston Ave & 69th St (*)',
#               'stAddress2': '',
#               'stationName': 'Eggleston Ave & 69th St (*)',
#               'status': 'IN_SERVICE',
#               'statusKey': 1,
#               'statusValue': 'In Service',
#               'testStation': False,
#               'totalDocks': 12},
#   '_type': 'logs'},
#  {'_index': 'divvy_stations_logs',
#   '_source': {'altitude': 0,
#               'availableBikes': 4,
#               'availableDocks': 3,
#               'city': 'Chicago',
#               'id': 651,
#               'is_renting': True,
#               'kioskType': 'K3_FULL',
#               'landMark': '18028',
#               'lastCommunicationTime': '2019-05-16 13:18:20',
#               'latitude': 41.765286,
#               'location': '',
#               'longitude': -87.621748,
#               'postalCode': '60619',
#               'stAddress1': 'Michigan Ave & 71st St',
#               'stAddress2': '',
#               'stationName': 'Michigan Ave & 71st St',
#               'status': 'IN_SERVICE',
#               'statusKey': 1,
#               'statusValue': 'In Service',
#               'testStation': False,
#               'totalDocks': 7},
#   '_type': 'logs'},
#  {'_index': 'divvy_stations_logs',
#   '_source': {'altitude': 0,
#               'availableBikes': 3,
#               'availableDocks': 8,
#               'city': 'Chicago',
#               'id': 652,
#               'is_renting': True,
#               'kioskType': 'K3_FULL',
#               'landMark': '18029',
#               'lastCommunicationTime': '2019-05-16 13:17:18',
#               'latitude': 41.766,
#               'location': '',
#               'longitude': -87.611726,
#               'postalCode': '60637',
#               'stAddress1': 'Rhodes Ave & 71st St',
#               'stAddress2': '',
#               'stationName': 'Rhodes Ave & 71st St',
#               'status': 'IN_SERVICE',
#               'statusKey': 1,
#               'statusValue': 'In Service',
#               'testStation': False,
#               'totalDocks': 11},
#   '_type': 'logs'},
#  {'_index': 'divvy_stations_logs',
#   '_source': {'altitude': 0,
#               'availableBikes': 7,
#               'availableDocks': 4,
#               'city': 'Chicago',
#               'id': 653,
#               'is_renting': True,
#               'kioskType': 'K3_FULL',
#               'landMark': '18030',
#               'lastCommunicationTime': '2019-05-16 13:17:02',
#               'latitude': 41.780595,
#               'location': '',
#               'longitude': -87.584846,
#               'postalCode': '60649',
#               'stAddress1': 'Cornell Dr & Hayes Dr',
#               'stAddress2': '',
#               'stationName': 'Cornell Dr & Hayes Dr',
#               'status': 'IN_SERVICE',
#               'statusKey': 1,
#               'statusValue': 'In Service',
#               'testStation': False,
#               'totalDocks': 11},
#   '_type': 'logs'},
#  {'_index': 'divvy_stations_logs',
#   '_source': {'altitude': 0,
#               'availableBikes': 0,
#               'availableDocks': 12,
#               'city': 'Chicago',
#               'id': 654,
#               'is_renting': True,
#               'kioskType': 'K3_FULL',
#               'landMark': '18046',
#               'lastCommunicationTime': '2019-05-16 13:19:24',
#               'latitude': 41.883073,
#               'location': '',
#               'longitude': -87.656952,
#               'postalCode': '60607',
#               'stAddress1': 'Racine Ave & Washington Blvd (*)',
#               'stAddress2': '',
#               'stationName': 'Racine Ave & Washington Blvd (*)',
#               'status': 'IN_SERVICE',
#               'statusKey': 1,
#               'statusValue': 'In Service',
#               'testStation': False,
#               'totalDocks': 12},
#   '_type': 'logs'},
#  {'_index': 'divvy_stations_logs',
#   '_source': {'altitude': 0,
#               'availableBikes': 6,
#               'availableDocks': 9,
#               'city': 'Chicago',
#               'id': 655,
#               'is_renting': True,
#               'kioskType': 'K3_FULL',
#               'landMark': '18047',
#               'lastCommunicationTime': '2019-05-16 13:18:47',
#               'latitude': 41.979851,
#               'location': '',
#               'longitude': -87.681932,
#               'postalCode': '60625',
#               'stAddress1': 'Hoyne Ave & Balmoral Ave',
#               'stAddress2': '',
#               'stationName': 'Hoyne Ave & Balmoral Ave',
#               'status': 'IN_SERVICE',
#               'statusKey': 1,
#               'statusValue': 'In Service',
#               'testStation': False,
#               'totalDocks': 15},
#   '_type': 'logs'},
#  {'_index': 'divvy_stations_logs',
#   '_source': {'altitude': 0,
#               'availableBikes': 9,
#               'availableDocks': 7,
#               'city': 'Chicago',
#               'id': 656,
#               'is_renting': True,
#               'kioskType': 'K3_FULL',
#               'landMark': '18054',
#               'lastCommunicationTime': '2019-05-16 13:16:35',
#               'latitude': 41.885951,
#               'location': '',
#               'longitude': -87.677009,
#               'postalCode': '60612',
#               'stAddress1': 'Damen Ave & Walnut (Lake) St (*)',
#               'stAddress2': '',
#               'stationName': 'Damen Ave & Walnut (Lake) St (*)',
#               'status': 'IN_SERVICE',
#               'statusKey': 1,
#               'statusValue': 'In Service',
#               'testStation': False,
#               'totalDocks': 16},
#   '_type': 'logs'},
#  {'_index': 'divvy_stations_logs',
#   '_source': {'altitude': 0,
#               'availableBikes': 0,
#               'availableDocks': 15,
#               'city': 'Chicago',
#               'id': 657,
#               'is_renting': True,
#               'kioskType': 'K3_FULL',
#               'landMark': '18056',
#               'lastCommunicationTime': '2019-05-16 13:19:36',
#               'latitude': 41.899181,
#               'location': '',
#               'longitude': -87.6722,
#               'postalCode': '60622',
#               'stAddress1': 'Wood St & Augusta Blvd',
#               'stAddress2': '',
#               'stationName': 'Wood St & Augusta Blvd',
#               'status': 'IN_SERVICE',
#               'statusKey': 1,
#               'statusValue': 'In Service',
#               'testStation': False,
#               'totalDocks': 15},
#   '_type': 'logs'},
#  {'_index': 'divvy_stations_logs',
#   '_source': {'altitude': 0,
#               'availableBikes': 6,
#               'availableDocks': 10,
#               'city': 'Chicago',
#               'id': 658,
#               'is_renting': True,
#               'kioskType': 'K3_FULL',
#               'landMark': '18057',
#               'lastCommunicationTime': '2019-05-16 13:17:18',
#               'latitude': 41.902997,
#               'location': '',
#               'longitude': -87.683825,
#               'postalCode': '60622',
#               'stAddress1': 'Leavitt St & Division St (*)',
#               'stAddress2': '',
#               'stationName': 'Leavitt St & Division St (*)',
#               'status': 'IN_SERVICE',
#               'statusKey': 1,
#               'statusValue': 'In Service',
#               'testStation': False,
#               'totalDocks': 16},
#   '_type': 'logs'},
#  {'_index': 'divvy_stations_logs',
#   '_source': {'altitude': 0,
#               'availableBikes': 2,
#               'availableDocks': 12,
#               'city': 'Chicago',
#               'id': 659,
#               'is_renting': True,
#               'kioskType': 'K3_FULL',
#               'landMark': '18058',
#               'lastCommunicationTime': '2019-05-16 13:16:11',
#               'latitude': 41.895501,
#               'location': '',
#               'longitude': -87.682017,
#               'postalCode': '60612',
#               'stAddress1': 'Leavitt St & Chicago Ave',
#               'stAddress2': '',
#               'stationName': 'Leavitt St & Chicago Ave',
#               'status': 'IN_SERVICE',
#               'statusKey': 1,
#               'statusValue': 'In Service',
#               'testStation': False,
#               'totalDocks': 15},
#   '_type': 'logs'},
#  {'_index': 'divvy_stations_logs',
#   '_source': {'altitude': 0,
#               'availableBikes': 9,
#               'availableDocks': 6,
#               'city': 'Chicago',
#               'id': 660,
#               'is_renting': True,
#               'kioskType': 'K3_FULL',
#               'landMark': '18066',
#               'lastCommunicationTime': '2019-05-16 13:17:26',
#               'latitude': 42.004583,
#               'location': '',
#               'longitude': -87.661406,
#               'postalCode': '60626',
#               'stAddress1': 'Sheridan Rd & Columbia Ave',
#               'stAddress2': '',
#               'stationName': 'Sheridan Rd & Columbia Ave',
#               'status': 'IN_SERVICE',
#               'statusKey': 1,
#               'statusValue': 'In Service',
#               'testStation': False,
#               'totalDocks': 15},
#   '_type': 'logs'},
#  {'_index': 'divvy_stations_logs',
#   '_source': {'altitude': 0,
#               'availableBikes': 8,
#               'availableDocks': 7,
#               'city': 'Evanston',
#               'id': 661,
#               'is_renting': True,
#               'kioskType': 'K3_FULL',
#               'landMark': 'E012',
#               'lastCommunicationTime': '2019-05-16 13:16:55',
#               'latitude': 42.057044,
#               'location': '',
#               'longitude': -87.686554,
#               'postalCode': '60201',
#               'stAddress1': 'Evanston Civic Center',
#               'stAddress2': '',
#               'stationName': 'Evanston Civic Center',
#               'status': 'IN_SERVICE',
#               'statusKey': 1,
#               'statusValue': 'In Service',
#               'testStation': False,
#               'totalDocks': 15},
#   '_type': 'logs'},
#  {'_index': 'divvy_stations_logs',
#   '_source': {'altitude': 0,
#               'availableBikes': 7,
#               'availableDocks': 8,
#               'city': 'Evanston',
#               'id': 662,
#               'is_renting': True,
#               'kioskType': 'K3_FULL',
#               'landMark': 'E013',
#               'lastCommunicationTime': '2019-05-16 13:18:30',
#               'latitude': 42.023463,
#               'location': '',
#               'longitude': -87.699595,
#               'postalCode': '60201',
#               'stAddress1': 'Dodge Ave & Mulford St',
#               'stAddress2': '',
#               'stationName': 'Dodge Ave & Mulford St',
#               'status': 'IN_SERVICE',
#               'statusKey': 1,
#               'statusValue': 'In Service',
#               'testStation': False,
#               'totalDocks': 15},
#   '_type': 'logs'},
#  {'_index': 'divvy_stations_logs',
#   '_source': {'altitude': 0,
#               'availableBikes': 6,
#               'availableDocks': 9,
#               'city': 'Evanston',
#               'id': 663,
#               'is_renting': True,
#               'kioskType': 'K3_FULL',
#               'landMark': 'E014',
#               'lastCommunicationTime': '2019-05-16 13:18:23',
#               'latitude': 42.064854,
#               'location': '',
#               'longitude': -87.715297,
#               'postalCode': '60201',
#               'stAddress1': 'Lincolnwood Dr & Central St',
#               'stAddress2': '',
#               'stationName': 'Lincolnwood Dr & Central St',
#               'status': 'IN_SERVICE',
#               'statusKey': 1,
#               'statusValue': 'In Service',
#               'testStation': False,
#               'totalDocks': 15},
#   '_type': 'logs'},
#  {'_index': 'divvy_stations_logs',
#   '_source': {'altitude': 0,
#               'availableBikes': 4,
#               'availableDocks': 12,
#               'city': 'Chicago',
#               'id': 664,
#               'is_renting': True,
#               'kioskType': 'K3_FULL',
#               'landMark': '18068',
#               'lastCommunicationTime': '2019-05-16 13:20:11',
#               'latitude': 41.939354,
#               'location': '',
#               'longitude': -87.683282,
#               'postalCode': '60618',
#               'stAddress1': 'Leavitt St & Belmont Ave (*)',
#               'stAddress2': '',
#               'stationName': 'Leavitt St & Belmont Ave (*)',
#               'status': 'IN_SERVICE',
#               'statusKey': 1,
#               'statusValue': 'In Service',
#               'testStation': False,
#               'totalDocks': 16},
#   '_type': 'logs'},
#  {'_index': 'divvy_stations_logs',
#   '_source': {'altitude': 0,
#               'availableBikes': 4,
#               'availableDocks': 3,
#               'city': 'Chicago',
#               'id': 665,
#               'is_renting': True,
#               'kioskType': 'K3_FULL',
#               'landMark': '19031',
#               'lastCommunicationTime': '2019-05-16 13:17:00',
#               'latitude': 41.747363,
#               'location': '',
#               'longitude': -87.580046,
#               'postalCode': '60617',
#               'stAddress1': 'South Chicago Ave & Elliot Ave',
#               'stAddress2': '',
#               'stationName': 'South Chicago Ave & Elliot Ave',
#               'status': 'IN_SERVICE',
#               'statusKey': 1,
#               'statusValue': 'In Service',
#               'testStation': False,
#               'totalDocks': 7},
#   '_type': 'logs'}]

# %%
# Start the bulk document-indexing
    
helpers.bulk(es, list_station_documents)
# Out:
# (608, [])

# %%
from elasticsearch import Elasticsearch, helpers 
import time


while True:
    # Get divvy stations status
    # Status is returned as a json reply
    response = urllib.request.urlopen('https://feeds.divvybikes.com/stations/stations.json')
    
    # Extract the body of the reply
    response_body = response.read()
    
    # Decode the format in json format
    stations_json = json.loads(response_body.decode("utf-8"))
    
    # load data file into a dataframe
    df__stations = pd.DataFrame(stations_json['stationBeanList'])
    
    # Clean the BLANKs from the data
    df__stations['altitude'] = df__stations['altitude'].apply(lambda x: 0 if x == '' else x)
    df__stations['postalCode'] = df__stations['postalCode'].apply(lambda x: 0 if x == '' else x)
    
    #Remove the whitespace from the end of hte city name
    df__stations['city'] = df__stations['city'].apply(lambda x: 'Chicago' if x == 'Chicago ' else x)
    
    # lets store our data subset into a file
    # This way you have a copy of data stored in a file 
    # that you could use in case you want to debug a problem on the orginal data received
    df__stations.to_csv('divvy_stations_logs.csv',sep=',', encoding='utf-8', index=False)
    df_stations_json = df__stations.to_json(orient='records')
    df_stations_json = json.loads(df_stations_json)
    list_station_documents = []
    for station in df_stations_json:
        index_station = {
            "_index": "divvy_stations_logs",
            "_type": "logs",
            "_source": station
        }
        list_station_documents.append(index_station)                      
    
    es = Elasticsearch()
    
    # Start the bulk document-indexing
    helpers.bulk(es, list_station_documents) 
    
    # Sleep for 125 seconds; divvy updates its stations status every 2 minutes
    print('Sent Heartbeat to Divvy Servers and Going to sleep now ...')
    time.sleep(90)    
    continue
# Out:
# Sent Heartbeat to Divvy Servers and Going to sleep now ...
# Sent Heartbeat to Divvy Servers and Going to sleep now ...
# Sent Heartbeat to Divvy Servers and Going to sleep now ...
# Sent Heartbeat to Divvy Servers and Going to sleep now ...
# Sent Heartbeat to Divvy Servers and Going to sleep now ...
# Sent Heartbeat to Divvy Servers and Going to sleep now ...
# Sent Heartbeat to Divvy Servers and Going to sleep now ...
# Sent Heartbeat to Divvy Servers and Going to sleep now ...
# Sent Heartbeat to Divvy Servers and Going to sleep now ...
# Sent Heartbeat to Divvy Servers and Going to sleep now ...
# Sent Heartbeat to Divvy Servers and Going to sleep now ...
# Sent Heartbeat to Divvy Servers and Going to sleep now ...
# Sent Heartbeat to Divvy Servers and Going to sleep now ...
# Sent Heartbeat to Divvy Servers and Going to sleep now ...
# Sent Heartbeat to Divvy Servers and Going to sleep now ...
# Sent Heartbeat to Divvy Servers and Going to sleep now ...
# Sent Heartbeat to Divvy Servers and Going to sleep now ...
# Sent Heartbeat to Divvy Servers and Going to sleep now ...
# Sent Heartbeat to Divvy Servers and Going to sleep now ...
# Sent Heartbeat to Divvy Servers and Going to sleep now ...
# Sent Heartbeat to Divvy Servers and Going to sleep now ...
# Sent Heartbeat to Divvy Servers and Going to sleep now ...
# Sent Heartbeat to Divvy Servers and Going to sleep now ...
# Sent Heartbeat to Divvy Servers and Going to sleep now ...
# Sent Heartbeat to Divvy Servers and Going to sleep now ...
